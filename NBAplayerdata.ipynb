# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
#for team in teams:
req = requests.get("https://www.basketball-reference.com/teams/GS/2016/on-off/")
content = req.
soup = BeautifulSoup(content)
table = soup.find('table')
#pd.read_html(str(table))

# %%
content

# %%
req = requests.get("https://www.basketball-reference.com/leagues/NBA_{}_advanced.html")
content = req.content
soup = BeautifulSoup(content)
tables = soup.find('table')
globals()['stats_%s' % '2016'] = pd.read_html(str(tables))
globals()['stats_%s' % '2016'] = globals()['stats_%s' % '2016'][0]

# %%
years = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017']

# %%
for year in years:
    req = requests.get("https://www.basketball-reference.com/leagues/NBA_{}_advanced.html".format(year))
    content = req.content
    soup = BeautifulSoup(content)
    tables = soup.find('table')
    globals()['advanced_stats_%s' % year] = pd.read_html(str(tables))
    globals()['advanced_stats_%s' % year] = globals()['advanced_stats_%s' % year][0]

# %%
advanced_stats_2007['YR'] = '06-07'
advanced_stats_2008['YR'] = '07-08'
advanced_stats_2009['YR'] = '08-09'
advanced_stats_2010['YR'] = '09-10'
advanced_stats_2011['YR'] = '10-11'
advanced_stats_2012['YR'] = '11-12'
advanced_stats_2013['YR'] = '12-13'
advanced_stats_2014['YR'] = '13-14'
advanced_stats_2015['YR'] = '14-15'
advanced_stats_2016['YR'] = '15-16'
advanced_stats_2017['YR'] = '16-17'

# %%
advanced_stats_2006['YR'] = '05-06'

# %%
advanced_stats_2006
# Out:
#       Rk                    Player    Pos  Age   Tm   G    MP   PER   TS%  \
# 0      1       Shareef Abdur-Rahim     PF   29  SAC  72  1961  17.2  .588
# 1      2                Alex Acker     SG   23  DET   5    35  -2.4  .281
# 2      3               Malik Allen     PF   27  CHI  54   701  11.5  .504
# 3      4                Ray Allen*     SG   30  SEA  78  3022  22.2  .590
# 4      5                Tony Allen     PG   24  BOS  51   978  12.9  .554
# 5      6              Rafer Alston     PG   29  HOU  63  2431  12.6  .475
# 6      7            Chris Andersen      C   27  NOK  32   570  14.1  .562
# 7      8             Alan Anderson     SF   23  CHA  36   564  10.4  .520
# 8      9            Derek Anderson     SG   31  TOT  43  1047  10.8  .496
# 9      9            Derek Anderson     SG   31  HOU  20   582  12.5  .527
# 10     9            Derek Anderson     SG   31  MIA  23   465   8.7  .453
# 11    10          Shandon Anderson     SF   32  MIA  48   638   6.2  .470
# ...

# %%
advanced_stats_2008
# Out:
#       Rk               Player    Pos  Age   Tm   G    MP    PER   TS%  3PAr  \
# 0      1  Shareef Abdur-Rahim     PF   31  SAC   6    51    5.5  .317  .000
# 1      2        Arron Afflalo     SG   22  DET  75   970   10.2  .494  .199
# 2      3         Maurice Ager     SG   23  TOT  26   165    1.8  .363  .292
# 3      3         Maurice Ager     SG   23  DAL  12    77   -4.4  .253  .296
# 4      3         Maurice Ager     SG   23  NJN  14    88    7.1  .443  .289
# 5      4         Blake Ahearn     PG   23  MIA  12   177    9.0  .495  .596
# 6      5    LaMarcus Aldridge     PF   22  POR  76  2649   18.5  .523  .006
# 7      6          Malik Allen     PF   29  TOT  73  1096    9.8  .500  .006
# 8      6          Malik Allen     PF   29  NJN  48   763   10.1  .489  .008
# 9      6          Malik Allen     PF   29  DAL  25   333    9.1  .540  .000
# 10     7           Ray Allen*     SG   32  BOS  73  2624   16.4  .584  .458
# ...

# %%
frames = [advanced_stats_2007,advanced_stats_2008,advanced_stats_2009,advanced_stats_2010,advanced_stats_2011,advanced_stats_2012,advanced_stats_2013,advanced_stats_2014,advanced_stats_2015,advanced_stats_2016,advanced_stats_2017]

# %%
allplayers = advanced_stats_2006.append(frames)

# %%
allplayers[allplayers['Tm'] == 'TOT']['Tm']
# Out:
# 8      TOT
# 16     TOT
# 20     TOT
# 23     TOT
# 29     TOT
# 33     TOT
# 36     TOT
# 47     TOT
# 59     TOT
# 62     TOT
# 79     TOT
# 101    TOT
# 122    TOT
# 127    TOT
# 131    TOT
# 136    TOT
# 153    TOT
# 161    TOT
# 176    TOT
# 179    TOT
# 200    TOT
# 215    TOT
# 257    TOT
# 261    TOT
# 279    TOT
# 304    TOT
# 308    TOT
# 344    TOT
# 354    TOT
# 362    TOT
#       ...
# 268    TOT
# 284    TOT
# 300    TOT
# 313    TOT
# 321    TOT
# 335    TOT
# 363    TOT
# 366    TOT
# 369    TOT
# 392    TOT
# 410    TOT
# 414    TOT
# 420    TOT
# 424    TOT
# 445    TOT
# 452    TOT
# 455    TOT
# 468    TOT
# 486    TOT
# 502    TOT
# 520    TOT
# 528    TOT
# 539    TOT
# 547    TOT
# 551    TOT
# 576    TOT
# 588    TOT
# 591    TOT
# 594    TOT
# 599    TOT
# Name: Tm, Length: 692, dtype: object

# %%
test = allplayers.drop(allplayers[allplayers.Tm == 'TOT'].index)

# %%
allplayers = allplayers[allplayers.Tm != 'TOT']

# %%
allplayers.drop(['Unnamed: 19', 'Unnamed: 24'], axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
allplayers.head()
# Out:
#   Rk               Player Pos Age   Tm   G    MP   PER   TS%  3PAr  ...    \
# 0  1  Shareef Abdur-Rahim  PF  29  SAC  72  1961  17.2  .588  .035  ...
# 1  2           Alex Acker  SG  23  DET   5    35  -2.4  .281  .313  ...
# 2  3          Malik Allen  PF  27  CHI  54   701  11.5  .504  .004  ...
# 3  4           Ray Allen*  SG  30  SEA  78  3022  22.2  .590  .435  ...
# 4  5           Tony Allen  PG  24  BOS  51   978  12.9  .554  .124  ...
#
#    USG%   OWS   DWS    WS   WS/48   OBPM  DBPM    BPM  VORP     YR
# 0  20.1   4.0   2.2   6.2    .152    0.4   0.4    0.9   1.4  05-06
# 1  27.2  -0.2   0.0  -0.2  -0.230  -10.4  -1.9  -12.3  -0.1  05-06
# 2  19.2   0.0   1.0   1.0    .068   -3.9   0.0   -3.9  -0.3  05-06
# 3  27.4   9.8  -0.3   9.5    .150    6.7  -3.1    3.6   4.2  05-06
# 4  18.8   0.6   1.0   1.7    .082   -1.6   0.2   -1.4   0.2  05-06
#
# [5 rows x 28 columns]

# %%
team_df = pd.read_csv('data/TEAMstats - TeamPer100.csv')

# %%
team_df.head()
# Out:
#                      Team     YR   G     MP    FG   FGA    FG%    3P   3PA  \
# 0  Golden State Warriors*  17-18  82  19730  42.9  85.3  0.503  11.3  28.9
# 1        Houston Rockets*  17-18  82  19755  39.5  86.0  0.460  15.6  43.2
# 2   New Orleans Pelicans*  17-18  82  19955  41.9  86.6  0.483  10.0  27.7
# 3        Toronto Raptors*  17-18  82  19830  42.0  89.1  0.472  12.0  33.6
# 4    Cleveland Cavaliers*  17-18  82  19730  41.1  86.3  0.476  12.2  32.7
#
#      3P%  ...      FT%  ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.391  ...    0.815  8.4  35.1  43.6  29.3  8.0  7.5  15.5  19.6  113.6
# 1  0.362  ...    0.781  9.2  35.2  44.4  22.0  8.7  4.9  14.1  19.9  114.7
# 2  0.362  ...    0.772  8.5  35.0  43.5  26.3  7.9  5.8  14.6  18.8  109.6
# 3  0.358  ...    0.794  9.9  34.9  44.8  24.8  7.8  6.2  13.6  22.2  113.8
# 4  0.372  ...    0.779  8.6  34.3  42.9  23.8  7.2  3.9  14.0  18.9  112.9
#
# [5 rows x 25 columns]

# %%
def update_team_name(df, team, yr):
    df[team] = df[team].str.replace('*', '')
    
    return df

# %%
team_df = update_team_name(team_df, 'Team', 'YR')

# %%
team_df
# Out:
#                                         Team     YR   G     MP    FG   FGA  \
# 0                Golden State Warriors 17-18  17-18  82  19730  42.9  85.3
# 1                      Houston Rockets 17-18  17-18  82  19755  39.5  86.0
# 2                 New Orleans Pelicans 17-18  17-18  82  19955  41.9  86.6
# 3                      Toronto Raptors 17-18  17-18  82  19830  42.0  89.1
# 4                  Cleveland Cavaliers 17-18  17-18  82  19730  41.1  86.3
# 5                       Denver Nuggets 17-18  17-18  82  19880  41.6  88.5
# 6                   Philadelphia 76ers 17-18  17-18  82  19780  40.7  86.3
# 7               Minnesota Timberwolves 17-18  17-18  82  19805  42.5  89.2
# 8                 Los Angeles Clippers 17-18  17-18  82  19705  40.7  86.4
# 9                    Charlotte Hornets 17-18  17-18  82  19780  39.4  87.6
# 10                  Los Angeles Lakers 17-18  17-18  82  19905  40.1  87.1
# ...

# %%
advdf = pd.read_csv('data/TEAMstats - AdvancedTeam.csv')

# %%
advdf = update_team_name(advdf, 'Team', 'Year')

# %%
advdf
# Out:
#      Rk                               Team   Year   Age   W   L  PW  PL   MOV  \
# 0     1                    Houston Rockets  17-18  29.8  65  17  61  21  8.48
# 1     2                    Toronto Raptors  17-18  25.8  59  23  60  22  7.78
# 2     3              Golden State Warriors  17-18  28.8  58  24  56  26  5.98
# 3     4                          Utah Jazz  17-18  26.7  48  34  53  29  4.30
# 4     5                 Philadelphia 76ers  17-18  25.8  52  30  53  29  4.50
# 5     6              Oklahoma City Thunder  17-18  27.3  48  34  50  32  3.41
# 6     7                     Boston Celtics  17-18  24.7  55  27  51  31  3.59
# 7     8                  San Antonio Spurs  17-18  29.3  47  35  49  33  2.89
# 8     9             Portland Trail Blazers  17-18  25.6  49  33  48  34  2.60
# 9    10             Minnesota Timberwolves  17-18  27.1  47  35  47  35  2.23
# 10   11                     Denver Nuggets  17-18  25.1  46  36  45  37  1.48
# ...

# %%
allplayers.drop('t_yr', axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
allplayers['t_yr'] = allplayers.Tm + ' ' + allplayers.YR
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
allplayers.head(7)
# Out:
#   Rk               Player Pos Age   Tm   G    MP   PER   TS%  3PAr    ...      \
# 0  1  Shareef Abdur-Rahim  PF  29  SAC  72  1961  17.2  .588  .035    ...
# 1  2           Alex Acker  SG  23  DET   5    35  -2.4  .281  .313    ...
# 2  3          Malik Allen  PF  27  CHI  54   701  11.5  .504  .004    ...
# 3  4           Ray Allen*  SG  30  SEA  78  3022  22.2  .590  .435    ...
# 4  5           Tony Allen  PG  24  BOS  51   978  12.9  .554  .124    ...
# 5  6         Rafer Alston  PG  29  HOU  63  2431  12.6  .475  .423    ...
# 6  7       Chris Andersen   C  27  NOK  32   570  14.1  .562  .000    ...
#
#     OWS   DWS    WS   WS/48   OBPM  DBPM    BPM  VORP     YR       t_yr
# 0   4.0   2.2   6.2    .152    0.4   0.4    0.9   1.4  05-06  SAC 05-06
# 1  -0.2   0.0  -0.2  -0.230  -10.4  -1.9  -12.3  -0.1  05-06  DET 05-06
# 2   0.0   1.0   1.0    .068   -3.9   0.0   -3.9  -0.3  05-06  CHI 05-06
# 3   9.8  -0.3   9.5    .150    6.7  -3.1    3.6   4.2  05-06  SEA 05-06
# ...

# %%
allplayers.Tm.unique()
# Out:
# array(['SAC', 'DET', 'CHI', 'SEA', 'BOS', 'HOU', 'NOK', 'CHA', 'MIA',
#        'CLE', 'DEN', 'TOR', 'WAS', 'NYK', 'ORL', 'DAL', 'MEM', 'LAC',
#        'Tm', 'MIN', 'PHO', 'PHI', 'SAS', 'ATL', 'MIL', 'IND', 'GSW',
#        'POR', 'UTA', 'LAL', 'NJN', 'NOH', 'OKC', 'BRK', 'NOP', 'CHO'],
#       dtype=object)

# %%
advdf.Team.unique()
# Out:
# array(['Houston Rockets', 'Toronto Raptors', 'Golden State Warriors',
#        'Utah Jazz', 'Philadelphia 76ers', 'Oklahoma City Thunder',
#        'Boston Celtics', 'San Antonio Spurs', 'Portland Trail Blazers',
#        'Minnesota Timberwolves', 'Denver Nuggets', 'New Orleans Pelicans',
#        'Indiana Pacers', 'Cleveland Cavaliers', 'Washington Wizards',
#        'Los Angeles Clippers', 'Miami Heat', 'Charlotte Hornets',
#        'Detroit Pistons', 'Milwaukee Bucks', 'Los Angeles Lakers',
#        'Dallas Mavericks', 'New York Knicks', 'Brooklyn Nets',
#        'Orlando Magic', 'Atlanta Hawks', 'Memphis Grizzlies',
#        'Sacramento Kings', 'Chicago Bulls', 'Phoenix Suns',
#        'Charlotte Bobcats', 'New Orleans Hornets', 'New Jersey Nets',
#        'Seattle SuperSonics', 'New Orleans/Oklahoma City Hornets'],
#       dtype=object)

# %%
tconv = pd.read_csv('data/Pstats - teams.csv')

# %%
tconv
# Out:
#                                  Team   Tm
# 0                     Houston Rockets  HOU
# 1                           Utah Jazz  UTA
# 2                      Boston Celtics  BOS
# 3              Minnesota Timberwolves  MIN
# 4                      Indiana Pacers  IND
# 5                Los Angeles Clippers  LAC
# 6                     Detroit Pistons  DET
# 7                    Dallas Mavericks  DAL
# 8                       Orlando Magic  ORL
# 9                    Sacramento Kings  SAC
# 10                  Charlotte Bobcats  CHA
# 11                Seattle SuperSonics  SEA
# 12                    Toronto Raptors  TOR
# 13                 Philadelphia 76ers  PHI
# 14                  San Antonio Spurs  SAS
# 15                     Denver Nuggets  DEN
# 16                Cleveland Cavaliers  CLE
# 17                         Miami Heat  MIA
# 18                    Milwaukee Bucks  MIL
# 19                    New York Knicks  NYK
# 20                      Atlanta Hawks  ATL
# ...

# %%
apf = pd.merge(allplayers, tconv, on='Tm', how='outer')

# %%
apf.drop('t_yr', axis=1, inplace=True)

# %%
apf['TM'] = apf['Team'] + ' ' + apf['YR']

# %%
apf.drop(['Rk', 'Tm', 'YR', 'Team'], axis=1, inplace=True)

# %%
apf[apf.TM == 'Sacramento Kings 05-06']
# Out:
#                  Player Pos Age   G    MP   PER   TS%  3PAr    FTr  ORB%  \
# 0   Shareef Abdur-Rahim  PF  29  72  1961  17.2  .588  .035   .440   6.4
# 1            Mike Bibby  PG  27  82  3167  17.9  .554  .360   .292   1.1
# 2      Francisco Garcia  SF  24  67  1301  10.3  .510  .422   .311   3.5
# 3            Jason Hart  PG  27  66   818   7.1  .444  .140   .253   1.7
# 4          Kevin Martin  SG  22  72  1913  14.8  .604  .328   .407   3.6
# 5           Brad Miller   C  29  79  2923  17.5  .576  .100   .385   4.9
# 6          Sergei Monia  SF  22   3     7  12.1  .347  .500  1.000   0.0
# 7      Vitaly Potapenko   C  30   9    32   8.2  .714  .000   .000   3.7
# 8          Ronnie Price  PG  22  29   150  10.5  .474  .466   .207   3.9
# 9         Jamal Sampson  PF  22  12    39  24.4  .635  .000   .286  15.2
# 10        Brian Skinner  PF  29  38   429  10.8  .544  .000   .391   8.3
# 11      Peja Stojakovic  SF  28  31  1147  13.6  .543  .422   .248   3.5
# ...

# %%
apf.head()
# Out:
#                 Player Pos Age   G    MP   PER   TS%  3PAr   FTr ORB%  \
# 0  Shareef Abdur-Rahim  PF  29  72  1961  17.2  .588  .035  .440  6.4
# 1           Mike Bibby  PG  27  82  3167  17.9  .554  .360  .292  1.1
# 2     Francisco Garcia  SF  24  67  1301  10.3  .510  .422  .311  3.5
# 3           Jason Hart  PG  27  66   818   7.1  .444  .140  .253  1.7
# 4         Kevin Martin  SG  22  72  1913  14.8  .604  .328  .407  3.6
#
#             ...            USG%   OWS  DWS   WS WS/48  OBPM  DBPM   BPM  VORP  \
# 0           ...            20.1   4.0  2.2  6.2  .152   0.4   0.4   0.9   1.4
# 1           ...            25.4   6.0  2.4  8.4  .127   3.2  -2.3   1.0   2.4
# 2           ...            15.7   0.0  1.6  1.6  .060  -2.4   1.0  -1.3   0.2
# 3           ...            16.2  -0.7  0.8  0.1  .006  -4.8  -0.7  -5.6  -0.7
# 4           ...            17.4   3.6  1.9  5.5  .137   0.8  -0.7   0.1   1.0
#
#                        TM
# 0  Sacramento Kings 05-06
# ...

# %%
t2 = apf.sort_values('MP').groupby('TM')

# %%
apf = apf[apf['Player'] != 'Player']

# %%
apf.shape
# Out:
# (6326, 26)

# %%
apf = apf.dropna()

# %%
apf.shape
# Out:
# (6289, 26)

# %%
apf.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%',
#        'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
#        'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'TM'],
#       dtype='object')

# %%
apffloats = pd.Series(['PER', 'TS%', '3PAr', 'FTr', 'ORB%',
       'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
       'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'])

# %%
afloats = apffloats.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-f05fe53675e5> in <module>
# ----> 1 afloats = apffloats.astype('float')
#
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
apf.OBPM.unique()
# Out:
# array(['0.4', '3.2', '-2.4', '-4.8', '0.8', '1.1', '-6.0', '-2.5', '1.5',
#        '-3.7', '0.9', '-1.1', '-0.4', '-5.6', '0.0', '-2.1', '2.1',
#        '-3.4', '-0.9', '3.8', '-1.7', '-23.9', '-2.2', '-0.7', '-6.6',
#        '-3.1', '-3.2', '1.9', '-3.6', '0.1', '-2.8', '-10.8', '-3.9',
#        '-2.6', '3.9', '0.7', '-0.5', '-0.2', '-10.1', '-5.3', '-3.0',
#        '2.2', '-12.2', '1.8', '-3.5', '0.3', '-5.1', '3.1', '1.4', '1.6',
#        '-15.4', '-0.8', '-4.6', '-5.2', '-6.8', '-1.0', '-7.8', '-1.8',
#        '-1.4', '-5.8', '-3.8', '-9.2', '-1.5', '-0.6', '-2.9', '0.6',
#        '-1.9', '-2.0', '-9.4', '0.5', '-1.6', '-2.3', '-4.3', '3.4',
#        '-6.4', '0.2', '2.0', '-11.1', '-4.5', '3.5', '-1.3', '2.9', '1.0',
#        '-4.2', '-7.2', '-6.7', '5.0', '-9.1', '9.4', '2.8', '-2.7', '5.8',
#        '-4.4', '-0.3', '-6.5', '-1.2', '4.5', '-10.4', '6.9', '-7.9',
#        '-4.0', '-7.7', '5.4', '-5.4', '2.3', '1.7', '6.8', '-0.1',
# ...

# %%
apf['OBPM'] = apf['OBPM'].astype('float')
apf['OBPM'] = apf['DBPM'].astype('float')

# %%
apf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6289 entries, 0 to 6598
# Data columns (total 26 columns):
# Player    6289 non-null object
# Pos       6289 non-null object
# Age       6289 non-null object
# G         6289 non-null object
# MP        6289 non-null object
# PER       6289 non-null object
# TS%       6289 non-null object
# 3PAr      6289 non-null object
# FTr       6289 non-null object
# ORB%      6289 non-null object
# DRB%      6289 non-null object
# TRB%      6289 non-null object
# AST%      6289 non-null object
# STL%      6289 non-null object
# BLK%      6289 non-null object
# TOV%      6289 non-null object
# USG%      6289 non-null object
# OWS       6289 non-null object
# DWS       6289 non-null object
# WS        6289 non-null object
# WS/48     6289 non-null object
# OBPM      6289 non-null float64
# DBPM      6289 non-null object
# BPM       6289 non-null object
# VORP      6289 non-null object
# TM        6289 non-null object
# ...
