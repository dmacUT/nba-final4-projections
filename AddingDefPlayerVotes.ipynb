# %%
import pandas as pd
import numpy as np

# %%
adt = pd.read_csv("data/Pstats - alldefteams.csv")

# %%
adv17 = {}
adv16= {}
adv15= {}
adv14= {}
adv13= {}
adv12= {}
adv11= {}
adv10= {}
adv9= {}
adv8= {}
adv7= {}
adv6= {}
adv5= {}

adl = [adv5, adv6, adv7, adv8, adv9, adv10, adv11, adv12, adv13, adv14, adv15, adv16, adv17]
len(adl)
# Out:
# 13

# %%
#add value and create dict 5-17
for i in range(0, 13):
    adl[i] = adt[adt.YR == (i+5)].drop('YR', axis = 1)
    adl[i] = {i+5:dict(zip(adl[i].Player, adl[i].Votes))}

# %%
#reverse it
adlrev = []
for i in range (12, -1, -1):
    adlrev.append(adl[i])

# %%
adlrev
# Out:
# [{17: {'Kawhi Leonard': 192,
#    'Draymond Green': 198,
#    'Rudy Gobert': 196,
#    'Patrick Beverly': 110,
#    'Chris Paul': 140,
#    'Tony Allen': 80,
#    'Danny Green': 68,
#    'Andre Roberson': 53,
#    'Anthony Davis': 58,
#    'Giannis Antetokounmpo': 35}},
#  {16: {'Kawhi Leonard': 260,
#    'Draymond Green': 251,
#    'DeAndre Jordan': 137,
#    'Avery Bradley': 149,
#    'Chris Paul': 148,
#    'Paul Millsap': 97,
#    'Paul George': 48,
#    'Hassan Whiteside': 126,
#    'Tony Allen': 121,
#    'Jimmy Butler': 62}},
#  {15: {'Kawhi Leonard': 242,
#    'Draymond Green': 229,
#    'Tony Allen': 207,
#    'DeAndre Jordan': 187,
#    'Chris Paul': 170,
#    'Anthony Davis': 155,
#    'Jimmy Butler': 132,
#    'Andrew Bogut': 102,
#    'John Wall': 67,
#    'Tim Duncan': 64}},
#  {14: {'Joakim Noah': 223,
#    'Paul George': 161,
#    'Chris Paul': 156,
#    'Serge Ibaka': 152,
#    'Andre Igoudala': 148,
#    'Lebron James': 134,
#    'Patrick Beverly': 112,
#    'Jimmy Butler': 103,
#    'Kawhi Leonard': 89,
#    'Roy Hibbert': 76}},
#  {13: {'Tony Allen': 53,
#    'Serge Ibaka': 46,
#    'Lebron James': 52,
#    'Chris Paul': 37,
#    'Joakim Noah': 24,
#    'Tyson Chandler': 24,
#    'Avery Bradley': 25,
#    'Mike Conley': 19,
#    'Tim Duncan': 20,
#    'Marc Gasol': 12,
#    'Paul George': 27}},
#  {12: {'Tony Allen': 33,
#    'Dwight Howard': 41,
#    'Serge Ibaka': 47,
#    'Lebron James': 53,
#    'Chris Paul': 35,
#    'Kobe Bryant': 17,
#    'Tyson Chandler': 36,
#    'Luol Deng': 20,
#    'Kevin Garnett': 26,
#    'Rajon Rondo': 29}},
#  {11: {'Kobe Bryant': 33,
#    'Kevin Garnett': 33,
#    'Dwight Howard': 56,
#    'Lebron James': 38,
#    'Rajon Rondo': 39,
#    'Tony Allen': 23,
#    'Tyson Chandler': 17,
#    'Andre Igoudala': 15,
#    'Joakim Noah': 15,
#    'Chis Paul': 18}},
#  {10: {'Kobe Bryant': 34,
#    'Dwight Howard': 57,
#    'Lebron James': 45,
#    'Rajon Rondo': 50,
#    'Gerald Wallace': 30,
#    'Tim Duncan': 21,
#    'Thabo Sefolosha': 14,
#    'Josh Smith': 20,
#    'Anderson Varejao': 15,
#    'Dwyane Wade': 20}},
#  {9: {'Kobe Bryant': 53,
#    'Kevin Garnett': 35,
#    'Dwight Howard': 55,
#    'Lebron James': 47,
#    'Chris Paul': 36,
#    'Metta World Peace': 22,
#    'Shane Battier': 22,
#    'Tim Duncan': 30,
#    'Rajon Rondo': 23,
#    'Dwyane Wade': 26}},
#  {8: {'Bruce Bowen': 36,
#    'Kobe Bryant': 52,
#    'Marcus Camby': 37,
#    'Tim Duncan': 33,
#    'Kevin Garnett': 52,
#    'Shane Battier': 29,
#    'Raja Bell': 18,
#    'Dwight Howard': 25,
#    'Chris Paul': 26,
#    'Tayshaun Prince': 20}},
#  {7: {'Raja Bell': 25,
#    'Bruce Bowen': 42,
#    'Kobe Bryant': 32,
#    'Marcus Camby': 34,
#    'Tim Duncan': 36,
#    'Kevin Garnett': 20,
#    'Kirk Hinrich': 18,
#    'Jason Kidd': 23,
#    'Tayshaun Prince': 21,
#    'Ben Wallace': 33}},
#  {6: {'Metta World Peace': 30,
#    'Bruce Bowen': 55,
#    'Andrei Kirlienko': 44,
#    'Kobe Bryant': 28,
#    'Ben Wallace': 54,
#    'Jason Kidd': 28,
#    'Chauncey Billups': 23,
#    'Marcus Camby': 15,
#    'Tim Duncan': 23,
#    'Kevin Garnett': 18,
#    'Tayshaun Prince': 13}},
#  {5: {'Ben Wallace': 51,
#    'Kevin Garnett': 48,
#    'Bruce Bowen': 48,
#    'Tim Duncan': 39,
#    'Larry Hughes': 22,
#    'Tayshaun Prince': 21,
#    'Marcus Camby': 21,
#    'Chauncey Billups': 17,
#    'Andrei Kirlienko': 17,
#    'Jason Kidd': 16,
#    'Dwyane Wade': 16}}]

# %%
#divide latest 4 yrs by 4
for i in range(0,4):
    for k, v in adlrev[i].items():
        for key, val in adlrev[i][k].items():
            adlrev[i][k][key] = adlrev[i][k][key]/4

# %%
z

# %%
adlrev
# Out:
# [{17: {'Kawhi Leonard': 48.0,
#    'Draymond Green': 49.5,
#    'Rudy Gobert': 49.0,
#    'Patrick Beverly': 27.5,
#    'Chris Paul': 35.0,
#    'Tony Allen': 20.0,
#    'Danny Green': 17.0,
#    'Andre Roberson': 13.25,
#    'Anthony Davis': 14.5,
#    'Giannis Antetokounmpo': 8.75}},
#  {16: {'Kawhi Leonard': 65.0,
#    'Draymond Green': 62.75,
#    'DeAndre Jordan': 34.25,
#    'Avery Bradley': 37.25,
#    'Chris Paul': 37.0,
#    'Paul Millsap': 24.25,
#    'Paul George': 12.0,
#    'Hassan Whiteside': 31.5,
#    'Tony Allen': 30.25,
#    'Jimmy Butler': 15.5}},
#  {15: {'Kawhi Leonard': 60.5,
#    'Draymond Green': 57.25,
#    'Tony Allen': 51.75,
#    'DeAndre Jordan': 46.75,
#    'Chris Paul': 42.5,
#    'Anthony Davis': 38.75,
#    'Jimmy Butler': 33.0,
#    'Andrew Bogut': 25.5,
#    'John Wall': 16.75,
#    'Tim Duncan': 16.0}},
#  {14: {'Joakim Noah': 55.75,
#    'Paul George': 40.25,
#    'Chris Paul': 39.0,
#    'Serge Ibaka': 38.0,
#    'Andre Igoudala': 37.0,
#    'Lebron James': 33.5,
#    'Patrick Beverly': 28.0,
#    'Jimmy Butler': 25.75,
#    'Kawhi Leonard': 22.25,
#    'Roy Hibbert': 19.0}},
#  {13: {'Tony Allen': 53,
#    'Serge Ibaka': 46,
#    'Lebron James': 52,
#    'Chris Paul': 37,
#    'Joakim Noah': 24,
#    'Tyson Chandler': 24,
#    'Avery Bradley': 25,
#    'Mike Conley': 19,
#    'Tim Duncan': 20,
#    'Marc Gasol': 12,
#    'Paul George': 27}},
#  {12: {'Tony Allen': 33,
#    'Dwight Howard': 41,
#    'Serge Ibaka': 47,
#    'Lebron James': 53,
#    'Chris Paul': 35,
#    'Kobe Bryant': 17,
#    'Tyson Chandler': 36,
#    'Luol Deng': 20,
#    'Kevin Garnett': 26,
#    'Rajon Rondo': 29}},
#  {11: {'Kobe Bryant': 33,
#    'Kevin Garnett': 33,
#    'Dwight Howard': 56,
#    'Lebron James': 38,
#    'Rajon Rondo': 39,
#    'Tony Allen': 23,
#    'Tyson Chandler': 17,
#    'Andre Igoudala': 15,
#    'Joakim Noah': 15,
#    'Chis Paul': 18}},
#  {10: {'Kobe Bryant': 34,
#    'Dwight Howard': 57,
#    'Lebron James': 45,
#    'Rajon Rondo': 50,
#    'Gerald Wallace': 30,
#    'Tim Duncan': 21,
#    'Thabo Sefolosha': 14,
#    'Josh Smith': 20,
#    'Anderson Varejao': 15,
#    'Dwyane Wade': 20}},
#  {9: {'Kobe Bryant': 53,
#    'Kevin Garnett': 35,
#    'Dwight Howard': 55,
#    'Lebron James': 47,
#    'Chris Paul': 36,
#    'Metta World Peace': 22,
#    'Shane Battier': 22,
#    'Tim Duncan': 30,
#    'Rajon Rondo': 23,
#    'Dwyane Wade': 26}},
#  {8: {'Bruce Bowen': 36,
#    'Kobe Bryant': 52,
#    'Marcus Camby': 37,
#    'Tim Duncan': 33,
#    'Kevin Garnett': 52,
#    'Shane Battier': 29,
#    'Raja Bell': 18,
#    'Dwight Howard': 25,
#    'Chris Paul': 26,
#    'Tayshaun Prince': 20}},
#  {7: {'Raja Bell': 25,
#    'Bruce Bowen': 42,
#    'Kobe Bryant': 32,
#    'Marcus Camby': 34,
#    'Tim Duncan': 36,
#    'Kevin Garnett': 20,
#    'Kirk Hinrich': 18,
#    'Jason Kidd': 23,
#    'Tayshaun Prince': 21,
#    'Ben Wallace': 33}},
#  {6: {'Metta World Peace': 30,
#    'Bruce Bowen': 55,
#    'Andrei Kirlienko': 44,
#    'Kobe Bryant': 28,
#    'Ben Wallace': 54,
#    'Jason Kidd': 28,
#    'Chauncey Billups': 23,
#    'Marcus Camby': 15,
#    'Tim Duncan': 23,
#    'Kevin Garnett': 18,
#    'Tayshaun Prince': 13}},
#  {5: {'Ben Wallace': 51,
#    'Kevin Garnett': 48,
#    'Bruce Bowen': 48,
#    'Tim Duncan': 39,
#    'Larry Hughes': 22,
#    'Tayshaun Prince': 21,
#    'Marcus Camby': 21,
#    'Chauncey Billups': 17,
#    'Andrei Kirlienko': 17,
#    'Jason Kidd': 16,
#    'Dwyane Wade': 16}}]

# %%
# %run alldeflists

# %%
type(advotes)
# Out:
# list

# %%
advotes[3]
# Out:
# 'DeAndre Jordan, L.A. Clippers, 63 (14); Anthony Davis, New Orleans, 62 (18); Tony Allen, Memphis, 60 (17); Tim Duncan, San Antonio, 45 (12); Dwight Howard, Houston, 26 (6); Taj Gibson, Chicago, 21 (2); Mike Conley, Memphis, 21 (5); Ricky Rubio, Minnesota, 19 (5); Lance Stephenson, Indiana, 14 (3); P.J. Tucker, Phoenix, 13 (2); Kevin Durant, Oklahoma City, 10 (2); Kyle Lowry, Toronto, 10 (3); Eric Bledsoe, Phoenix, 9 (1); Marc Gasol, Memphis, 8; John Wall, Washington, 8 (1); Thabo Sefolosha, Oklahoma City, 8 (1); Kirk Hinrich, Chicago, 7 (2); Trevor Ariza, Washington, 5 (2); Avery Bradley, Boston, 5 (1); Russell Westbrook, Oklahoma City, 5 (1); Klay Thompson, Golden State, 5; Andrew Bogut, Golden State, 4; Chris Bosh, Miami, 4 (1); Luol Deng, Cleveland, 4 (1); Wesley Matthews, Portland, 4 (1); Tony Parker, San Antonio, 4 (1); Nicolas Batum, Portland, 3 (1); Stephen Curry, Golden State, 3 (1); Danny Green, San Antonio, 3 (1); Michael Kidd-Gilchrist, Charlotte, 3; Shaun Livingston, Brooklyn, 3 (1); Victor Oladipo, Orlando, 3 (1); DeMarre Carroll, Atlanta, 2; Matt Barnes, L.A. Clippers, 2 (1); James Harden, Houston, 2; George Hill, Indiana, 2; Jeff Teague, Atlanta, 2; Dwyane Wade, Miami, 2 (1); Kemba Walker, Charlotte, 2; David West, Indiana, 2; Arron Afflalo, Orlando, 1; Corey Brewer, Minnesota, 1; Michael Carter-Williams, Philadelphia, 1; Darren Collison, L.A. Clippers, 1; DeMar DeRozan, Toronto, 1; Andre Drummond, Detroit, 1; Monta Ellis, Dallas, 1; Danny Granger, L.A. Clippers, 1; Draymond Green, Golden State, 1; Reggie Jackson, Oklahoma City, 1; David Lee, Golden State, 1; Paul Millsap, Atlanta, 1; Rajon Rondo, Boston, 1'

# %%
def text_to_votes(test):
    tl = test.split(";")
    tl = [i.split(",") for i in tl]
    tldict = {i[0].lstrip(): int(i[2].split()[0]) for i in tl}
    return tldict

# %%
adv_dict = []
for i in range(len(advotes)):
    adv_dict.append(text_to_votes(advotes[i]))

# %%
for i in adv_dict:
    for k, v in i.items():
        k = k.lstrip()

# %%
adv_dict
# Out:
# [{'Avery Bradley': 46,
#   'Klay Thompson': 45,
#   'John Wall': 38,
#   'DeAndre Jordan': 35,
#   'Paul Millsap': 35,
#   'Hassan Whiteside': 25,
#   'Marcus Smart': 21,
#   'Jimmy Butler': 18,
#   'LeBron James': 12,
#   'Robert Covington': 11,
#   'Russell Westbrook': 10,
#   'Paul George': 7,
#   'Kevin Durant': 6,
#   'Dwight Howard': 6,
#   'Mike Conley': 5,
#   'Jae Crowder': 5,
#   'Jrue Holiday': 5,
#   'Wesley Matthews': 4,
#   'Stephen Curry': 3,
#   'Andre Iguodala': 3,
#   'Michael Kidd-Gilchrist': 3,
#   'Ricky Rubio': 3,
#   'P.J. Tucker': 3,
#   'Trevor Ariza': 2,
#   'Nicolas Batum': 2,
#   'Marc Gasol': 2,
#   'Eric Gordon': 2,
#   'Karl-Anthony Towns': 2,
#   'Steven Adams': 1,
#   'LaMarcus Aldridge': 1,
#   'Al-Farouq Aminu': 1,
#   'Kentavious Caldwell-Pope': 1,
#   'George Hill': 1,
#   'Serge Ibaka': 1,
#   'Damian Lillard': 1,
#   'Luc Mbah a Moute': 1,
#   'Austin Rivers': 1,
#   'Isaiah Thomas': 1,
#   'Cody Zeller': 1},
#  {'Rudy Gobert': 64,
#   'Klay Thompson': 49,
#   'Jae Crowder': 47,
#   'LeBron James': 43,
#   'Kyle Lowry': 43,
#   'Danny Green': 39,
#   'Russell Westbrook': 35,
#   'Tim Duncan': 33,
#   'Ricky Rubio': 30,
#   'Kentavious Caldwell-Pope': 27,
#   'Anthony Davis': 24,
#   'Andre Drummond': 14,
#   'Serge Ibaka': 14,
#   'Stephen Curry': 13,
#   'Andre Iguodala': 13,
#   'Patrick Beverley': 11,
#   'Al Horford': 7,
#   'Marcus Smart': 7,
#   'John Wall': 6,
#   'Giannis Antetokounmpo': 3,
#   'Trevor Ariza': 3,
#   'Kent Bazemore': 3,
#   'Andrew Bogut': 3,
#   'DeMarcus Cousins': 3,
#   'Nicolas Batum': 2,
#   'Victor Oladipo': 2,
#   'LaMarcus Aldridge': 1,
#   'Harrison Barnes': 1,
#   'Bismack Biyombo': 1,
#   'Mike Conley': 1,
#   'Kevin Durant': 1,
#   'Derrick Favors': 1,
#   'George Hill': 1,
#   'Wesley Matthews': 1,
#   'Luc Mbah a Moute': 1,
#   'Kristaps Porzingis': 1,
#   'Andre Roberson': 1,
#   'Mike Scott': 1,
#   'Dwyane Wade': 1},
#  {'Rudy Gobert': 54,
#   'LeBron James': 47,
#   'Russell Westbrook': 35,
#   'Avery Bradley': 26,
#   'Michael Kidd-Gilchrist': 21,
#   'Marc Gasol': 18,
#   'Danny Green': 18,
#   'Trevor Ariza': 17,
#   'Stephen Curry': 14,
#   'DeMarre Carroll': 11,
#   'Patrick Beverley': 10,
#   'Khris Middleton': 9,
#   'Serge Ibaka': 8,
#   'Andre Iguodala': 8,
#   'Paul Millsap': 8,
#   'Jeff Teague': 7,
#   'Mike Conley': 6,
#   'Joakim Noah': 6,
#   'Nerlens Noel': 5,
#   'P.J. Tucker': 4,
#   'Giannis Antetokounmpo': 3,
#   'Pau Gasol': 3,
#   'Wesley Matthews': 3,
#   'James Harden': 2,
#   'Marcus Smart': 2,
#   'Hassan Whiteside': 2,
#   'Eric Bledsoe': 1,
#   'DeMarcus Cousins': 1,
#   'Andre Drummond': 1,
#   'Manu Ginobili': 1,
#   'Blake Griffin': 1,
#   'George Hill': 1,
#   'Al Horford': 1,
#   'Victor Oladipo': 1,
#   'Zaza Pachulia': 1,
#   'Elfrid Payton': 1,
#   'Zach Randolph': 1,
#   'Rajon Rondo': 1,
#   'Iman Shumpert': 1,
#   'Dwyane Wade': 1},
#  {'DeAndre Jordan': 63,
#   'Anthony Davis': 62,
#   'Tony Allen': 60,
#   'Tim Duncan': 45,
#   'Dwight Howard': 26,
#   'Taj Gibson': 21,
#   'Mike Conley': 21,
#   'Ricky Rubio': 19,
#   'Lance Stephenson': 14,
#   'P.J. Tucker': 13,
#   'Kevin Durant': 10,
#   'Kyle Lowry': 10,
#   'Eric Bledsoe': 9,
#   'Marc Gasol': 8,
#   'John Wall': 8,
#   'Thabo Sefolosha': 8,
#   'Kirk Hinrich': 7,
#   'Trevor Ariza': 5,
#   'Avery Bradley': 5,
#   'Russell Westbrook': 5,
#   'Klay Thompson': 5,
#   'Andrew Bogut': 4,
#   'Chris Bosh': 4,
#   'Luol Deng': 4,
#   'Wesley Matthews': 4,
#   'Tony Parker': 4,
#   'Nicolas Batum': 3,
#   'Stephen Curry': 3,
#   'Danny Green': 3,
#   'Michael Kidd-Gilchrist': 3,
#   'Shaun Livingston': 3,
#   'Victor Oladipo': 3,
#   'DeMarre Carroll': 2,
#   'Matt Barnes': 2,
#   'James Harden': 2,
#   'George Hill': 2,
#   'Jeff Teague': 2,
#   'Dwyane Wade': 2,
#   'Kemba Walker': 2,
#   'David West': 2,
#   'Arron Afflalo': 1,
#   'Corey Brewer': 1,
#   'Michael Carter-Williams': 1,
#   'Darren Collison': 1,
#   'DeMar DeRozan': 1,
#   'Andre Drummond': 1,
#   'Monta Ellis': 1,
#   'Danny Granger': 1,
#   'Draymond Green': 1,
#   'Reggie Jackson': 1,
#   'David Lee': 1,
#   'Paul Millsap': 1,
#   'Rajon Rondo': 1},
#  {'Andre Iguodala': 16,
#   'Larry Sanders': 16,
#   'Thabo Sefolosha': 15,
#   'Luol Deng': 11,
#   'Dwight Howard': 9,
#   'Kobe Bryant': 6,
#   'Roy Hibbert': 6,
#   'Kenneth Faried': 4,
#   'Russell Westbrook': 4,
#   'Shane Battier': 2,
#   'Nicolas Batum': 2,
#   'Corey Brewer': 2,
#   'George Hill': 2,
#   'Mike James': 2,
#   'Kawhi Leonard': 2,
#   'Tony Parker': 2,
#   'Dwyane Wade': 2,
#   'Metta World Peace': 2,
#   'Eric Bledsoe': 1,
#   'Kevin Durant': 1,
#   'Jrue Holiday': 1,
#   'Andrei Kirilenko': 1,
#   'Iman Shumpert': 1,
#   'David West': 1},
#  {'Andre Iguodala': 19,
#   'Joakim Noah': 14,
#   'Iman Shumpert': 13,
#   'Paul George': 10,
#   'Russell Westbrook': 9,
#   'Josh Smith': 8,
#   'Dwyane Wade': 5,
#   'Thabo Sefolosha': 5,
#   'Grant Hill': 5,
#   'Tim Duncan': 5,
#   'Avery Bradley': 3,
#   'Marc Gasol': 3,
#   'Metta World Peace': 3,
#   'Shawn Marion': 3,
#   'Joe Johnson': 2,
#   'Mike Conley': 2,
#   'Derrick Rose': 1,
#   'Jrue Holiday': 1,
#   'Carlos Boozer': 1,
#   'Luc Mbah a Moute': 1},
#  {'Derrick Rose': 14,
#   'Dwyane Wade': 13,
#   'Russell Westbrook': 13,
#   'Gerald Wallace': 11,
#   'Grant Hill': 11,
#   'Luol Deng': 11,
#   'Tim Duncan': 11,
#   'Chuck Hayes': 10,
#   'Al Horford': 7,
#   'Josh Smith': 7,
#   'Ron Artest': 7,
#   'Serge Ibaka': 6,
#   'Shane Battier': 5,
#   'Thabo Sefolosha': 5,
#   'Wesley Matthews': 4,
#   'Kendrick Perkins': 3,
#   'Nicolas Batum': 3,
#   'Joe Johnson': 2,
#   'Keith Bogans': 2,
#   'Kyle Lowry': 2,
#   'Lamar Odom': 2,
#   'Luc Mbah a Moute': 2,
#   'Manu Ginobili': 2,
#   'Andrew Bogut': 1,
#   'Andrew Bynum': 1,
#   'Arron Afflalo': 1,
#   'Jrue Holiday': 1,
#   'Kirk Hinrich': 1,
#   'Nene Hilario': 1,
#   'Ronnie Brewer': 1,
#   'Shawn Marion': 1,
#   'Tayshaun Prince': 1},
#  {'Jason Kidd': 12,
#   'Marcus Camby': 12,
#   'Ron Artest': 11,
#   'Deron Williams': 10,
#   'Kirk Hinrich': 9,
#   'Andrew Bogut': 8,
#   'Luc Mbah a Moute': 8,
#   'Arron Afflalo': 6,
#   'Kenyon Martin': 5,
#   'Kevin Garnett': 5,
#   'Grant Hill': 4,
#   'Joakim Noah': 4,
#   'Kendrick Perkins': 4,
#   'Shane Battier': 4,
#   'Andrei Kirilenko': 3,
#   'Russell Westbrook': 3,
#   'Trevor Ariza': 3,
#   'Andre Iguodala': 2,
#   'George Hill': 2,
#   'Jermaine O’Neal': 2,
#   'Joe Johnson': 2,
#   'Lamar Odom': 2,
#   'Luis Scola': 2,
#   'Manu Ginobili': 2,
#   'Nicolas Batum': 2,
#   'Caron Butler': 1,
#   'Chauncey Billups': 1,
#   'Jared Dudley': 1,
#   'Kevin Durant': 1,
#   'Raymond Felton': 1,
#   'Marc Gasol': 1,
#   'Pau Gasol': 1,
#   'Chuck Hayes': 1,
#   'Brendan Haywood': 1,
#   'Al Horford': 1,
#   'Serge Ibaka': 1,
#   'Ersan Ilyasova': 1,
#   'Stephen Jackson': 1,
#   'Nene Hilario': 1,
#   'Chris Paul': 1,
#   'Tayshaun Prince': 1,
#   'Earl Watson': 1},
#  {'Tayshaun Prince': 15,
#   'Raja Bell': 8,
#   'Joel Przybilla': 7,
#   'Chauncey Billups': 5,
#   'Ronnie Brewer': 5,
#   'Andre Iguodala': 5,
#   'Yao Ming': 5,
#   'Emeka Okafor': 5,
#   'Kendrick Perkins': 4,
#   'Samuel Dalembert': 3,
#   'Derek Fisher': 3,
#   'Udonis Haslem': 3,
#   'Jason Kidd': 3,
#   'Anderson Varejao': 3,
#   'Deron Williams': 3,
#   'Trevor Ariza': 2,
#   'Kirk Hinrich': 2,
#   'Joe Johnson': 2,
#   'Andrei Kirilenko': 2,
#   'David Lee': 2,
#   'James Posey': 2,
#   'J.R. Smith': 2,
#   'Gerald Wallace': 2,
#   'NenFe': 1,
#   'Chris Andersen': 1,
#   'Pau Gasol': 1,
#   'Antonio McDyess': 1,
#   'Andre Miller': 1,
#   'Travis Outlaw': 1,
#   'Brandon Roy': 1,
#   'Rasheed Wallace': 1},
#  {'Chauncey Billups': 14,
#   'Jason Kidd': 13,
#   'Rasheed Wallace': 13,
#   'Rajon Rondo': 11,
#   'Deron Williams': 8,
#   'Josh Smith': 8,
#   'Ron Artest': 8,
#   'Tyson Chandler': 8,
#   'Andrei Kirilenko': 6,
#   'Derek Fisher': 4,
#   'LeBron James': 4,
#   'Manu Ginobili': 4,
#   'Kirk Hinrich': 3,
#   'Samuel Dalembert': 3,
#   'Andre Iguodala': 2,
#   'Brandon Roy': 2,
#   'Paul Pierce': 2,
#   'Andre Miller': 1,
#   'Andres Nocioni': 1,
#   'Baron Davis': 1,
#   'Caron Butler': 1,
#   'Chris Bosh': 1,
#   'Dikembe Mutombo': 1,
#   'Josh Howard': 1,
#   'Richard Hamilton': 1,
#   'Ronnie Brewer': 1},
#  {'Shane Battier': 17,
#   'Shawn Marion': 15,
#   'Chauncey Billups': 13,
#   'Ron Artest': 12,
#   'Gerald Wallace': 11,
#   'Alonzo Mourning': 9,
#   'Devin Harris': 8,
#   'Tyson Chandler': 8,
#   'Josh Howard': 7,
#   'Emeka Okafor': 6,
#   'Luol Deng': 5,
#   'Rasheed Wallace': 5,
#   'Dwight Howard': 5,
#   'Andrei Kirilenko': 5,
#   'Josh Smith': 4,
#   'Manu Ginobili': 4,
#   'Richard Hamilton': 3,
#   'Jermaine O’Neal': 3,
#   'Andre Iguodala': 3,
#   'Deron Williams': 3,
#   'Elton Brand': 2,
#   'Dwyane Wade': 2,
#   'Trenton Hassell': 2,
#   'Tony Parker': 2,
#   'Caron Butler': 2,
#   'Chris Duhon': 1,
#   'Allen Iverson': 1,
#   'Udonis Haslem': 1,
#   'Richard Jefferson': 1,
#   'Chris Paul': 1,
#   'Andre Miller': 1,
#   'Joel Przybilla': 1,
#   'Francisco Elson': 1,
#   'Chris Bosh': 1,
#   'Gilbert Arenas': 1},
#  {'Rasheed Wallace': 12,
#   'Gerald Wallace': 11,
#   'Shawn Marion': 11,
#   'Raja Bell': 9,
#   'Dwyane Wade': 8,
#   'Kirk Hinrich': 7,
#   'Alonzo Mourning': 7,
#   'Shane Battier': 6,
#   'Gilbert Arenas': 4,
#   'Andre Iguodala': 4,
#   'P.J. Brown': 3,
#   'Manu Ginobili': 3,
#   'Dwight Howard': 3,
#   'Josh Howard': 3,
#   'Brevin Knight': 3,
#   'Shaquille O’Neal': 3,
#   'Elton Brand': 2,
#   'LeBron James': 2,
#   'Tony Parker': 2,
#   'Quinton Ross': 2,
#   'Allen Iverson': 2,
#   'Eddie Jones': 2,
#   'Jason Collins': 1,
#   'Boris Diaw': 1,
#   'Pau Gasol': 1,
#   'Trenton Hassel': 1,
#   'Mike James': 1,
#   'Richard Jefferson': 1,
#   'Ruben Patterson': 1,
#   'Chris Paul': 1,
#   'Jason Terry': 1,
#   'Yao Ming': 1},
#  {'Shaquille O’Neal': 16,
#   'Allen Iverson': 14,
#   'Kobe Bryant': 12,
#   'Shawn Marion': 9,
#   'Manu Ginobili': 9,
#   'Rasheed Wallace': 8,
#   'Kenyon Martin': 6,
#   'Tony Parker': 5,
#   'Andre Iguodala': 5,
#   'Shane Battier': 4,
#   'Andre Miller': 4,
#   'Tyson Chandler': 3,
#   'Trenton Hassell': 3,
#   'Kirk Hinrich': 3,
#   'Joe Johnson': 3,
#   'Earl Watson': 3,
#   'Udonis Haslem': 2,
#   'Tracy McGrady': 2,
#   'Josh Howard': 2,
#   'Joel Przybilla': 2,
#   'Desmond Mason': 2,
#   'Brevin Knight': 2,
#   'Vince Carter': 1,
#   'P.J. Brown': 1,
#   'Mickael Pietrus': 1,
#   'Kurt Thomas': 1,
#   'Jeff Foster': 1,
#   'Greg Buckner': 1,
#   'Gilbert Arenas': 1,
#   'Gary Payton': 1,
#   'Emeka Okafor': 1,
#   'Eddie Jones': 1,
#   'Clifford Robinson': 1,
#   'Brendan Haywood': 1,
#   'Anthony Johnson': 1,
#   'Andres Nocioni': 1,
#   'Amaré Stoudemire': 1}]

# %%
yr17
# Out:
# {'Avery Bradley': 46,
#  ' Klay Thompson': 45,
#  ' John Wall': 38,
#  ' DeAndre Jordan': 35,
#  ' Paul Millsap': 35,
#  ' Hassan Whiteside': 25,
#  ' Marcus Smart': 21,
#  ' Jimmy Butler': 18,
#  ' LeBron James': 12,
#  ' Robert Covington': 11,
#  ' Russell Westbrook': 10,
#  ' Paul George': 7,
#  ' Kevin Durant': 6,
#  ' Dwight Howard': 6,
#  ' Mike Conley': 5,
#  ' Jae Crowder': 5,
#  ' Jrue Holiday': 5,
#  ' Wesley Matthews': 4,
#  ' Stephen Curry': 3,
#  ' Andre Iguodala': 3,
#  ' Michael Kidd-Gilchrist': 3,
#  ' Ricky Rubio': 3,
#  ' P.J. Tucker': 3,
#  ' Trevor Ariza': 2,
#  ' Nicolas Batum': 2,
#  ' Marc Gasol': 2,
#  ' Eric Gordon': 2,
#  ' Karl-Anthony Towns': 2,
#  ' Steven Adams': 1,
#  ' LaMarcus Aldridge': 1,
#  ' Al-Farouq Aminu': 1,
#  ' Kentavious Caldwell-Pope': 1,
#  ' George Hill': 1,
#  ' Serge Ibaka': 1,
#  ' Damian Lillard': 1,
#  ' Luc Mbah a Moute': 1,
#  ' Austin Rivers': 1,
#  ' Isaiah Thomas': 1,
#  ' Cody Zeller': 1}

# %%
#adding year
yr = 17
for i in range(0, 13):
    adv_dict[i] = {yr:adv_dict[i]}
    yr -= 1

# %%
adv_dict
# Out:
# [{17: {'Avery Bradley': 46,
#    'Klay Thompson': 45,
#    'John Wall': 38,
#    'DeAndre Jordan': 35,
#    'Paul Millsap': 35,
#    'Hassan Whiteside': 25,
#    'Marcus Smart': 21,
#    'Jimmy Butler': 18,
#    'LeBron James': 12,
#    'Robert Covington': 11,
#    'Russell Westbrook': 10,
#    'Paul George': 7,
#    'Kevin Durant': 6,
#    'Dwight Howard': 6,
#    'Mike Conley': 5,
#    'Jae Crowder': 5,
#    'Jrue Holiday': 5,
#    'Wesley Matthews': 4,
#    'Stephen Curry': 3,
#    'Andre Iguodala': 3,
#    'Michael Kidd-Gilchrist': 3,
#    'Ricky Rubio': 3,
#    'P.J. Tucker': 3,
#    'Trevor Ariza': 2,
#    'Nicolas Batum': 2,
#    'Marc Gasol': 2,
#    'Eric Gordon': 2,
#    'Karl-Anthony Towns': 2,
#    'Steven Adams': 1,
#    'LaMarcus Aldridge': 1,
#    'Al-Farouq Aminu': 1,
#    'Kentavious Caldwell-Pope': 1,
#    'George Hill': 1,
#    'Serge Ibaka': 1,
#    'Damian Lillard': 1,
#    'Luc Mbah a Moute': 1,
#    'Austin Rivers': 1,
#    'Isaiah Thomas': 1,
#    'Cody Zeller': 1}},
#  {16: {'Rudy Gobert': 64,
#    'Klay Thompson': 49,
#    'Jae Crowder': 47,
#    'LeBron James': 43,
#    'Kyle Lowry': 43,
#    'Danny Green': 39,
#    'Russell Westbrook': 35,
#    'Tim Duncan': 33,
#    'Ricky Rubio': 30,
#    'Kentavious Caldwell-Pope': 27,
#    'Anthony Davis': 24,
#    'Andre Drummond': 14,
#    'Serge Ibaka': 14,
#    'Stephen Curry': 13,
#    'Andre Iguodala': 13,
#    'Patrick Beverley': 11,
#    'Al Horford': 7,
#    'Marcus Smart': 7,
#    'John Wall': 6,
#    'Giannis Antetokounmpo': 3,
#    'Trevor Ariza': 3,
#    'Kent Bazemore': 3,
#    'Andrew Bogut': 3,
#    'DeMarcus Cousins': 3,
#    'Nicolas Batum': 2,
#    'Victor Oladipo': 2,
#    'LaMarcus Aldridge': 1,
#    'Harrison Barnes': 1,
#    'Bismack Biyombo': 1,
#    'Mike Conley': 1,
#    'Kevin Durant': 1,
#    'Derrick Favors': 1,
#    'George Hill': 1,
#    'Wesley Matthews': 1,
#    'Luc Mbah a Moute': 1,
#    'Kristaps Porzingis': 1,
#    'Andre Roberson': 1,
#    'Mike Scott': 1,
#    'Dwyane Wade': 1}},
#  {15: {'Rudy Gobert': 54,
#    'LeBron James': 47,
#    'Russell Westbrook': 35,
#    'Avery Bradley': 26,
#    'Michael Kidd-Gilchrist': 21,
#    'Marc Gasol': 18,
#    'Danny Green': 18,
#    'Trevor Ariza': 17,
#    'Stephen Curry': 14,
#    'DeMarre Carroll': 11,
#    'Patrick Beverley': 10,
#    'Khris Middleton': 9,
#    'Serge Ibaka': 8,
#    'Andre Iguodala': 8,
#    'Paul Millsap': 8,
#    'Jeff Teague': 7,
#    'Mike Conley': 6,
#    'Joakim Noah': 6,
#    'Nerlens Noel': 5,
#    'P.J. Tucker': 4,
#    'Giannis Antetokounmpo': 3,
#    'Pau Gasol': 3,
#    'Wesley Matthews': 3,
#    'James Harden': 2,
#    'Marcus Smart': 2,
#    'Hassan Whiteside': 2,
#    'Eric Bledsoe': 1,
#    'DeMarcus Cousins': 1,
#    'Andre Drummond': 1,
#    'Manu Ginobili': 1,
#    'Blake Griffin': 1,
#    'George Hill': 1,
#    'Al Horford': 1,
#    'Victor Oladipo': 1,
#    'Zaza Pachulia': 1,
#    'Elfrid Payton': 1,
#    'Zach Randolph': 1,
#    'Rajon Rondo': 1,
#    'Iman Shumpert': 1,
#    'Dwyane Wade': 1}},
#  {14: {'DeAndre Jordan': 63,
#    'Anthony Davis': 62,
#    'Tony Allen': 60,
#    'Tim Duncan': 45,
#    'Dwight Howard': 26,
#    'Taj Gibson': 21,
#    'Mike Conley': 21,
#    'Ricky Rubio': 19,
#    'Lance Stephenson': 14,
#    'P.J. Tucker': 13,
#    'Kevin Durant': 10,
#    'Kyle Lowry': 10,
#    'Eric Bledsoe': 9,
#    'Marc Gasol': 8,
#    'John Wall': 8,
#    'Thabo Sefolosha': 8,
#    'Kirk Hinrich': 7,
#    'Trevor Ariza': 5,
#    'Avery Bradley': 5,
#    'Russell Westbrook': 5,
#    'Klay Thompson': 5,
#    'Andrew Bogut': 4,
#    'Chris Bosh': 4,
#    'Luol Deng': 4,
#    'Wesley Matthews': 4,
#    'Tony Parker': 4,
#    'Nicolas Batum': 3,
#    'Stephen Curry': 3,
#    'Danny Green': 3,
#    'Michael Kidd-Gilchrist': 3,
#    'Shaun Livingston': 3,
#    'Victor Oladipo': 3,
#    'DeMarre Carroll': 2,
#    'Matt Barnes': 2,
#    'James Harden': 2,
#    'George Hill': 2,
#    'Jeff Teague': 2,
#    'Dwyane Wade': 2,
#    'Kemba Walker': 2,
#    'David West': 2,
#    'Arron Afflalo': 1,
#    'Corey Brewer': 1,
#    'Michael Carter-Williams': 1,
#    'Darren Collison': 1,
#    'DeMar DeRozan': 1,
#    'Andre Drummond': 1,
#    'Monta Ellis': 1,
#    'Danny Granger': 1,
#    'Draymond Green': 1,
#    'Reggie Jackson': 1,
#    'David Lee': 1,
#    'Paul Millsap': 1,
#    'Rajon Rondo': 1}},
#  {13: {'Andre Iguodala': 16,
#    'Larry Sanders': 16,
#    'Thabo Sefolosha': 15,
#    'Luol Deng': 11,
#    'Dwight Howard': 9,
#    'Kobe Bryant': 6,
#    'Roy Hibbert': 6,
#    'Kenneth Faried': 4,
#    'Russell Westbrook': 4,
#    'Shane Battier': 2,
#    'Nicolas Batum': 2,
#    'Corey Brewer': 2,
#    'George Hill': 2,
#    'Mike James': 2,
#    'Kawhi Leonard': 2,
#    'Tony Parker': 2,
#    'Dwyane Wade': 2,
#    'Metta World Peace': 2,
#    'Eric Bledsoe': 1,
#    'Kevin Durant': 1,
#    'Jrue Holiday': 1,
#    'Andrei Kirilenko': 1,
#    'Iman Shumpert': 1,
#    'David West': 1}},
#  {12: {'Andre Iguodala': 19,
#    'Joakim Noah': 14,
#    'Iman Shumpert': 13,
#    'Paul George': 10,
#    'Russell Westbrook': 9,
#    'Josh Smith': 8,
#    'Dwyane Wade': 5,
#    'Thabo Sefolosha': 5,
#    'Grant Hill': 5,
#    'Tim Duncan': 5,
#    'Avery Bradley': 3,
#    'Marc Gasol': 3,
#    'Metta World Peace': 3,
#    'Shawn Marion': 3,
#    'Joe Johnson': 2,
#    'Mike Conley': 2,
#    'Derrick Rose': 1,
#    'Jrue Holiday': 1,
#    'Carlos Boozer': 1,
#    'Luc Mbah a Moute': 1}},
#  {11: {'Derrick Rose': 14,
#    'Dwyane Wade': 13,
#    'Russell Westbrook': 13,
#    'Gerald Wallace': 11,
#    'Grant Hill': 11,
#    'Luol Deng': 11,
#    'Tim Duncan': 11,
#    'Chuck Hayes': 10,
#    'Al Horford': 7,
#    'Josh Smith': 7,
#    'Ron Artest': 7,
#    'Serge Ibaka': 6,
#    'Shane Battier': 5,
#    'Thabo Sefolosha': 5,
#    'Wesley Matthews': 4,
#    'Kendrick Perkins': 3,
#    'Nicolas Batum': 3,
#    'Joe Johnson': 2,
#    'Keith Bogans': 2,
#    'Kyle Lowry': 2,
#    'Lamar Odom': 2,
#    'Luc Mbah a Moute': 2,
#    'Manu Ginobili': 2,
#    'Andrew Bogut': 1,
#    'Andrew Bynum': 1,
#    'Arron Afflalo': 1,
#    'Jrue Holiday': 1,
#    'Kirk Hinrich': 1,
#    'Nene Hilario': 1,
#    'Ronnie Brewer': 1,
#    'Shawn Marion': 1,
#    'Tayshaun Prince': 1}},
#  {10: {'Jason Kidd': 12,
#    'Marcus Camby': 12,
#    'Ron Artest': 11,
#    'Deron Williams': 10,
#    'Kirk Hinrich': 9,
#    'Andrew Bogut': 8,
#    'Luc Mbah a Moute': 8,
#    'Arron Afflalo': 6,
#    'Kenyon Martin': 5,
#    'Kevin Garnett': 5,
#    'Grant Hill': 4,
#    'Joakim Noah': 4,
#    'Kendrick Perkins': 4,
#    'Shane Battier': 4,
#    'Andrei Kirilenko': 3,
#    'Russell Westbrook': 3,
#    'Trevor Ariza': 3,
#    'Andre Iguodala': 2,
#    'George Hill': 2,
#    'Jermaine O’Neal': 2,
#    'Joe Johnson': 2,
#    'Lamar Odom': 2,
#    'Luis Scola': 2,
#    'Manu Ginobili': 2,
#    'Nicolas Batum': 2,
#    'Caron Butler': 1,
#    'Chauncey Billups': 1,
#    'Jared Dudley': 1,
#    'Kevin Durant': 1,
#    'Raymond Felton': 1,
#    'Marc Gasol': 1,
#    'Pau Gasol': 1,
#    'Chuck Hayes': 1,
#    'Brendan Haywood': 1,
#    'Al Horford': 1,
#    'Serge Ibaka': 1,
#    'Ersan Ilyasova': 1,
#    'Stephen Jackson': 1,
#    'Nene Hilario': 1,
#    'Chris Paul': 1,
#    'Tayshaun Prince': 1,
#    'Earl Watson': 1}},
#  {9: {'Tayshaun Prince': 15,
#    'Raja Bell': 8,
#    'Joel Przybilla': 7,
#    'Chauncey Billups': 5,
#    'Ronnie Brewer': 5,
#    'Andre Iguodala': 5,
#    'Yao Ming': 5,
#    'Emeka Okafor': 5,
#    'Kendrick Perkins': 4,
#    'Samuel Dalembert': 3,
#    'Derek Fisher': 3,
#    'Udonis Haslem': 3,
#    'Jason Kidd': 3,
#    'Anderson Varejao': 3,
#    'Deron Williams': 3,
#    'Trevor Ariza': 2,
#    'Kirk Hinrich': 2,
#    'Joe Johnson': 2,
#    'Andrei Kirilenko': 2,
#    'David Lee': 2,
#    'James Posey': 2,
#    'J.R. Smith': 2,
#    'Gerald Wallace': 2,
#    'NenFe': 1,
#    'Chris Andersen': 1,
#    'Pau Gasol': 1,
#    'Antonio McDyess': 1,
#    'Andre Miller': 1,
#    'Travis Outlaw': 1,
#    'Brandon Roy': 1,
#    'Rasheed Wallace': 1}},
#  {8: {'Chauncey Billups': 14,
#    'Jason Kidd': 13,
#    'Rasheed Wallace': 13,
#    'Rajon Rondo': 11,
#    'Deron Williams': 8,
#    'Josh Smith': 8,
#    'Ron Artest': 8,
#    'Tyson Chandler': 8,
#    'Andrei Kirilenko': 6,
#    'Derek Fisher': 4,
#    'LeBron James': 4,
#    'Manu Ginobili': 4,
#    'Kirk Hinrich': 3,
#    'Samuel Dalembert': 3,
#    'Andre Iguodala': 2,
#    'Brandon Roy': 2,
#    'Paul Pierce': 2,
#    'Andre Miller': 1,
#    'Andres Nocioni': 1,
#    'Baron Davis': 1,
#    'Caron Butler': 1,
#    'Chris Bosh': 1,
#    'Dikembe Mutombo': 1,
#    'Josh Howard': 1,
#    'Richard Hamilton': 1,
#    'Ronnie Brewer': 1}},
#  {7: {'Shane Battier': 17,
#    'Shawn Marion': 15,
#    'Chauncey Billups': 13,
#    'Ron Artest': 12,
#    'Gerald Wallace': 11,
#    'Alonzo Mourning': 9,
#    'Devin Harris': 8,
#    'Tyson Chandler': 8,
#    'Josh Howard': 7,
#    'Emeka Okafor': 6,
#    'Luol Deng': 5,
#    'Rasheed Wallace': 5,
#    'Dwight Howard': 5,
#    'Andrei Kirilenko': 5,
#    'Josh Smith': 4,
#    'Manu Ginobili': 4,
#    'Richard Hamilton': 3,
#    'Jermaine O’Neal': 3,
#    'Andre Iguodala': 3,
#    'Deron Williams': 3,
#    'Elton Brand': 2,
#    'Dwyane Wade': 2,
#    'Trenton Hassell': 2,
#    'Tony Parker': 2,
#    'Caron Butler': 2,
#    'Chris Duhon': 1,
#    'Allen Iverson': 1,
#    'Udonis Haslem': 1,
#    'Richard Jefferson': 1,
#    'Chris Paul': 1,
#    'Andre Miller': 1,
#    'Joel Przybilla': 1,
#    'Francisco Elson': 1,
#    'Chris Bosh': 1,
#    'Gilbert Arenas': 1}},
#  {6: {'Rasheed Wallace': 12,
#    'Gerald Wallace': 11,
#    'Shawn Marion': 11,
#    'Raja Bell': 9,
#    'Dwyane Wade': 8,
#    'Kirk Hinrich': 7,
#    'Alonzo Mourning': 7,
#    'Shane Battier': 6,
#    'Gilbert Arenas': 4,
#    'Andre Iguodala': 4,
#    'P.J. Brown': 3,
#    'Manu Ginobili': 3,
#    'Dwight Howard': 3,
#    'Josh Howard': 3,
#    'Brevin Knight': 3,
#    'Shaquille O’Neal': 3,
#    'Elton Brand': 2,
#    'LeBron James': 2,
#    'Tony Parker': 2,
#    'Quinton Ross': 2,
#    'Allen Iverson': 2,
#    'Eddie Jones': 2,
#    'Jason Collins': 1,
#    'Boris Diaw': 1,
#    'Pau Gasol': 1,
#    'Trenton Hassel': 1,
#    'Mike James': 1,
#    'Richard Jefferson': 1,
#    'Ruben Patterson': 1,
#    'Chris Paul': 1,
#    'Jason Terry': 1,
#    'Yao Ming': 1}},
#  {5: {'Shaquille O’Neal': 16,
#    'Allen Iverson': 14,
#    'Kobe Bryant': 12,
#    'Shawn Marion': 9,
#    'Manu Ginobili': 9,
#    'Rasheed Wallace': 8,
#    'Kenyon Martin': 6,
#    'Tony Parker': 5,
#    'Andre Iguodala': 5,
#    'Shane Battier': 4,
#    'Andre Miller': 4,
#    'Tyson Chandler': 3,
#    'Trenton Hassell': 3,
#    'Kirk Hinrich': 3,
#    'Joe Johnson': 3,
#    'Earl Watson': 3,
#    'Udonis Haslem': 2,
#    'Tracy McGrady': 2,
#    'Josh Howard': 2,
#    'Joel Przybilla': 2,
#    'Desmond Mason': 2,
#    'Brevin Knight': 2,
#    'Vince Carter': 1,
#    'P.J. Brown': 1,
#    'Mickael Pietrus': 1,
#    'Kurt Thomas': 1,
#    'Jeff Foster': 1,
#    'Greg Buckner': 1,
#    'Gilbert Arenas': 1,
#    'Gary Payton': 1,
#    'Emeka Okafor': 1,
#    'Eddie Jones': 1,
#    'Clifford Robinson': 1,
#    'Brendan Haywood': 1,
#    'Anthony Johnson': 1,
#    'Andres Nocioni': 1,
#    'Amaré Stoudemire': 1}}]

# %%
for i in range(0,4):
    for k, v in adv_dict[i].items():
        for key, val in adv_dict[i][k].items():
            adv_dict[i][k][key] = adv_dict[i][k][key]/4

# %%
adv_dict
# Out:
# [{17: {'Avery Bradley': 11.5,
#    'Klay Thompson': 11.25,
#    'John Wall': 9.5,
#    'DeAndre Jordan': 8.75,
#    'Paul Millsap': 8.75,
#    'Hassan Whiteside': 6.25,
#    'Marcus Smart': 5.25,
#    'Jimmy Butler': 4.5,
#    'LeBron James': 3.0,
#    'Robert Covington': 2.75,
#    'Russell Westbrook': 2.5,
#    'Paul George': 1.75,
#    'Kevin Durant': 1.5,
#    'Dwight Howard': 1.5,
#    'Mike Conley': 1.25,
#    'Jae Crowder': 1.25,
#    'Jrue Holiday': 1.25,
#    'Wesley Matthews': 1.0,
#    'Stephen Curry': 0.75,
#    'Andre Iguodala': 0.75,
#    'Michael Kidd-Gilchrist': 0.75,
#    'Ricky Rubio': 0.75,
#    'P.J. Tucker': 0.75,
#    'Trevor Ariza': 0.5,
#    'Nicolas Batum': 0.5,
#    'Marc Gasol': 0.5,
#    'Eric Gordon': 0.5,
#    'Karl-Anthony Towns': 0.5,
#    'Steven Adams': 0.25,
#    'LaMarcus Aldridge': 0.25,
#    'Al-Farouq Aminu': 0.25,
#    'Kentavious Caldwell-Pope': 0.25,
#    'George Hill': 0.25,
#    'Serge Ibaka': 0.25,
#    'Damian Lillard': 0.25,
#    'Luc Mbah a Moute': 0.25,
#    'Austin Rivers': 0.25,
#    'Isaiah Thomas': 0.25,
#    'Cody Zeller': 0.25}},
#  {16: {'Rudy Gobert': 16.0,
#    'Klay Thompson': 12.25,
#    'Jae Crowder': 11.75,
#    'LeBron James': 10.75,
#    'Kyle Lowry': 10.75,
#    'Danny Green': 9.75,
#    'Russell Westbrook': 8.75,
#    'Tim Duncan': 8.25,
#    'Ricky Rubio': 7.5,
#    'Kentavious Caldwell-Pope': 6.75,
#    'Anthony Davis': 6.0,
#    'Andre Drummond': 3.5,
#    'Serge Ibaka': 3.5,
#    'Stephen Curry': 3.25,
#    'Andre Iguodala': 3.25,
#    'Patrick Beverley': 2.75,
#    'Al Horford': 1.75,
#    'Marcus Smart': 1.75,
#    'John Wall': 1.5,
#    'Giannis Antetokounmpo': 0.75,
#    'Trevor Ariza': 0.75,
#    'Kent Bazemore': 0.75,
#    'Andrew Bogut': 0.75,
#    'DeMarcus Cousins': 0.75,
#    'Nicolas Batum': 0.5,
#    'Victor Oladipo': 0.5,
#    'LaMarcus Aldridge': 0.25,
#    'Harrison Barnes': 0.25,
#    'Bismack Biyombo': 0.25,
#    'Mike Conley': 0.25,
#    'Kevin Durant': 0.25,
#    'Derrick Favors': 0.25,
#    'George Hill': 0.25,
#    'Wesley Matthews': 0.25,
#    'Luc Mbah a Moute': 0.25,
#    'Kristaps Porzingis': 0.25,
#    'Andre Roberson': 0.25,
#    'Mike Scott': 0.25,
#    'Dwyane Wade': 0.25}},
#  {15: {'Rudy Gobert': 13.5,
#    'LeBron James': 11.75,
#    'Russell Westbrook': 8.75,
#    'Avery Bradley': 6.5,
#    'Michael Kidd-Gilchrist': 5.25,
#    'Marc Gasol': 4.5,
#    'Danny Green': 4.5,
#    'Trevor Ariza': 4.25,
#    'Stephen Curry': 3.5,
#    'DeMarre Carroll': 2.75,
#    'Patrick Beverley': 2.5,
#    'Khris Middleton': 2.25,
#    'Serge Ibaka': 2.0,
#    'Andre Iguodala': 2.0,
#    'Paul Millsap': 2.0,
#    'Jeff Teague': 1.75,
#    'Mike Conley': 1.5,
#    'Joakim Noah': 1.5,
#    'Nerlens Noel': 1.25,
#    'P.J. Tucker': 1.0,
#    'Giannis Antetokounmpo': 0.75,
#    'Pau Gasol': 0.75,
#    'Wesley Matthews': 0.75,
#    'James Harden': 0.5,
#    'Marcus Smart': 0.5,
#    'Hassan Whiteside': 0.5,
#    'Eric Bledsoe': 0.25,
#    'DeMarcus Cousins': 0.25,
#    'Andre Drummond': 0.25,
#    'Manu Ginobili': 0.25,
#    'Blake Griffin': 0.25,
#    'George Hill': 0.25,
#    'Al Horford': 0.25,
#    'Victor Oladipo': 0.25,
#    'Zaza Pachulia': 0.25,
#    'Elfrid Payton': 0.25,
#    'Zach Randolph': 0.25,
#    'Rajon Rondo': 0.25,
#    'Iman Shumpert': 0.25,
#    'Dwyane Wade': 0.25}},
#  {14: {'DeAndre Jordan': 15.75,
#    'Anthony Davis': 15.5,
#    'Tony Allen': 15.0,
#    'Tim Duncan': 11.25,
#    'Dwight Howard': 6.5,
#    'Taj Gibson': 5.25,
#    'Mike Conley': 5.25,
#    'Ricky Rubio': 4.75,
#    'Lance Stephenson': 3.5,
#    'P.J. Tucker': 3.25,
#    'Kevin Durant': 2.5,
#    'Kyle Lowry': 2.5,
#    'Eric Bledsoe': 2.25,
#    'Marc Gasol': 2.0,
#    'John Wall': 2.0,
#    'Thabo Sefolosha': 2.0,
#    'Kirk Hinrich': 1.75,
#    'Trevor Ariza': 1.25,
#    'Avery Bradley': 1.25,
#    'Russell Westbrook': 1.25,
#    'Klay Thompson': 1.25,
#    'Andrew Bogut': 1.0,
#    'Chris Bosh': 1.0,
#    'Luol Deng': 1.0,
#    'Wesley Matthews': 1.0,
#    'Tony Parker': 1.0,
#    'Nicolas Batum': 0.75,
#    'Stephen Curry': 0.75,
#    'Danny Green': 0.75,
#    'Michael Kidd-Gilchrist': 0.75,
#    'Shaun Livingston': 0.75,
#    'Victor Oladipo': 0.75,
#    'DeMarre Carroll': 0.5,
#    'Matt Barnes': 0.5,
#    'James Harden': 0.5,
#    'George Hill': 0.5,
#    'Jeff Teague': 0.5,
#    'Dwyane Wade': 0.5,
#    'Kemba Walker': 0.5,
#    'David West': 0.5,
#    'Arron Afflalo': 0.25,
#    'Corey Brewer': 0.25,
#    'Michael Carter-Williams': 0.25,
#    'Darren Collison': 0.25,
#    'DeMar DeRozan': 0.25,
#    'Andre Drummond': 0.25,
#    'Monta Ellis': 0.25,
#    'Danny Granger': 0.25,
#    'Draymond Green': 0.25,
#    'Reggie Jackson': 0.25,
#    'David Lee': 0.25,
#    'Paul Millsap': 0.25,
#    'Rajon Rondo': 0.25}},
#  {13: {'Andre Iguodala': 16,
#    'Larry Sanders': 16,
#    'Thabo Sefolosha': 15,
#    'Luol Deng': 11,
#    'Dwight Howard': 9,
#    'Kobe Bryant': 6,
#    'Roy Hibbert': 6,
#    'Kenneth Faried': 4,
#    'Russell Westbrook': 4,
#    'Shane Battier': 2,
#    'Nicolas Batum': 2,
#    'Corey Brewer': 2,
#    'George Hill': 2,
#    'Mike James': 2,
#    'Kawhi Leonard': 2,
#    'Tony Parker': 2,
#    'Dwyane Wade': 2,
#    'Metta World Peace': 2,
#    'Eric Bledsoe': 1,
#    'Kevin Durant': 1,
#    'Jrue Holiday': 1,
#    'Andrei Kirilenko': 1,
#    'Iman Shumpert': 1,
#    'David West': 1}},
#  {12: {'Andre Iguodala': 19,
#    'Joakim Noah': 14,
#    'Iman Shumpert': 13,
#    'Paul George': 10,
#    'Russell Westbrook': 9,
#    'Josh Smith': 8,
#    'Dwyane Wade': 5,
#    'Thabo Sefolosha': 5,
#    'Grant Hill': 5,
#    'Tim Duncan': 5,
#    'Avery Bradley': 3,
#    'Marc Gasol': 3,
#    'Metta World Peace': 3,
#    'Shawn Marion': 3,
#    'Joe Johnson': 2,
#    'Mike Conley': 2,
#    'Derrick Rose': 1,
#    'Jrue Holiday': 1,
#    'Carlos Boozer': 1,
#    'Luc Mbah a Moute': 1}},
#  {11: {'Derrick Rose': 14,
#    'Dwyane Wade': 13,
#    'Russell Westbrook': 13,
#    'Gerald Wallace': 11,
#    'Grant Hill': 11,
#    'Luol Deng': 11,
#    'Tim Duncan': 11,
#    'Chuck Hayes': 10,
#    'Al Horford': 7,
#    'Josh Smith': 7,
#    'Ron Artest': 7,
#    'Serge Ibaka': 6,
#    'Shane Battier': 5,
#    'Thabo Sefolosha': 5,
#    'Wesley Matthews': 4,
#    'Kendrick Perkins': 3,
#    'Nicolas Batum': 3,
#    'Joe Johnson': 2,
#    'Keith Bogans': 2,
#    'Kyle Lowry': 2,
#    'Lamar Odom': 2,
#    'Luc Mbah a Moute': 2,
#    'Manu Ginobili': 2,
#    'Andrew Bogut': 1,
#    'Andrew Bynum': 1,
#    'Arron Afflalo': 1,
#    'Jrue Holiday': 1,
#    'Kirk Hinrich': 1,
#    'Nene Hilario': 1,
#    'Ronnie Brewer': 1,
#    'Shawn Marion': 1,
#    'Tayshaun Prince': 1}},
#  {10: {'Jason Kidd': 12,
#    'Marcus Camby': 12,
#    'Ron Artest': 11,
#    'Deron Williams': 10,
#    'Kirk Hinrich': 9,
#    'Andrew Bogut': 8,
#    'Luc Mbah a Moute': 8,
#    'Arron Afflalo': 6,
#    'Kenyon Martin': 5,
#    'Kevin Garnett': 5,
#    'Grant Hill': 4,
#    'Joakim Noah': 4,
#    'Kendrick Perkins': 4,
#    'Shane Battier': 4,
#    'Andrei Kirilenko': 3,
#    'Russell Westbrook': 3,
#    'Trevor Ariza': 3,
#    'Andre Iguodala': 2,
#    'George Hill': 2,
#    'Jermaine O’Neal': 2,
#    'Joe Johnson': 2,
#    'Lamar Odom': 2,
#    'Luis Scola': 2,
#    'Manu Ginobili': 2,
#    'Nicolas Batum': 2,
#    'Caron Butler': 1,
#    'Chauncey Billups': 1,
#    'Jared Dudley': 1,
#    'Kevin Durant': 1,
#    'Raymond Felton': 1,
#    'Marc Gasol': 1,
#    'Pau Gasol': 1,
#    'Chuck Hayes': 1,
#    'Brendan Haywood': 1,
#    'Al Horford': 1,
#    'Serge Ibaka': 1,
#    'Ersan Ilyasova': 1,
#    'Stephen Jackson': 1,
#    'Nene Hilario': 1,
#    'Chris Paul': 1,
#    'Tayshaun Prince': 1,
#    'Earl Watson': 1}},
#  {9: {'Tayshaun Prince': 15,
#    'Raja Bell': 8,
#    'Joel Przybilla': 7,
#    'Chauncey Billups': 5,
#    'Ronnie Brewer': 5,
#    'Andre Iguodala': 5,
#    'Yao Ming': 5,
#    'Emeka Okafor': 5,
#    'Kendrick Perkins': 4,
#    'Samuel Dalembert': 3,
#    'Derek Fisher': 3,
#    'Udonis Haslem': 3,
#    'Jason Kidd': 3,
#    'Anderson Varejao': 3,
#    'Deron Williams': 3,
#    'Trevor Ariza': 2,
#    'Kirk Hinrich': 2,
#    'Joe Johnson': 2,
#    'Andrei Kirilenko': 2,
#    'David Lee': 2,
#    'James Posey': 2,
#    'J.R. Smith': 2,
#    'Gerald Wallace': 2,
#    'NenFe': 1,
#    'Chris Andersen': 1,
#    'Pau Gasol': 1,
#    'Antonio McDyess': 1,
#    'Andre Miller': 1,
#    'Travis Outlaw': 1,
#    'Brandon Roy': 1,
#    'Rasheed Wallace': 1}},
#  {8: {'Chauncey Billups': 14,
#    'Jason Kidd': 13,
#    'Rasheed Wallace': 13,
#    'Rajon Rondo': 11,
#    'Deron Williams': 8,
#    'Josh Smith': 8,
#    'Ron Artest': 8,
#    'Tyson Chandler': 8,
#    'Andrei Kirilenko': 6,
#    'Derek Fisher': 4,
#    'LeBron James': 4,
#    'Manu Ginobili': 4,
#    'Kirk Hinrich': 3,
#    'Samuel Dalembert': 3,
#    'Andre Iguodala': 2,
#    'Brandon Roy': 2,
#    'Paul Pierce': 2,
#    'Andre Miller': 1,
#    'Andres Nocioni': 1,
#    'Baron Davis': 1,
#    'Caron Butler': 1,
#    'Chris Bosh': 1,
#    'Dikembe Mutombo': 1,
#    'Josh Howard': 1,
#    'Richard Hamilton': 1,
#    'Ronnie Brewer': 1}},
#  {7: {'Shane Battier': 17,
#    'Shawn Marion': 15,
#    'Chauncey Billups': 13,
#    'Ron Artest': 12,
#    'Gerald Wallace': 11,
#    'Alonzo Mourning': 9,
#    'Devin Harris': 8,
#    'Tyson Chandler': 8,
#    'Josh Howard': 7,
#    'Emeka Okafor': 6,
#    'Luol Deng': 5,
#    'Rasheed Wallace': 5,
#    'Dwight Howard': 5,
#    'Andrei Kirilenko': 5,
#    'Josh Smith': 4,
#    'Manu Ginobili': 4,
#    'Richard Hamilton': 3,
#    'Jermaine O’Neal': 3,
#    'Andre Iguodala': 3,
#    'Deron Williams': 3,
#    'Elton Brand': 2,
#    'Dwyane Wade': 2,
#    'Trenton Hassell': 2,
#    'Tony Parker': 2,
#    'Caron Butler': 2,
#    'Chris Duhon': 1,
#    'Allen Iverson': 1,
#    'Udonis Haslem': 1,
#    'Richard Jefferson': 1,
#    'Chris Paul': 1,
#    'Andre Miller': 1,
#    'Joel Przybilla': 1,
#    'Francisco Elson': 1,
#    'Chris Bosh': 1,
#    'Gilbert Arenas': 1}},
#  {6: {'Rasheed Wallace': 12,
#    'Gerald Wallace': 11,
#    'Shawn Marion': 11,
#    'Raja Bell': 9,
#    'Dwyane Wade': 8,
#    'Kirk Hinrich': 7,
#    'Alonzo Mourning': 7,
#    'Shane Battier': 6,
#    'Gilbert Arenas': 4,
#    'Andre Iguodala': 4,
#    'P.J. Brown': 3,
#    'Manu Ginobili': 3,
#    'Dwight Howard': 3,
#    'Josh Howard': 3,
#    'Brevin Knight': 3,
#    'Shaquille O’Neal': 3,
#    'Elton Brand': 2,
#    'LeBron James': 2,
#    'Tony Parker': 2,
#    'Quinton Ross': 2,
#    'Allen Iverson': 2,
#    'Eddie Jones': 2,
#    'Jason Collins': 1,
#    'Boris Diaw': 1,
#    'Pau Gasol': 1,
#    'Trenton Hassel': 1,
#    'Mike James': 1,
#    'Richard Jefferson': 1,
#    'Ruben Patterson': 1,
#    'Chris Paul': 1,
#    'Jason Terry': 1,
#    'Yao Ming': 1}},
#  {5: {'Shaquille O’Neal': 16,
#    'Allen Iverson': 14,
#    'Kobe Bryant': 12,
#    'Shawn Marion': 9,
#    'Manu Ginobili': 9,
#    'Rasheed Wallace': 8,
#    'Kenyon Martin': 6,
#    'Tony Parker': 5,
#    'Andre Iguodala': 5,
#    'Shane Battier': 4,
#    'Andre Miller': 4,
#    'Tyson Chandler': 3,
#    'Trenton Hassell': 3,
#    'Kirk Hinrich': 3,
#    'Joe Johnson': 3,
#    'Earl Watson': 3,
#    'Udonis Haslem': 2,
#    'Tracy McGrady': 2,
#    'Josh Howard': 2,
#    'Joel Przybilla': 2,
#    'Desmond Mason': 2,
#    'Brevin Knight': 2,
#    'Vince Carter': 1,
#    'P.J. Brown': 1,
#    'Mickael Pietrus': 1,
#    'Kurt Thomas': 1,
#    'Jeff Foster': 1,
#    'Greg Buckner': 1,
#    'Gilbert Arenas': 1,
#    'Gary Payton': 1,
#    'Emeka Okafor': 1,
#    'Eddie Jones': 1,
#    'Clifford Robinson': 1,
#    'Brendan Haywood': 1,
#    'Anthony Johnson': 1,
#    'Andres Nocioni': 1,
#    'Amaré Stoudemire': 1}}]

# %%
fv_dict = {}
year = 17
for i in range(0,13):
    adv_dict[i][year].update(adlrev[i][year])
    fv_dict[year] = adv_dict[i][year]
    year -= 1

# %%
fv_dict
# Out:
# {17: {'Avery Bradley': 11.5,
#   'Klay Thompson': 11.25,
#   'John Wall': 9.5,
#   'DeAndre Jordan': 8.75,
#   'Paul Millsap': 8.75,
#   'Hassan Whiteside': 6.25,
#   'Marcus Smart': 5.25,
#   'Jimmy Butler': 4.5,
#   'LeBron James': 3.0,
#   'Robert Covington': 2.75,
#   'Russell Westbrook': 2.5,
#   'Paul George': 1.75,
#   'Kevin Durant': 1.5,
#   'Dwight Howard': 1.5,
#   'Mike Conley': 1.25,
#   'Jae Crowder': 1.25,
#   'Jrue Holiday': 1.25,
#   'Wesley Matthews': 1.0,
#   'Stephen Curry': 0.75,
#   'Andre Iguodala': 0.75,
#   'Michael Kidd-Gilchrist': 0.75,
#   'Ricky Rubio': 0.75,
#   'P.J. Tucker': 0.75,
#   'Trevor Ariza': 0.5,
#   'Nicolas Batum': 0.5,
#   'Marc Gasol': 0.5,
#   'Eric Gordon': 0.5,
#   'Karl-Anthony Towns': 0.5,
#   'Steven Adams': 0.25,
#   'LaMarcus Aldridge': 0.25,
#   'Al-Farouq Aminu': 0.25,
#   'Kentavious Caldwell-Pope': 0.25,
#   'George Hill': 0.25,
#   'Serge Ibaka': 0.25,
#   'Damian Lillard': 0.25,
#   'Luc Mbah a Moute': 0.25,
#   'Austin Rivers': 0.25,
#   'Isaiah Thomas': 0.25,
#   'Cody Zeller': 0.25,
#   'Kawhi Leonard': 48.0,
#   'Draymond Green': 49.5,
#   'Rudy Gobert': 49.0,
#   'Patrick Beverly': 27.5,
#   'Chris Paul': 35.0,
#   'Tony Allen': 20.0,
#   'Danny Green': 17.0,
#   'Andre Roberson': 13.25,
#   'Anthony Davis': 14.5,
#   'Giannis Antetokounmpo': 8.75},
#  16: {'Rudy Gobert': 16.0,
#   'Klay Thompson': 12.25,
#   'Jae Crowder': 11.75,
#   'LeBron James': 10.75,
#   'Kyle Lowry': 10.75,
#   'Danny Green': 9.75,
#   'Russell Westbrook': 8.75,
#   'Tim Duncan': 8.25,
#   'Ricky Rubio': 7.5,
#   'Kentavious Caldwell-Pope': 6.75,
#   'Anthony Davis': 6.0,
#   'Andre Drummond': 3.5,
#   'Serge Ibaka': 3.5,
#   'Stephen Curry': 3.25,
#   'Andre Iguodala': 3.25,
#   'Patrick Beverley': 2.75,
#   'Al Horford': 1.75,
#   'Marcus Smart': 1.75,
#   'John Wall': 1.5,
#   'Giannis Antetokounmpo': 0.75,
#   'Trevor Ariza': 0.75,
#   'Kent Bazemore': 0.75,
#   'Andrew Bogut': 0.75,
#   'DeMarcus Cousins': 0.75,
#   'Nicolas Batum': 0.5,
#   'Victor Oladipo': 0.5,
#   'LaMarcus Aldridge': 0.25,
#   'Harrison Barnes': 0.25,
#   'Bismack Biyombo': 0.25,
#   'Mike Conley': 0.25,
#   'Kevin Durant': 0.25,
#   'Derrick Favors': 0.25,
#   'George Hill': 0.25,
#   'Wesley Matthews': 0.25,
#   'Luc Mbah a Moute': 0.25,
#   'Kristaps Porzingis': 0.25,
#   'Andre Roberson': 0.25,
#   'Mike Scott': 0.25,
#   'Dwyane Wade': 0.25,
#   'Kawhi Leonard': 65.0,
#   'Draymond Green': 62.75,
#   'DeAndre Jordan': 34.25,
#   'Avery Bradley': 37.25,
#   'Chris Paul': 37.0,
#   'Paul Millsap': 24.25,
#   'Paul George': 12.0,
#   'Hassan Whiteside': 31.5,
#   'Tony Allen': 30.25,
#   'Jimmy Butler': 15.5},
#  15: {'Rudy Gobert': 13.5,
#   'LeBron James': 11.75,
#   'Russell Westbrook': 8.75,
#   'Avery Bradley': 6.5,
#   'Michael Kidd-Gilchrist': 5.25,
#   'Marc Gasol': 4.5,
#   'Danny Green': 4.5,
#   'Trevor Ariza': 4.25,
#   'Stephen Curry': 3.5,
#   'DeMarre Carroll': 2.75,
#   'Patrick Beverley': 2.5,
#   'Khris Middleton': 2.25,
#   'Serge Ibaka': 2.0,
#   'Andre Iguodala': 2.0,
#   'Paul Millsap': 2.0,
#   'Jeff Teague': 1.75,
#   'Mike Conley': 1.5,
#   'Joakim Noah': 1.5,
#   'Nerlens Noel': 1.25,
#   'P.J. Tucker': 1.0,
#   'Giannis Antetokounmpo': 0.75,
#   'Pau Gasol': 0.75,
#   'Wesley Matthews': 0.75,
#   'James Harden': 0.5,
#   'Marcus Smart': 0.5,
#   'Hassan Whiteside': 0.5,
#   'Eric Bledsoe': 0.25,
#   'DeMarcus Cousins': 0.25,
#   'Andre Drummond': 0.25,
#   'Manu Ginobili': 0.25,
#   'Blake Griffin': 0.25,
#   'George Hill': 0.25,
#   'Al Horford': 0.25,
#   'Victor Oladipo': 0.25,
#   'Zaza Pachulia': 0.25,
#   'Elfrid Payton': 0.25,
#   'Zach Randolph': 0.25,
#   'Rajon Rondo': 0.25,
#   'Iman Shumpert': 0.25,
#   'Dwyane Wade': 0.25,
#   'Kawhi Leonard': 60.5,
#   'Draymond Green': 57.25,
#   'Tony Allen': 51.75,
#   'DeAndre Jordan': 46.75,
#   'Chris Paul': 42.5,
#   'Anthony Davis': 38.75,
#   'Jimmy Butler': 33.0,
#   'Andrew Bogut': 25.5,
#   'John Wall': 16.75,
#   'Tim Duncan': 16.0},
#  14: {'DeAndre Jordan': 15.75,
#   'Anthony Davis': 15.5,
#   'Tony Allen': 15.0,
#   'Tim Duncan': 11.25,
#   'Dwight Howard': 6.5,
#   'Taj Gibson': 5.25,
#   'Mike Conley': 5.25,
#   'Ricky Rubio': 4.75,
#   'Lance Stephenson': 3.5,
#   'P.J. Tucker': 3.25,
#   'Kevin Durant': 2.5,
#   'Kyle Lowry': 2.5,
#   'Eric Bledsoe': 2.25,
#   'Marc Gasol': 2.0,
#   'John Wall': 2.0,
#   'Thabo Sefolosha': 2.0,
#   'Kirk Hinrich': 1.75,
#   'Trevor Ariza': 1.25,
#   'Avery Bradley': 1.25,
#   'Russell Westbrook': 1.25,
#   'Klay Thompson': 1.25,
#   'Andrew Bogut': 1.0,
#   'Chris Bosh': 1.0,
#   'Luol Deng': 1.0,
#   'Wesley Matthews': 1.0,
#   'Tony Parker': 1.0,
#   'Nicolas Batum': 0.75,
#   'Stephen Curry': 0.75,
#   'Danny Green': 0.75,
#   'Michael Kidd-Gilchrist': 0.75,
#   'Shaun Livingston': 0.75,
#   'Victor Oladipo': 0.75,
#   'DeMarre Carroll': 0.5,
#   'Matt Barnes': 0.5,
#   'James Harden': 0.5,
#   'George Hill': 0.5,
#   'Jeff Teague': 0.5,
#   'Dwyane Wade': 0.5,
#   'Kemba Walker': 0.5,
#   'David West': 0.5,
#   'Arron Afflalo': 0.25,
#   'Corey Brewer': 0.25,
#   'Michael Carter-Williams': 0.25,
#   'Darren Collison': 0.25,
#   'DeMar DeRozan': 0.25,
#   'Andre Drummond': 0.25,
#   'Monta Ellis': 0.25,
#   'Danny Granger': 0.25,
#   'Draymond Green': 0.25,
#   'Reggie Jackson': 0.25,
#   'David Lee': 0.25,
#   'Paul Millsap': 0.25,
#   'Rajon Rondo': 0.25,
#   'Joakim Noah': 55.75,
#   'Paul George': 40.25,
#   'Chris Paul': 39.0,
#   'Serge Ibaka': 38.0,
#   'Andre Igoudala': 37.0,
#   'Lebron James': 33.5,
#   'Patrick Beverly': 28.0,
#   'Jimmy Butler': 25.75,
#   'Kawhi Leonard': 22.25,
#   'Roy Hibbert': 19.0},
#  13: {'Andre Iguodala': 16,
#   'Larry Sanders': 16,
#   'Thabo Sefolosha': 15,
#   'Luol Deng': 11,
#   'Dwight Howard': 9,
#   'Kobe Bryant': 6,
#   'Roy Hibbert': 6,
#   'Kenneth Faried': 4,
#   'Russell Westbrook': 4,
#   'Shane Battier': 2,
#   'Nicolas Batum': 2,
#   'Corey Brewer': 2,
#   'George Hill': 2,
#   'Mike James': 2,
#   'Kawhi Leonard': 2,
#   'Tony Parker': 2,
#   'Dwyane Wade': 2,
#   'Metta World Peace': 2,
#   'Eric Bledsoe': 1,
#   'Kevin Durant': 1,
#   'Jrue Holiday': 1,
#   'Andrei Kirilenko': 1,
#   'Iman Shumpert': 1,
#   'David West': 1,
#   'Tony Allen': 53,
#   'Serge Ibaka': 46,
#   'Lebron James': 52,
#   'Chris Paul': 37,
#   'Joakim Noah': 24,
#   'Tyson Chandler': 24,
#   'Avery Bradley': 25,
#   'Mike Conley': 19,
#   'Tim Duncan': 20,
#   'Marc Gasol': 12,
#   'Paul George': 27},
#  12: {'Andre Iguodala': 19,
#   'Joakim Noah': 14,
#   'Iman Shumpert': 13,
#   'Paul George': 10,
#   'Russell Westbrook': 9,
#   'Josh Smith': 8,
#   'Dwyane Wade': 5,
#   'Thabo Sefolosha': 5,
#   'Grant Hill': 5,
#   'Tim Duncan': 5,
#   'Avery Bradley': 3,
#   'Marc Gasol': 3,
#   'Metta World Peace': 3,
#   'Shawn Marion': 3,
#   'Joe Johnson': 2,
#   'Mike Conley': 2,
#   'Derrick Rose': 1,
#   'Jrue Holiday': 1,
#   'Carlos Boozer': 1,
#   'Luc Mbah a Moute': 1,
#   'Tony Allen': 33,
#   'Dwight Howard': 41,
#   'Serge Ibaka': 47,
#   'Lebron James': 53,
#   'Chris Paul': 35,
#   'Kobe Bryant': 17,
#   'Tyson Chandler': 36,
#   'Luol Deng': 20,
#   'Kevin Garnett': 26,
#   'Rajon Rondo': 29},
#  11: {'Derrick Rose': 14,
#   'Dwyane Wade': 13,
#   'Russell Westbrook': 13,
#   'Gerald Wallace': 11,
#   'Grant Hill': 11,
#   'Luol Deng': 11,
#   'Tim Duncan': 11,
#   'Chuck Hayes': 10,
#   'Al Horford': 7,
#   'Josh Smith': 7,
#   'Ron Artest': 7,
#   'Serge Ibaka': 6,
#   'Shane Battier': 5,
#   'Thabo Sefolosha': 5,
#   'Wesley Matthews': 4,
#   'Kendrick Perkins': 3,
#   'Nicolas Batum': 3,
#   'Joe Johnson': 2,
#   'Keith Bogans': 2,
#   'Kyle Lowry': 2,
#   'Lamar Odom': 2,
#   'Luc Mbah a Moute': 2,
#   'Manu Ginobili': 2,
#   'Andrew Bogut': 1,
#   'Andrew Bynum': 1,
#   'Arron Afflalo': 1,
#   'Jrue Holiday': 1,
#   'Kirk Hinrich': 1,
#   'Nene Hilario': 1,
#   'Ronnie Brewer': 1,
#   'Shawn Marion': 1,
#   'Tayshaun Prince': 1,
#   'Kobe Bryant': 33,
#   'Kevin Garnett': 33,
#   'Dwight Howard': 56,
#   'Lebron James': 38,
#   'Rajon Rondo': 39,
#   'Tony Allen': 23,
#   'Tyson Chandler': 17,
#   'Andre Igoudala': 15,
#   'Joakim Noah': 15,
#   'Chis Paul': 18},
#  10: {'Jason Kidd': 12,
#   'Marcus Camby': 12,
#   'Ron Artest': 11,
#   'Deron Williams': 10,
#   'Kirk Hinrich': 9,
#   'Andrew Bogut': 8,
#   'Luc Mbah a Moute': 8,
#   'Arron Afflalo': 6,
#   'Kenyon Martin': 5,
#   'Kevin Garnett': 5,
#   'Grant Hill': 4,
#   'Joakim Noah': 4,
#   'Kendrick Perkins': 4,
#   'Shane Battier': 4,
#   'Andrei Kirilenko': 3,
#   'Russell Westbrook': 3,
#   'Trevor Ariza': 3,
#   'Andre Iguodala': 2,
#   'George Hill': 2,
#   'Jermaine O’Neal': 2,
#   'Joe Johnson': 2,
#   'Lamar Odom': 2,
#   'Luis Scola': 2,
#   'Manu Ginobili': 2,
#   'Nicolas Batum': 2,
#   'Caron Butler': 1,
#   'Chauncey Billups': 1,
#   'Jared Dudley': 1,
#   'Kevin Durant': 1,
#   'Raymond Felton': 1,
#   'Marc Gasol': 1,
#   'Pau Gasol': 1,
#   'Chuck Hayes': 1,
#   'Brendan Haywood': 1,
#   'Al Horford': 1,
#   'Serge Ibaka': 1,
#   'Ersan Ilyasova': 1,
#   'Stephen Jackson': 1,
#   'Nene Hilario': 1,
#   'Chris Paul': 1,
#   'Tayshaun Prince': 1,
#   'Earl Watson': 1,
#   'Kobe Bryant': 34,
#   'Dwight Howard': 57,
#   'Lebron James': 45,
#   'Rajon Rondo': 50,
#   'Gerald Wallace': 30,
#   'Tim Duncan': 21,
#   'Thabo Sefolosha': 14,
#   'Josh Smith': 20,
#   'Anderson Varejao': 15,
#   'Dwyane Wade': 20},
#  9: {'Tayshaun Prince': 15,
#   'Raja Bell': 8,
#   'Joel Przybilla': 7,
#   'Chauncey Billups': 5,
#   'Ronnie Brewer': 5,
#   'Andre Iguodala': 5,
#   'Yao Ming': 5,
#   'Emeka Okafor': 5,
#   'Kendrick Perkins': 4,
#   'Samuel Dalembert': 3,
#   'Derek Fisher': 3,
#   'Udonis Haslem': 3,
#   'Jason Kidd': 3,
#   'Anderson Varejao': 3,
#   'Deron Williams': 3,
#   'Trevor Ariza': 2,
#   'Kirk Hinrich': 2,
#   'Joe Johnson': 2,
#   'Andrei Kirilenko': 2,
#   'David Lee': 2,
#   'James Posey': 2,
#   'J.R. Smith': 2,
#   'Gerald Wallace': 2,
#   'NenFe': 1,
#   'Chris Andersen': 1,
#   'Pau Gasol': 1,
#   'Antonio McDyess': 1,
#   'Andre Miller': 1,
#   'Travis Outlaw': 1,
#   'Brandon Roy': 1,
#   'Rasheed Wallace': 1,
#   'Kobe Bryant': 53,
#   'Kevin Garnett': 35,
#   'Dwight Howard': 55,
#   'Lebron James': 47,
#   'Chris Paul': 36,
#   'Metta World Peace': 22,
#   'Shane Battier': 22,
#   'Tim Duncan': 30,
#   'Rajon Rondo': 23,
#   'Dwyane Wade': 26},
#  8: {'Chauncey Billups': 14,
#   'Jason Kidd': 13,
#   'Rasheed Wallace': 13,
#   'Rajon Rondo': 11,
#   'Deron Williams': 8,
#   'Josh Smith': 8,
#   'Ron Artest': 8,
#   'Tyson Chandler': 8,
#   'Andrei Kirilenko': 6,
#   'Derek Fisher': 4,
#   'LeBron James': 4,
#   'Manu Ginobili': 4,
#   'Kirk Hinrich': 3,
#   'Samuel Dalembert': 3,
#   'Andre Iguodala': 2,
#   'Brandon Roy': 2,
#   'Paul Pierce': 2,
#   'Andre Miller': 1,
#   'Andres Nocioni': 1,
#   'Baron Davis': 1,
#   'Caron Butler': 1,
#   'Chris Bosh': 1,
#   'Dikembe Mutombo': 1,
#   'Josh Howard': 1,
#   'Richard Hamilton': 1,
#   'Ronnie Brewer': 1,
#   'Bruce Bowen': 36,
#   'Kobe Bryant': 52,
#   'Marcus Camby': 37,
#   'Tim Duncan': 33,
#   'Kevin Garnett': 52,
#   'Shane Battier': 29,
#   'Raja Bell': 18,
#   'Dwight Howard': 25,
#   'Chris Paul': 26,
#   'Tayshaun Prince': 20},
#  7: {'Shane Battier': 17,
#   'Shawn Marion': 15,
#   'Chauncey Billups': 13,
#   'Ron Artest': 12,
#   'Gerald Wallace': 11,
#   'Alonzo Mourning': 9,
#   'Devin Harris': 8,
#   'Tyson Chandler': 8,
#   'Josh Howard': 7,
#   'Emeka Okafor': 6,
#   'Luol Deng': 5,
#   'Rasheed Wallace': 5,
#   'Dwight Howard': 5,
#   'Andrei Kirilenko': 5,
#   'Josh Smith': 4,
#   'Manu Ginobili': 4,
#   'Richard Hamilton': 3,
#   'Jermaine O’Neal': 3,
#   'Andre Iguodala': 3,
#   'Deron Williams': 3,
#   'Elton Brand': 2,
#   'Dwyane Wade': 2,
#   'Trenton Hassell': 2,
#   'Tony Parker': 2,
#   'Caron Butler': 2,
#   'Chris Duhon': 1,
#   'Allen Iverson': 1,
#   'Udonis Haslem': 1,
#   'Richard Jefferson': 1,
#   'Chris Paul': 1,
#   'Andre Miller': 1,
#   'Joel Przybilla': 1,
#   'Francisco Elson': 1,
#   'Chris Bosh': 1,
#   'Gilbert Arenas': 1,
#   'Raja Bell': 25,
#   'Bruce Bowen': 42,
#   'Kobe Bryant': 32,
#   'Marcus Camby': 34,
#   'Tim Duncan': 36,
#   'Kevin Garnett': 20,
#   'Kirk Hinrich': 18,
#   'Jason Kidd': 23,
#   'Tayshaun Prince': 21,
#   'Ben Wallace': 33},
#  6: {'Rasheed Wallace': 12,
#   'Gerald Wallace': 11,
#   'Shawn Marion': 11,
#   'Raja Bell': 9,
#   'Dwyane Wade': 8,
#   'Kirk Hinrich': 7,
#   'Alonzo Mourning': 7,
#   'Shane Battier': 6,
#   'Gilbert Arenas': 4,
#   'Andre Iguodala': 4,
#   'P.J. Brown': 3,
#   'Manu Ginobili': 3,
#   'Dwight Howard': 3,
#   'Josh Howard': 3,
#   'Brevin Knight': 3,
#   'Shaquille O’Neal': 3,
#   'Elton Brand': 2,
#   'LeBron James': 2,
#   'Tony Parker': 2,
#   'Quinton Ross': 2,
#   'Allen Iverson': 2,
#   'Eddie Jones': 2,
#   'Jason Collins': 1,
#   'Boris Diaw': 1,
#   'Pau Gasol': 1,
#   'Trenton Hassel': 1,
#   'Mike James': 1,
#   'Richard Jefferson': 1,
#   'Ruben Patterson': 1,
#   'Chris Paul': 1,
#   'Jason Terry': 1,
#   'Yao Ming': 1,
#   'Metta World Peace': 30,
#   'Bruce Bowen': 55,
#   'Andrei Kirlienko': 44,
#   'Kobe Bryant': 28,
#   'Ben Wallace': 54,
#   'Jason Kidd': 28,
#   'Chauncey Billups': 23,
#   'Marcus Camby': 15,
#   'Tim Duncan': 23,
#   'Kevin Garnett': 18,
#   'Tayshaun Prince': 13},
#  5: {'Shaquille O’Neal': 16,
#   'Allen Iverson': 14,
#   'Kobe Bryant': 12,
#   'Shawn Marion': 9,
#   'Manu Ginobili': 9,
#   'Rasheed Wallace': 8,
#   'Kenyon Martin': 6,
#   'Tony Parker': 5,
#   'Andre Iguodala': 5,
#   'Shane Battier': 4,
#   'Andre Miller': 4,
#   'Tyson Chandler': 3,
#   'Trenton Hassell': 3,
#   'Kirk Hinrich': 3,
#   'Joe Johnson': 3,
#   'Earl Watson': 3,
#   'Udonis Haslem': 2,
#   'Tracy McGrady': 2,
#   'Josh Howard': 2,
#   'Joel Przybilla': 2,
#   'Desmond Mason': 2,
#   'Brevin Knight': 2,
#   'Vince Carter': 1,
#   'P.J. Brown': 1,
#   'Mickael Pietrus': 1,
#   'Kurt Thomas': 1,
#   'Jeff Foster': 1,
#   'Greg Buckner': 1,
#   'Gilbert Arenas': 1,
#   'Gary Payton': 1,
#   'Emeka Okafor': 1,
#   'Eddie Jones': 1,
#   'Clifford Robinson': 1,
#   'Brendan Haywood': 1,
#   'Anthony Johnson': 1,
#   'Andres Nocioni': 1,
#   'Amaré Stoudemire': 1,
#   'Ben Wallace': 51,
#   'Kevin Garnett': 48,
#   'Bruce Bowen': 48,
#   'Tim Duncan': 39,
#   'Larry Hughes': 22,
#   'Tayshaun Prince': 21,
#   'Marcus Camby': 21,
#   'Chauncey Billups': 17,
#   'Andrei Kirlienko': 17,
#   'Jason Kidd': 16,
#   'Dwyane Wade': 16}}

# %%
final_votes
# Out:
# [{17: {'Avery Bradley': 11.5,
#    'Klay Thompson': 11.25,
#    'John Wall': 9.5,
#    'DeAndre Jordan': 8.75,
#    'Paul Millsap': 8.75,
#    'Hassan Whiteside': 6.25,
#    'Marcus Smart': 5.25,
#    'Jimmy Butler': 4.5,
#    'LeBron James': 3.0,
#    'Robert Covington': 2.75,
#    'Russell Westbrook': 2.5,
#    'Paul George': 1.75,
#    'Kevin Durant': 1.5,
#    'Dwight Howard': 1.5,
#    'Mike Conley': 1.25,
#    'Jae Crowder': 1.25,
#    'Jrue Holiday': 1.25,
#    'Wesley Matthews': 1.0,
#    'Stephen Curry': 0.75,
#    'Andre Iguodala': 0.75,
#    'Michael Kidd-Gilchrist': 0.75,
#    'Ricky Rubio': 0.75,
#    'P.J. Tucker': 0.75,
#    'Trevor Ariza': 0.5,
#    'Nicolas Batum': 0.5,
#    'Marc Gasol': 0.5,
#    'Eric Gordon': 0.5,
#    'Karl-Anthony Towns': 0.5,
#    'Steven Adams': 0.25,
#    'LaMarcus Aldridge': 0.25,
#    'Al-Farouq Aminu': 0.25,
#    'Kentavious Caldwell-Pope': 0.25,
#    'George Hill': 0.25,
#    'Serge Ibaka': 0.25,
#    'Damian Lillard': 0.25,
#    'Luc Mbah a Moute': 0.25,
#    'Austin Rivers': 0.25,
#    'Isaiah Thomas': 0.25,
#    'Cody Zeller': 0.25,
#    'Kawhi Leonard': 48.0,
#    'Draymond Green': 49.5,
#    'Rudy Gobert': 49.0,
#    'Patrick Beverly': 27.5,
#    'Chris Paul': 35.0,
#    'Tony Allen': 20.0,
#    'Danny Green': 17.0,
#    'Andre Roberson': 13.25,
#    'Anthony Davis': 14.5,
#    'Giannis Antetokounmpo': 8.75}},
#  {16: {'Rudy Gobert': 16.0,
#    'Klay Thompson': 12.25,
#    'Jae Crowder': 11.75,
#    'LeBron James': 10.75,
#    'Kyle Lowry': 10.75,
#    'Danny Green': 9.75,
#    'Russell Westbrook': 8.75,
#    'Tim Duncan': 8.25,
#    'Ricky Rubio': 7.5,
#    'Kentavious Caldwell-Pope': 6.75,
#    'Anthony Davis': 6.0,
#    'Andre Drummond': 3.5,
#    'Serge Ibaka': 3.5,
#    'Stephen Curry': 3.25,
#    'Andre Iguodala': 3.25,
#    'Patrick Beverley': 2.75,
#    'Al Horford': 1.75,
#    'Marcus Smart': 1.75,
#    'John Wall': 1.5,
#    'Giannis Antetokounmpo': 0.75,
#    'Trevor Ariza': 0.75,
#    'Kent Bazemore': 0.75,
#    'Andrew Bogut': 0.75,
#    'DeMarcus Cousins': 0.75,
#    'Nicolas Batum': 0.5,
#    'Victor Oladipo': 0.5,
#    'LaMarcus Aldridge': 0.25,
#    'Harrison Barnes': 0.25,
#    'Bismack Biyombo': 0.25,
#    'Mike Conley': 0.25,
#    'Kevin Durant': 0.25,
#    'Derrick Favors': 0.25,
#    'George Hill': 0.25,
#    'Wesley Matthews': 0.25,
#    'Luc Mbah a Moute': 0.25,
#    'Kristaps Porzingis': 0.25,
#    'Andre Roberson': 0.25,
#    'Mike Scott': 0.25,
#    'Dwyane Wade': 0.25,
#    'Kawhi Leonard': 65.0,
#    'Draymond Green': 62.75,
#    'DeAndre Jordan': 34.25,
#    'Avery Bradley': 37.25,
#    'Chris Paul': 37.0,
#    'Paul Millsap': 24.25,
#    'Paul George': 12.0,
#    'Hassan Whiteside': 31.5,
#    'Tony Allen': 30.25,
#    'Jimmy Butler': 15.5}},
#  {15: {'Rudy Gobert': 13.5,
#    'LeBron James': 11.75,
#    'Russell Westbrook': 8.75,
#    'Avery Bradley': 6.5,
#    'Michael Kidd-Gilchrist': 5.25,
#    'Marc Gasol': 4.5,
#    'Danny Green': 4.5,
#    'Trevor Ariza': 4.25,
#    'Stephen Curry': 3.5,
#    'DeMarre Carroll': 2.75,
#    'Patrick Beverley': 2.5,
#    'Khris Middleton': 2.25,
#    'Serge Ibaka': 2.0,
#    'Andre Iguodala': 2.0,
#    'Paul Millsap': 2.0,
#    'Jeff Teague': 1.75,
#    'Mike Conley': 1.5,
#    'Joakim Noah': 1.5,
#    'Nerlens Noel': 1.25,
#    'P.J. Tucker': 1.0,
#    'Giannis Antetokounmpo': 0.75,
#    'Pau Gasol': 0.75,
#    'Wesley Matthews': 0.75,
#    'James Harden': 0.5,
#    'Marcus Smart': 0.5,
#    'Hassan Whiteside': 0.5,
#    'Eric Bledsoe': 0.25,
#    'DeMarcus Cousins': 0.25,
#    'Andre Drummond': 0.25,
#    'Manu Ginobili': 0.25,
#    'Blake Griffin': 0.25,
#    'George Hill': 0.25,
#    'Al Horford': 0.25,
#    'Victor Oladipo': 0.25,
#    'Zaza Pachulia': 0.25,
#    'Elfrid Payton': 0.25,
#    'Zach Randolph': 0.25,
#    'Rajon Rondo': 0.25,
#    'Iman Shumpert': 0.25,
#    'Dwyane Wade': 0.25,
#    'Kawhi Leonard': 60.5,
#    'Draymond Green': 57.25,
#    'Tony Allen': 51.75,
#    'DeAndre Jordan': 46.75,
#    'Chris Paul': 42.5,
#    'Anthony Davis': 38.75,
#    'Jimmy Butler': 33.0,
#    'Andrew Bogut': 25.5,
#    'John Wall': 16.75,
#    'Tim Duncan': 16.0}},
#  {14: {'DeAndre Jordan': 15.75,
#    'Anthony Davis': 15.5,
#    'Tony Allen': 15.0,
#    'Tim Duncan': 11.25,
#    'Dwight Howard': 6.5,
#    'Taj Gibson': 5.25,
#    'Mike Conley': 5.25,
#    'Ricky Rubio': 4.75,
#    'Lance Stephenson': 3.5,
#    'P.J. Tucker': 3.25,
#    'Kevin Durant': 2.5,
#    'Kyle Lowry': 2.5,
#    'Eric Bledsoe': 2.25,
#    'Marc Gasol': 2.0,
#    'John Wall': 2.0,
#    'Thabo Sefolosha': 2.0,
#    'Kirk Hinrich': 1.75,
#    'Trevor Ariza': 1.25,
#    'Avery Bradley': 1.25,
#    'Russell Westbrook': 1.25,
#    'Klay Thompson': 1.25,
#    'Andrew Bogut': 1.0,
#    'Chris Bosh': 1.0,
#    'Luol Deng': 1.0,
#    'Wesley Matthews': 1.0,
#    'Tony Parker': 1.0,
#    'Nicolas Batum': 0.75,
#    'Stephen Curry': 0.75,
#    'Danny Green': 0.75,
#    'Michael Kidd-Gilchrist': 0.75,
#    'Shaun Livingston': 0.75,
#    'Victor Oladipo': 0.75,
#    'DeMarre Carroll': 0.5,
#    'Matt Barnes': 0.5,
#    'James Harden': 0.5,
#    'George Hill': 0.5,
#    'Jeff Teague': 0.5,
#    'Dwyane Wade': 0.5,
#    'Kemba Walker': 0.5,
#    'David West': 0.5,
#    'Arron Afflalo': 0.25,
#    'Corey Brewer': 0.25,
#    'Michael Carter-Williams': 0.25,
#    'Darren Collison': 0.25,
#    'DeMar DeRozan': 0.25,
#    'Andre Drummond': 0.25,
#    'Monta Ellis': 0.25,
#    'Danny Granger': 0.25,
#    'Draymond Green': 0.25,
#    'Reggie Jackson': 0.25,
#    'David Lee': 0.25,
#    'Paul Millsap': 0.25,
#    'Rajon Rondo': 0.25,
#    'Joakim Noah': 55.75,
#    'Paul George': 40.25,
#    'Chris Paul': 39.0,
#    'Serge Ibaka': 38.0,
#    'Andre Igoudala': 37.0,
#    'Lebron James': 33.5,
#    'Patrick Beverly': 28.0,
#    'Jimmy Butler': 25.75,
#    'Kawhi Leonard': 22.25,
#    'Roy Hibbert': 19.0}},
#  {13: {'Andre Iguodala': 16,
#    'Larry Sanders': 16,
#    'Thabo Sefolosha': 15,
#    'Luol Deng': 11,
#    'Dwight Howard': 9,
#    'Kobe Bryant': 6,
#    'Roy Hibbert': 6,
#    'Kenneth Faried': 4,
#    'Russell Westbrook': 4,
#    'Shane Battier': 2,
#    'Nicolas Batum': 2,
#    'Corey Brewer': 2,
#    'George Hill': 2,
#    'Mike James': 2,
#    'Kawhi Leonard': 2,
#    'Tony Parker': 2,
#    'Dwyane Wade': 2,
#    'Metta World Peace': 2,
#    'Eric Bledsoe': 1,
#    'Kevin Durant': 1,
#    'Jrue Holiday': 1,
#    'Andrei Kirilenko': 1,
#    'Iman Shumpert': 1,
#    'David West': 1,
#    'Tony Allen': 53,
#    'Serge Ibaka': 46,
#    'Lebron James': 52,
#    'Chris Paul': 37,
#    'Joakim Noah': 24,
#    'Tyson Chandler': 24,
#    'Avery Bradley': 25,
#    'Mike Conley': 19,
#    'Tim Duncan': 20,
#    'Marc Gasol': 12,
#    'Paul George': 27}},
#  {12: {'Andre Iguodala': 19,
#    'Joakim Noah': 14,
#    'Iman Shumpert': 13,
#    'Paul George': 10,
#    'Russell Westbrook': 9,
#    'Josh Smith': 8,
#    'Dwyane Wade': 5,
#    'Thabo Sefolosha': 5,
#    'Grant Hill': 5,
#    'Tim Duncan': 5,
#    'Avery Bradley': 3,
#    'Marc Gasol': 3,
#    'Metta World Peace': 3,
#    'Shawn Marion': 3,
#    'Joe Johnson': 2,
#    'Mike Conley': 2,
#    'Derrick Rose': 1,
#    'Jrue Holiday': 1,
#    'Carlos Boozer': 1,
#    'Luc Mbah a Moute': 1,
#    'Tony Allen': 33,
#    'Dwight Howard': 41,
#    'Serge Ibaka': 47,
#    'Lebron James': 53,
#    'Chris Paul': 35,
#    'Kobe Bryant': 17,
#    'Tyson Chandler': 36,
#    'Luol Deng': 20,
#    'Kevin Garnett': 26,
#    'Rajon Rondo': 29}},
#  {11: {'Derrick Rose': 14,
#    'Dwyane Wade': 13,
#    'Russell Westbrook': 13,
#    'Gerald Wallace': 11,
#    'Grant Hill': 11,
#    'Luol Deng': 11,
#    'Tim Duncan': 11,
#    'Chuck Hayes': 10,
#    'Al Horford': 7,
#    'Josh Smith': 7,
#    'Ron Artest': 7,
#    'Serge Ibaka': 6,
#    'Shane Battier': 5,
#    'Thabo Sefolosha': 5,
#    'Wesley Matthews': 4,
#    'Kendrick Perkins': 3,
#    'Nicolas Batum': 3,
#    'Joe Johnson': 2,
#    'Keith Bogans': 2,
#    'Kyle Lowry': 2,
#    'Lamar Odom': 2,
#    'Luc Mbah a Moute': 2,
#    'Manu Ginobili': 2,
#    'Andrew Bogut': 1,
#    'Andrew Bynum': 1,
#    'Arron Afflalo': 1,
#    'Jrue Holiday': 1,
#    'Kirk Hinrich': 1,
#    'Nene Hilario': 1,
#    'Ronnie Brewer': 1,
#    'Shawn Marion': 1,
#    'Tayshaun Prince': 1,
#    'Kobe Bryant': 33,
#    'Kevin Garnett': 33,
#    'Dwight Howard': 56,
#    'Lebron James': 38,
#    'Rajon Rondo': 39,
#    'Tony Allen': 23,
#    'Tyson Chandler': 17,
#    'Andre Igoudala': 15,
#    'Joakim Noah': 15,
#    'Chis Paul': 18}},
#  {10: {'Jason Kidd': 12,
#    'Marcus Camby': 12,
#    'Ron Artest': 11,
#    'Deron Williams': 10,
#    'Kirk Hinrich': 9,
#    'Andrew Bogut': 8,
#    'Luc Mbah a Moute': 8,
#    'Arron Afflalo': 6,
#    'Kenyon Martin': 5,
#    'Kevin Garnett': 5,
#    'Grant Hill': 4,
#    'Joakim Noah': 4,
#    'Kendrick Perkins': 4,
#    'Shane Battier': 4,
#    'Andrei Kirilenko': 3,
#    'Russell Westbrook': 3,
#    'Trevor Ariza': 3,
#    'Andre Iguodala': 2,
#    'George Hill': 2,
#    'Jermaine O’Neal': 2,
#    'Joe Johnson': 2,
#    'Lamar Odom': 2,
#    'Luis Scola': 2,
#    'Manu Ginobili': 2,
#    'Nicolas Batum': 2,
#    'Caron Butler': 1,
#    'Chauncey Billups': 1,
#    'Jared Dudley': 1,
#    'Kevin Durant': 1,
#    'Raymond Felton': 1,
#    'Marc Gasol': 1,
#    'Pau Gasol': 1,
#    'Chuck Hayes': 1,
#    'Brendan Haywood': 1,
#    'Al Horford': 1,
#    'Serge Ibaka': 1,
#    'Ersan Ilyasova': 1,
#    'Stephen Jackson': 1,
#    'Nene Hilario': 1,
#    'Chris Paul': 1,
#    'Tayshaun Prince': 1,
#    'Earl Watson': 1,
#    'Kobe Bryant': 34,
#    'Dwight Howard': 57,
#    'Lebron James': 45,
#    'Rajon Rondo': 50,
#    'Gerald Wallace': 30,
#    'Tim Duncan': 21,
#    'Thabo Sefolosha': 14,
#    'Josh Smith': 20,
#    'Anderson Varejao': 15,
#    'Dwyane Wade': 20}},
#  {9: {'Tayshaun Prince': 15,
#    'Raja Bell': 8,
#    'Joel Przybilla': 7,
#    'Chauncey Billups': 5,
#    'Ronnie Brewer': 5,
#    'Andre Iguodala': 5,
#    'Yao Ming': 5,
#    'Emeka Okafor': 5,
#    'Kendrick Perkins': 4,
#    'Samuel Dalembert': 3,
#    'Derek Fisher': 3,
#    'Udonis Haslem': 3,
#    'Jason Kidd': 3,
#    'Anderson Varejao': 3,
#    'Deron Williams': 3,
#    'Trevor Ariza': 2,
#    'Kirk Hinrich': 2,
#    'Joe Johnson': 2,
#    'Andrei Kirilenko': 2,
#    'David Lee': 2,
#    'James Posey': 2,
#    'J.R. Smith': 2,
#    'Gerald Wallace': 2,
#    'NenFe': 1,
#    'Chris Andersen': 1,
#    'Pau Gasol': 1,
#    'Antonio McDyess': 1,
#    'Andre Miller': 1,
#    'Travis Outlaw': 1,
#    'Brandon Roy': 1,
#    'Rasheed Wallace': 1,
#    'Kobe Bryant': 53,
#    'Kevin Garnett': 35,
#    'Dwight Howard': 55,
#    'Lebron James': 47,
#    'Chris Paul': 36,
#    'Metta World Peace': 22,
#    'Shane Battier': 22,
#    'Tim Duncan': 30,
#    'Rajon Rondo': 23,
#    'Dwyane Wade': 26}},
#  {8: {'Chauncey Billups': 14,
#    'Jason Kidd': 13,
#    'Rasheed Wallace': 13,
#    'Rajon Rondo': 11,
#    'Deron Williams': 8,
#    'Josh Smith': 8,
#    'Ron Artest': 8,
#    'Tyson Chandler': 8,
#    'Andrei Kirilenko': 6,
#    'Derek Fisher': 4,
#    'LeBron James': 4,
#    'Manu Ginobili': 4,
#    'Kirk Hinrich': 3,
#    'Samuel Dalembert': 3,
#    'Andre Iguodala': 2,
#    'Brandon Roy': 2,
#    'Paul Pierce': 2,
#    'Andre Miller': 1,
#    'Andres Nocioni': 1,
#    'Baron Davis': 1,
#    'Caron Butler': 1,
#    'Chris Bosh': 1,
#    'Dikembe Mutombo': 1,
#    'Josh Howard': 1,
#    'Richard Hamilton': 1,
#    'Ronnie Brewer': 1,
#    'Bruce Bowen': 36,
#    'Kobe Bryant': 52,
#    'Marcus Camby': 37,
#    'Tim Duncan': 33,
#    'Kevin Garnett': 52,
#    'Shane Battier': 29,
#    'Raja Bell': 18,
#    'Dwight Howard': 25,
#    'Chris Paul': 26,
#    'Tayshaun Prince': 20}},
#  {7: {'Shane Battier': 17,
#    'Shawn Marion': 15,
#    'Chauncey Billups': 13,
#    'Ron Artest': 12,
#    'Gerald Wallace': 11,
#    'Alonzo Mourning': 9,
#    'Devin Harris': 8,
#    'Tyson Chandler': 8,
#    'Josh Howard': 7,
#    'Emeka Okafor': 6,
#    'Luol Deng': 5,
#    'Rasheed Wallace': 5,
#    'Dwight Howard': 5,
#    'Andrei Kirilenko': 5,
#    'Josh Smith': 4,
#    'Manu Ginobili': 4,
#    'Richard Hamilton': 3,
#    'Jermaine O’Neal': 3,
#    'Andre Iguodala': 3,
#    'Deron Williams': 3,
#    'Elton Brand': 2,
#    'Dwyane Wade': 2,
#    'Trenton Hassell': 2,
#    'Tony Parker': 2,
#    'Caron Butler': 2,
#    'Chris Duhon': 1,
#    'Allen Iverson': 1,
#    'Udonis Haslem': 1,
#    'Richard Jefferson': 1,
#    'Chris Paul': 1,
#    'Andre Miller': 1,
#    'Joel Przybilla': 1,
#    'Francisco Elson': 1,
#    'Chris Bosh': 1,
#    'Gilbert Arenas': 1,
#    'Raja Bell': 25,
#    'Bruce Bowen': 42,
#    'Kobe Bryant': 32,
#    'Marcus Camby': 34,
#    'Tim Duncan': 36,
#    'Kevin Garnett': 20,
#    'Kirk Hinrich': 18,
#    'Jason Kidd': 23,
#    'Tayshaun Prince': 21,
#    'Ben Wallace': 33}},
#  {6: {'Rasheed Wallace': 12,
#    'Gerald Wallace': 11,
#    'Shawn Marion': 11,
#    'Raja Bell': 9,
#    'Dwyane Wade': 8,
#    'Kirk Hinrich': 7,
#    'Alonzo Mourning': 7,
#    'Shane Battier': 6,
#    'Gilbert Arenas': 4,
#    'Andre Iguodala': 4,
#    'P.J. Brown': 3,
#    'Manu Ginobili': 3,
#    'Dwight Howard': 3,
#    'Josh Howard': 3,
#    'Brevin Knight': 3,
#    'Shaquille O’Neal': 3,
#    'Elton Brand': 2,
#    'LeBron James': 2,
#    'Tony Parker': 2,
#    'Quinton Ross': 2,
#    'Allen Iverson': 2,
#    'Eddie Jones': 2,
#    'Jason Collins': 1,
#    'Boris Diaw': 1,
#    'Pau Gasol': 1,
#    'Trenton Hassel': 1,
#    'Mike James': 1,
#    'Richard Jefferson': 1,
#    'Ruben Patterson': 1,
#    'Chris Paul': 1,
#    'Jason Terry': 1,
#    'Yao Ming': 1,
#    'Metta World Peace': 30,
#    'Bruce Bowen': 55,
#    'Andrei Kirlienko': 44,
#    'Kobe Bryant': 28,
#    'Ben Wallace': 54,
#    'Jason Kidd': 28,
#    'Chauncey Billups': 23,
#    'Marcus Camby': 15,
#    'Tim Duncan': 23,
#    'Kevin Garnett': 18,
#    'Tayshaun Prince': 13}},
#  {5: {'Shaquille O’Neal': 16,
#    'Allen Iverson': 14,
#    'Kobe Bryant': 12,
#    'Shawn Marion': 9,
#    'Manu Ginobili': 9,
#    'Rasheed Wallace': 8,
#    'Kenyon Martin': 6,
#    'Tony Parker': 5,
#    'Andre Iguodala': 5,
#    'Shane Battier': 4,
#    'Andre Miller': 4,
#    'Tyson Chandler': 3,
#    'Trenton Hassell': 3,
#    'Kirk Hinrich': 3,
#    'Joe Johnson': 3,
#    'Earl Watson': 3,
#    'Udonis Haslem': 2,
#    'Tracy McGrady': 2,
#    'Josh Howard': 2,
#    'Joel Przybilla': 2,
#    'Desmond Mason': 2,
#    'Brevin Knight': 2,
#    'Vince Carter': 1,
#    'P.J. Brown': 1,
#    'Mickael Pietrus': 1,
#    'Kurt Thomas': 1,
#    'Jeff Foster': 1,
#    'Greg Buckner': 1,
#    'Gilbert Arenas': 1,
#    'Gary Payton': 1,
#    'Emeka Okafor': 1,
#    'Eddie Jones': 1,
#    'Clifford Robinson': 1,
#    'Brendan Haywood': 1,
#    'Anthony Johnson': 1,
#    'Andres Nocioni': 1,
#    'Amaré Stoudemire': 1,
#    'Ben Wallace': 51,
#    'Kevin Garnett': 48,
#    'Bruce Bowen': 48,
#    'Tim Duncan': 39,
#    'Larry Hughes': 22,
#    'Tayshaun Prince': 21,
#    'Marcus Camby': 21,
#    'Chauncey Billups': 17,
#    'Andrei Kirlienko': 17,
#    'Jason Kidd': 16,
#    'Dwyane Wade': 16}}]

# %%
adv_dict[0][17].update(adlrev[0][17])

# %%
adv_dict[0][17]
# Out:
# {'Avery Bradley': 11.5,
#  'Klay Thompson': 11.25,
#  'John Wall': 9.5,
#  'DeAndre Jordan': 8.75,
#  'Paul Millsap': 8.75,
#  'Hassan Whiteside': 6.25,
#  'Marcus Smart': 5.25,
#  'Jimmy Butler': 4.5,
#  'LeBron James': 3.0,
#  'Robert Covington': 2.75,
#  'Russell Westbrook': 2.5,
#  'Paul George': 1.75,
#  'Kevin Durant': 1.5,
#  'Dwight Howard': 1.5,
#  'Mike Conley': 1.25,
#  'Jae Crowder': 1.25,
#  'Jrue Holiday': 1.25,
#  'Wesley Matthews': 1.0,
#  'Stephen Curry': 0.75,
#  'Andre Iguodala': 0.75,
#  'Michael Kidd-Gilchrist': 0.75,
#  'Ricky Rubio': 0.75,
#  'P.J. Tucker': 0.75,
#  'Trevor Ariza': 0.5,
#  'Nicolas Batum': 0.5,
#  'Marc Gasol': 0.5,
#  'Eric Gordon': 0.5,
#  'Karl-Anthony Towns': 0.5,
#  'Steven Adams': 0.25,
#  'LaMarcus Aldridge': 0.25,
#  'Al-Farouq Aminu': 0.25,
#  'Kentavious Caldwell-Pope': 0.25,
#  'George Hill': 0.25,
#  'Serge Ibaka': 0.25,
#  'Damian Lillard': 0.25,
#  'Luc Mbah a Moute': 0.25,
#  'Austin Rivers': 0.25,
#  'Isaiah Thomas': 0.25,
#  'Cody Zeller': 0.25,
#  'Kawhi Leonard': 48.0,
#  'Draymond Green': 49.5,
#  'Rudy Gobert': 49.0,
#  'Patrick Beverly': 27.5,
#  'Chris Paul': 35.0,
#  'Tony Allen': 20.0,
#  'Danny Green': 17.0,
#  'Andre Roberson': 13.25,
#  'Anthony Davis': 14.5,
#  'Giannis Antetokounmpo': 8.75}

# %%
a = [{17:{"a":1,"b":2,"c":3}}]
b = [{17:{"d":1,"e":2,"f":3}}]

# %%
a[0][17].update(b[0][17])

# %%
a[0]
# Out:
# {17: {'a': 1, 'b': 2, 'c': 3, 'd': 1, 'e': 2, 'f': 3}}

# %%
c = [{k,v f}]

# %%
a[0]
# Out:
# {17: {'d': 1, 'e': 2, 'f': 3}, 'd': 1, 'e': 2, 'f': 3}

# %%
# %run process_players

# %%
ap_merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-fa37ae8ed735> in <module>
# ----> 1 ap_merged
#
# NameError: name 'ap_merged' is not defined

# %%
from process_players import *

# %%
pdata = get_clean_pdata()

# %%
pdata
# Out:
#                  Player Pos  Age   G    MP   PER    TS%   3PAr    FTr  ORB%  \
# 1933      Allen Iverson  SG   32  82  3424  20.9  0.567  0.177  0.512   1.5
# 2344     Gilbert Arenas  PG   24  80  3384  23.8  0.581  0.324  0.479   2.0
# 1646       LeBron James  SF   21  79  3361  28.1  0.568  0.208  0.447   2.6
# 5016        Joe Johnson  SG   26  82  3343  17.3  0.535  0.297  0.253   2.9
# 4985        Joe Johnson  SG   24  82  3340  17.9  0.537  0.258  0.237   3.4
# 2352     Antawn Jamison  SF   29  82  3288  17.7  0.518  0.250  0.199   5.7
# 6297        Kobe Bryant  SG   27  80  3277  28.0  0.559  0.238  0.377   2.6
# 4563     Andre Iguodala  SF   25  82  3269  18.4  0.560  0.228  0.454   3.3
# 4290       Shawn Marion  PF   27  81  3263  23.6  0.591  0.212  0.218   8.7
# 4551     Andre Iguodala  SF   24  82  3242  19.0  0.543  0.240  0.396   3.1
# 6776       Kevin Durant  SF   21  82  3239  26.2  0.607  0.210  0.504   3.8
# 5740        Monta Ellis  SG   25  80  3227  18.6  0.536  0.235  0.268   1.5
# 6306         Lamar Odom  PF   26  80  3221  17.0  0.558  0.232  0.338   6.6
# 5952  LaMarcus Aldridge  PF   25  81  3211  21.5  0.549  0.016  0.314  10.1
# 539           Luol Deng  SF   25  82  3208  15.5  0.549  0.288  0.291   4.4
# 6560  Richard Jefferson  SF   27  82  3200  17.4  0.571  0.160  0.511   3.4
# 5684        Baron Davis  PG   28  82  3196  19.8  0.523  0.344  0.278   3.1
# 4579     Andre Iguodala  SF   26  82  3193  17.8  0.535  0.271  0.384   3.0
# 6329        Kobe Bryant  SG   29  82  3192  24.2  0.576  0.246  0.439   3.4
# 2616     Jamal Crawford  SG   27  80  3190  16.0  0.528  0.355  0.274   1.3
# 1660       LeBron James  SF   22  78  3190  24.5  0.552  0.191  0.432   3.0
# 3345           Rudy Gay  SF   23  80  3175  16.2  0.535  0.157  0.311   4.2
# 5997     Damian Lillard  PG   22  82  3167  16.4  0.546  0.391  0.249   1.5
# 1            Mike Bibby  PG   27  82  3167  17.9  0.554  0.360  0.292   1.1
# 1290   Jason Richardson  SF   27  82  3149  18.4  0.554  0.408  0.225   2.9
# 5750      Dorell Wright  SF   25  82  3147  15.0  0.539  0.450  0.199   3.1
# 2124    Morris Peterson  SG   28  82  3140  15.3  0.561  0.409  0.268   2.4
# 6314        Kobe Bryant  SG   28  77  3140  26.1  0.580  0.227  0.437   2.8
# 3276          Pau Gasol  PF   25  80  3135  22.7  0.555  0.010  0.517   7.5
# 5211       Michael Redd  SG   26  80  3130  21.2  0.574  0.272  0.377   2.9
# ...                 ...  ..  ...  ..   ...   ...    ...    ...    ...   ...
# 3648         Nick Young  SG   26  22   518   9.9  0.509  0.440  0.202   2.5
# 2350       Jarvis Hayes  SG   24  21   516  12.2  0.499  0.257  0.164   4.2
# 2497      Al Harrington  PF   33  34   511   9.7  0.506  0.483  0.169   3.3
# 786    Brian Scalabrine   C   30  39   504   7.4  0.558  0.535  0.158   1.8
# 4297       Marcus Banks  PG   25  45   503  11.3  0.497  0.148  0.306   2.4
# 6818     Reggie Jackson  PG   21  45   501   9.2  0.408  0.390  0.182   3.4
# 4978    Esteban Batista  PF   22  57   495   7.1  0.489  0.013  0.663  14.4
# 1313   Jason Richardson  SG   28  14   491  15.8  0.536  0.268  0.250   3.3
# 4521   Shavlik Randolph  PF   22  57   487  12.6  0.511  0.000  0.732  13.2
# 6389        Luke Walton  SF   30  54   484   5.1  0.378  0.293  0.086   2.2
# 5629       Al Jefferson   C   33  36   484  20.2  0.563  0.014  0.173   7.0
# 3673       Ryan Hollins  PF   29  61   482  11.9  0.730  0.000  0.778   7.4
# 6013        CJ McCollum  SG   22  38   476   9.0  0.521  0.449  0.191   1.6
# 32           Mike Bibby  PG   29  15   473  13.5  0.494  0.318  0.161   2.8
# 1080        Jordan Hill   C   24  32   469  15.1  0.529  0.022  0.289  11.5
# 5683    Austin Croshere  PF   32  44   457  13.2  0.573  0.445  0.234   7.4
# 4315     Gordan Giricek  SG   30  22   442  12.3  0.580  0.314  0.107   2.5
# 2011      Evan Fournier  SG   20  38   428  13.8  0.597  0.355  0.257   1.6
# 3386       Jeremy Pargo  PG   25  44   424   4.4  0.389  0.253  0.180   3.2
# 4288        Jim Jackson  SF   35  27   420   3.2  0.367  0.488  0.101   3.0
# 2634   Danilo Gallinari  SG   20  28   412  13.4  0.621  0.576  0.216   3.3
# 6835        Eric Maynor  PG   25  37   391   7.5  0.419  0.400  0.183   1.6
# 239           Tony Delk  PG   32  23   378  16.1  0.526  0.294  0.156   4.0
# 5696     Brandan Wright  PF   20  38   376  17.2  0.583  0.000  0.357  10.4
# 1926      Chucky Atkins  SG   33  24   352   8.9  0.449  0.648  0.074   0.9
# 6298       Andrew Bynum   C   18  46   338   7.4  0.394  0.000  0.329  11.9
# 6786        Etan Thomas   C   31  23   321   6.9  0.483  0.000  0.324   6.6
# 361     Josh Harrellson   C   24  32   317  13.4  0.547  0.378  0.085   9.8
# 4273   Shabazz Muhammad  SF   25  32   301   9.3  0.446  0.157  0.256   5.7
# 4308         Jalen Rose  SF   34  29   246  13.4  0.592  0.547  0.140   1.5
#
#         ...        WS  WS/48  OBPM  DBPM  BPM  VORP  \
# 1933    ...      11.6  0.163   3.5  -1.9  1.6   3.1
# 2344    ...      13.6  0.193   6.9  -1.4  5.5   6.4
# 1646    ...      16.3  0.232   7.9   1.4  9.3   9.5
# 5016    ...       7.0  0.100   3.1  -1.9  1.1   2.7
# 4985    ...       6.0  0.086   3.0  -2.4  0.7   2.2
# 2352    ...       8.2  0.119   1.0  -1.0  0.0   1.6
# 6297    ...      15.3  0.224   7.3  -1.5  5.8   6.5
# 4563    ...       9.2  0.134   2.8   1.0  3.8   4.8
# 4290    ...      14.6  0.214   2.9   2.3  5.3   5.9
# 4551    ...       9.6  0.143   2.9   1.5  4.3   5.2
# 6776    ...      16.1  0.238   4.9   0.2  5.1   5.8
# 5740    ...       6.0  0.089   2.0  -1.8  0.2   1.8
# 6306    ...       9.2  0.137   1.7   1.7  3.4   4.4
# 5952    ...      11.1  0.166   1.9   0.5  2.4   3.5
# 539     ...       9.9  0.149   1.2   1.0  2.2   3.4
# 6560    ...       7.6  0.114   2.0  -2.0  0.0   1.6
# 5684    ...       8.7  0.131   3.7  -0.1  3.6   4.5
# 4579    ...       6.7  0.101   1.9   0.8  2.7   3.8
# 6329    ...      13.8  0.208   5.1   0.3  5.4   6.0
# 2616    ...       5.0  0.076   2.5  -2.7 -0.2   1.5
# 1660    ...      13.7  0.206   5.4   2.0  7.4   7.6
# 3345    ...       6.4  0.096   0.7  -0.2  0.4   1.9
# 5997    ...       5.8  0.088   2.7  -2.4  0.3   1.9
# 1       ...       8.4  0.127   3.2  -2.3  1.0   2.4
# 1290    ...       7.4  0.113   3.5  -0.7  2.8   3.8
# 5750    ...       5.8  0.088   1.5  -0.4  1.1   2.5
# 2124    ...       5.9  0.090   2.4  -1.4  1.0   2.4
# 6314    ...      13.0  0.199   6.1  -1.4  4.7   5.3
# 3276    ...      12.0  0.184   2.0   3.1  5.1   5.6
# 5211    ...      10.8  0.166   4.5  -2.0  2.4   3.5
# ...     ...       ...    ...   ...   ...  ...   ...
# 3648    ...       0.4  0.040  -1.2  -2.7 -3.8  -0.2
# 2350    ...       0.7  0.065  -1.1  -1.3 -2.5  -0.1
# 2497    ...       0.4  0.035  -2.2  -2.4 -4.6  -0.3
# 786     ...       1.1  0.105  -1.4   0.0 -1.4   0.1
# 4297    ...       0.4  0.037  -2.8  -1.3 -4.1  -0.3
# 6818    ...       0.1  0.011  -2.6  -1.3 -3.9  -0.2
# 4978    ...       0.1  0.011  -4.9  -1.7 -6.6  -0.6
# 1313    ...       1.1  0.104   1.0  -1.4 -0.4   0.2
# 4521    ...       1.1  0.105  -2.4   0.0 -2.4   0.0
# 6389    ...      -0.2 -0.016  -5.7  -0.5 -6.2  -0.5
# 5629    ...       1.6  0.158  -1.7   1.3 -0.5   0.2
# 3673    ...       1.3  0.126  -2.0   1.7 -0.3   0.2
# 6013    ...       0.2  0.019  -2.1  -2.0 -4.1  -0.3
# 32      ...       0.3  0.035   0.1  -1.7 -1.6   0.1
# 1080    ...       1.1  0.118  -2.8   0.6 -2.3   0.0
# 5683    ...       1.1  0.112  -0.1  -1.6 -1.7   0.0
# 4315    ...       0.7  0.076   0.0  -2.0 -2.0   0.0
# 2011    ...       1.0  0.115   1.0  -2.0 -0.9   0.1
# 3386    ...      -0.8 -0.085  -5.7  -2.0 -7.7  -0.6
# 4288    ...      -0.7 -0.075  -6.0  -0.2 -6.2  -0.4
# 2634    ...       1.0  0.119   0.7  -1.3 -0.6   0.1
# 6835    ...       0.0 -0.003  -3.9  -4.5 -8.4  -0.6
# 239     ...       0.9  0.111   0.6  -1.3 -0.7   0.1
# 5696    ...       1.1  0.142  -1.8  -0.6 -2.4   0.0
# 1926    ...       0.3  0.040  -1.1  -2.9 -4.0  -0.2
# 6298    ...       0.1  0.007  -6.3   0.5 -5.8  -0.3
# 6786    ...       0.2  0.028  -6.5  -0.2 -6.7  -0.4
# 361     ...       0.7  0.108  -0.5   0.2 -0.2   0.1
# 4273    ...       0.0  0.008  -4.2  -4.2 -8.4  -0.5
# 4308    ...       0.6  0.111   1.1  -2.2 -1.1   0.1
#
#                                 TM  YR  YRprior        MPG
# 1933          Denver Nuggets 07-08   8        7  41.756098
# 2344      Washington Wizards 05-06   6        5  42.300000
# 1646     Cleveland Cavaliers 05-06   6        5  42.544304
# 5016           Atlanta Hawks 07-08   8        7  40.768293
# 4985           Atlanta Hawks 05-06   6        5  40.731707
# 2352      Washington Wizards 05-06   6        5  40.097561
# 6297      Los Angeles Lakers 05-06   6        5  40.962500
# 4563      Philadelphia 76ers 08-09   9        8  39.865854
# 4290            Phoenix Suns 05-06   6        5  40.283951
# 4551      Philadelphia 76ers 07-08   8        7  39.536585
# 6776   Oklahoma City Thunder 09-10  10        9  39.500000
# 5740   Golden State Warriors 10-11  11       10  40.337500
# 6306      Los Angeles Lakers 05-06   6        5  40.262500
# 5952  Portland Trail Blazers 10-11  11       10  39.641975
# 539            Chicago Bulls 10-11  11       10  39.121951
# 6560         New Jersey Nets 07-08   8        7  39.024390
# 5684   Golden State Warriors 07-08   8        7  38.975610
# 4579      Philadelphia 76ers 09-10  10        9  38.939024
# 6329      Los Angeles Lakers 07-08   8        7  38.926829
# 2616         New York Knicks 07-08   8        7  39.875000
# 1660     Cleveland Cavaliers 06-07   7        6  40.897436
# 3345       Memphis Grizzlies 09-10  10        9  39.687500
# 5997  Portland Trail Blazers 12-13  13       12  38.621951
# 1           Sacramento Kings 05-06   6        5  38.621951
# 1290       Charlotte Bobcats 07-08   8        7  38.402439
# 5750   Golden State Warriors 10-11  11       10  38.378049
# 2124         Toronto Raptors 05-06   6        5  38.292683
# 6314      Los Angeles Lakers 06-07   7        6  40.779221
# 3276       Memphis Grizzlies 05-06   6        5  39.187500
# 5211         Milwaukee Bucks 05-06   6        5  39.125000
# ...                            ...  ..      ...        ...
# 3648    Los Angeles Clippers 11-12  12       11  23.545455
# 2350      Washington Wizards 05-06   6        5  24.571429
# 2497      Washington Wizards 13-14  14       13  15.029412
# 786           Boston Celtics 08-09   9        8  12.923077
# 4297            Phoenix Suns 06-07   7        6  11.177778
# 6818   Oklahoma City Thunder 11-12  12       11  11.133333
# 4978           Atlanta Hawks 05-06   6        5   8.684211
# 1313       Charlotte Bobcats 08-09   9        8  35.071429
# 4521      Philadelphia 76ers 05-06   6        5   8.543860
# 6389      Los Angeles Lakers 10-11  11       10   8.962963
# 5629          Indiana Pacers 17-18  18       17  13.444444
# 3673    Los Angeles Clippers 13-14  14       13   7.901639
# 6013  Portland Trail Blazers 13-14  14       13  12.526316
# 32          Sacramento Kings 07-08   8        7  31.533333
# 1080         Houston Rockets 11-12  12       11  14.656250
# 5683   Golden State Warriors 07-08   8        7  10.386364
# 4315            Phoenix Suns 07-08   8        7  20.090909
# 2011          Denver Nuggets 12-13  13       12  11.263158
# 3386       Memphis Grizzlies 11-12  12       11   9.636364
# 4288            Phoenix Suns 05-06   6        5  15.555556
# 2634         New York Knicks 08-09   9        8  14.714286
# 6835   Oklahoma City Thunder 12-13  13       12  10.567568
# 239          Detroit Pistons 05-06   6        5  16.434783
# 5696   Golden State Warriors 07-08   8        7   9.894737
# 1926          Denver Nuggets 07-08   8        7  14.666667
# 6298      Los Angeles Lakers 05-06   6        5   7.347826
# 6786   Oklahoma City Thunder 09-10  10        9  13.956522
# 361          Detroit Pistons 13-14  14       13   9.906250
# 4273  Minnesota Timberwolves 17-18  18       17   9.406250
# 4308            Phoenix Suns 06-07   7        6   8.482759
#
# [3900 rows x 29 columns]

# %%
# %run add_touches

# %%
btgm
# Out:
#                                Age     G      MP    PER     TS%    3PAr  \
# TM
# Atlanta Hawks 13-14           27.9  66.2  1748.7  15.47  0.5624  0.3247
# Atlanta Hawks 14-15           27.8  70.2  1751.9  15.65  0.5589  0.3659
# Atlanta Hawks 15-16           28.0  71.4  1798.5  14.90  0.5598  0.3413
# Atlanta Hawks 16-17           27.7  67.0  1710.0  13.58  0.5449  0.3237
# Atlanta Hawks 17-18           26.1  62.2  1528.4  14.38  0.5561  0.3593
# Boston Celtics 13-14          25.2  65.0  1652.5  13.76  0.5146  0.2433
# Boston Celtics 14-15          24.9  62.4  1631.9  14.84  0.5165  0.2562
# Boston Celtics 15-16          25.3  74.0  1842.2  15.01  0.5350  0.2732
# Boston Celtics 16-17          25.6  73.5  1831.3  14.63  0.5598  0.3895
# Boston Celtics 17-18          24.9  68.7  1749.8  14.46  0.5464  0.3675
# Brooklyn Nets 13-14           30.3  68.6  1673.4  15.17  0.5559  0.2504
# Brooklyn Nets 14-15           29.4  64.4  1716.2  14.99  0.5327  0.2532
# Brooklyn Nets 15-16           27.3  66.2  1652.3  13.82  0.5164  0.2511
# Brooklyn Nets 16-17           25.8  67.1  1564.8  12.94  0.5447  0.3669
# Brooklyn Nets 17-18           24.7  67.7  1717.9  14.31  0.5599  0.4008
# Charlotte Bobcats 13-14       24.8  69.0  1759.7  14.26  0.5408  0.2437
# Charlotte Hornets 14-15       25.7  64.2  1661.2  13.71  0.5048  0.1941
# Charlotte Hornets 15-16       25.7  68.2  1749.7  14.95  0.5354  0.3360
# Charlotte Hornets 16-17       26.8  67.8  1808.2  15.10  0.5507  0.2784
# Charlotte Hornets 17-18       26.1  71.4  1757.7  14.34  0.5391  0.3374
# Chicago Bulls 13-14           29.0  70.1  1911.3  13.92  0.5153  0.2337
# Chicago Bulls 14-15           28.7  68.8  1886.4  15.22  0.5334  0.2969
# Chicago Bulls 15-16           26.7  67.9  1707.9  14.20  0.5240  0.2623
# Chicago Bulls 16-17           27.0  64.8  1604.2  15.62  0.5419  0.2319
# Chicago Bulls 17-18           24.4  65.9  1637.1  13.16  0.5309  0.3024
# Cleveland Cavaliers 13-14     25.3  66.6  1689.1  14.22  0.5272  0.2351
# Cleveland Cavaliers 14-15     26.5  58.8  1674.5  15.78  0.5446  0.3125
# Cleveland Cavaliers 15-16     28.2  68.6  1801.4  15.11  0.5541  0.3404
# Cleveland Cavaliers 16-17     29.8  65.0  1728.7  14.81  0.5722  0.4576
# Cleveland Cavaliers 17-18     30.8  64.2  1539.6  14.96  0.5861  0.4058
# ...                            ...   ...     ...    ...     ...     ...
# Portland Trail Blazers 13-14  25.7  69.9  1866.8  14.77  0.5409  0.2914
# Portland Trail Blazers 14-15  27.3  64.0  1697.8  15.18  0.5506  0.3508
# Portland Trail Blazers 15-16  24.1  77.0  1906.5  14.68  0.5488  0.2944
# Portland Trail Blazers 16-17  25.0  68.5  1819.0  14.15  0.5487  0.2789
# Portland Trail Blazers 17-18  25.5  74.0  1859.0  14.24  0.5461  0.3319
# Sacramento Kings 13-14        24.3  63.9  1640.8  13.63  0.5170  0.2250
# Sacramento Kings 14-15        25.2  68.7  1728.0  14.51  0.5414  0.2236
# Sacramento Kings 15-16        26.2  68.9  1814.6  14.89  0.5548  0.2420
# Sacramento Kings 16-17        28.5  64.4  1585.4  13.85  0.5539  0.3198
# Sacramento Kings 17-18        26.3  67.0  1667.2  14.09  0.5382  0.2687
# San Antonio Spurs 13-14       29.0  71.6  1701.9  16.89  0.5810  0.2503
# San Antonio Spurs 14-15       29.8  70.4  1708.0  16.86  0.5668  0.2282
# San Antonio Spurs 15-16       30.9  72.9  1705.0  16.89  0.5539  0.2256
# San Antonio Spurs 16-17       30.9  72.3  1707.4  16.30  0.5643  0.2665
# San Antonio Spurs 17-18       29.3  73.8  1707.3  15.22  0.5454  0.3405
# Toronto Raptors 13-14         26.0  64.8  1786.4  14.89  0.5421  0.2634
# Toronto Raptors 14-15         26.2  75.4  1927.2  16.22  0.5642  0.2736
# Toronto Raptors 15-16         26.7  68.8  1818.1  15.40  0.5466  0.2866
# Toronto Raptors 16-17         25.7  67.3  1693.6  15.88  0.5681  0.3025
# Toronto Raptors 17-18         25.5  76.3  1801.5  16.51  0.5828  0.3751
# Utah Jazz 13-14               25.1  70.5  1832.9  13.35  0.5143  0.2535
# Utah Jazz 14-15               23.5  69.4  1771.2  14.45  0.5247  0.2994
# Utah Jazz 15-16               24.2  69.5  1734.8  14.52  0.5413  0.3028
# Utah Jazz 16-17               27.4  66.6  1711.4  14.66  0.5588  0.3199
# Utah Jazz 17-18               26.4  68.0  1667.6  15.34  0.5715  0.3171
# Washington Wizards 13-14      26.8  67.8  1788.5  14.03  0.5343  0.2384
# Washington Wizards 14-15      28.7  70.7  1738.5  14.44  0.5315  0.1919
# Washington Wizards 15-16      27.8  64.9  1735.3  15.00  0.5560  0.2734
# Washington Wizards 16-17      25.8  68.6  1775.1  14.64  0.5646  0.2936
# Washington Wizards 17-18      27.4  73.9  1840.6  14.92  0.5690  0.2845
#
#                                  FTr  ORB%   DRB%   TRB%       ...        \
# TM                                                             ...
# Atlanta Hawks 13-14           0.2539  4.57  15.55  10.11       ...
# Atlanta Hawks 14-15           0.2732  4.31  14.98   9.80       ...
# Atlanta Hawks 15-16           0.2306  3.83  14.39   9.23       ...
# Atlanta Hawks 16-17           0.2847  4.10  14.43   9.34       ...
# Atlanta Hawks 17-18           0.2567  4.18  14.88   9.53       ...
# Boston Celtics 13-14          0.2606  5.49  14.55   9.90       ...
# Boston Celtics 14-15          0.2367  5.22  16.10  10.58       ...
# Boston Celtics 15-16          0.2720  5.63  15.74  10.61       ...
# Boston Celtics 16-17          0.2472  4.32  15.70  10.05       ...
# Boston Celtics 17-18          0.2435  4.63  16.00  10.38       ...
# Brooklyn Nets 13-14           0.3531  4.90  15.93  10.43       ...
# Brooklyn Nets 14-15           0.2613  4.90  16.28  10.60       ...
# Brooklyn Nets 15-16           0.2473  4.57  15.09   9.75       ...
# Brooklyn Nets 16-17           0.2890  3.69  15.08   9.44       ...
# Brooklyn Nets 17-18           0.2644  4.50  15.52   9.97       ...
# Charlotte Bobcats 13-14       0.3574  4.92  16.08  10.47       ...
# Charlotte Hornets 14-15       0.3328  4.53  16.48  10.33       ...
# Charlotte Hornets 15-16       0.2713  4.23  17.21  10.67       ...
# Charlotte Hornets 16-17       0.3209  4.09  15.85   9.93       ...
# Charlotte Hornets 17-18       0.2936  3.94  14.45   9.10       ...
# Chicago Bulls 13-14           0.2860  5.82  15.29  10.63       ...
# Chicago Bulls 14-15           0.2948  5.13  14.37   9.86       ...
# Chicago Bulls 15-16           0.2113  4.76  14.40   9.67       ...
# Chicago Bulls 16-17           0.2488  6.08  16.06  11.02       ...
# Chicago Bulls 17-18           0.2315  4.55  16.09  10.11       ...
# Cleveland Cavaliers 13-14     0.2767  5.18  14.15   9.56       ...
# Cleveland Cavaliers 14-15     0.2539  5.51  14.24   9.94       ...
# Cleveland Cavaliers 15-16     0.2524  4.68  14.75   9.74       ...
# Cleveland Cavaliers 16-17     0.2464  4.15  14.96   9.73       ...
# Cleveland Cavaliers 17-18     0.2621  4.26  15.82  10.14       ...
# ...                              ...   ...    ...    ...       ...
# Portland Trail Blazers 13-14  0.2581  6.20  15.22  10.77       ...
# Portland Trail Blazers 14-15  0.2045  4.82  14.85   9.95       ...
# Portland Trail Blazers 15-16  0.2945  5.66  16.16  10.91       ...
# Portland Trail Blazers 16-17  0.2971  5.45  16.65  11.05       ...
# Portland Trail Blazers 17-18  0.2252  4.84  15.72  10.31       ...
# Sacramento Kings 13-14        0.3092  5.28  14.81   9.97       ...
# Sacramento Kings 14-15        0.3375  4.96  14.39   9.84       ...
# Sacramento Kings 15-16        0.2853  5.46  15.17  10.35       ...
# Sacramento Kings 16-17        0.2638  4.16  15.12   9.71       ...
# Sacramento Kings 17-18        0.1948  4.64  15.88  10.01       ...
# San Antonio Spurs 13-14       0.2521  4.87  15.44  10.36       ...
# San Antonio Spurs 14-15       0.2825  5.08  15.57  10.43       ...
# San Antonio Spurs 15-16       0.2225  4.43  15.91  10.38       ...
# San Antonio Spurs 16-17       0.2561  5.12  16.03  10.69       ...
# San Antonio Spurs 17-18       0.2326  4.53  15.85  10.15       ...
# Toronto Raptors 13-14         0.3212  5.89  15.34  10.58       ...
# Toronto Raptors 14-15         0.3244  5.40  14.89  10.14       ...
# Toronto Raptors 15-16         0.3139  5.25  15.84  10.63       ...
# Toronto Raptors 16-17         0.2683  4.93  15.02  10.00       ...
# Toronto Raptors 17-18         0.2365  5.01  15.74  10.48       ...
# Utah Jazz 13-14               0.2305  5.00  14.09   9.40       ...
# Utah Jazz 14-15               0.2857  5.92  15.41  10.69       ...
# Utah Jazz 15-16               0.2687  4.99  15.29  10.15       ...
# Utah Jazz 16-17               0.2674  4.08  14.40   9.37       ...
# Utah Jazz 17-18               0.2998  4.77  16.47  10.68       ...
# Washington Wizards 13-14      0.2423  5.19  14.72   9.87       ...
# Washington Wizards 14-15      0.2322  5.70  16.34  11.15       ...
# Washington Wizards 15-16      0.2692  3.75  15.20   9.37       ...
# Washington Wizards 16-17      0.2294  4.41  14.27   9.36       ...
# Washington Wizards 17-18      0.2736  5.00  15.39  10.20       ...
#
#                               OBPM  DBPM   BPM  VORP    YR  YRprior  \
# TM
# Atlanta Hawks 13-14           0.11 -0.02  0.10  1.04  14.0     13.0
# Atlanta Hawks 14-15           0.55  0.33  0.88  1.58  15.0     14.0
# Atlanta Hawks 15-16          -0.34  0.94  0.60  1.49  16.0     15.0
# Atlanta Hawks 16-17          -1.12  0.81 -0.31  0.88  17.0     16.0
# Atlanta Hawks 17-18          -0.49 -0.40 -0.93  0.52  18.0     17.0
# Boston Celtics 13-14         -0.85 -0.35 -1.23  0.33  14.0     13.0
# Boston Celtics 14-15         -0.33  0.58  0.22  0.86  15.0     14.0
# Boston Celtics 15-16         -0.18  0.68  0.49  1.39  16.0     15.0
# Boston Celtics 16-17          0.17  0.17  0.36  1.32  17.0     16.0
# Boston Celtics 17-18         -0.31  1.12  0.80  1.38  18.0     17.0
# Brooklyn Nets 13-14          -0.05  0.15  0.11  0.89  14.0     13.0
# Brooklyn Nets 14-15          -0.21 -0.28 -0.52  0.66  15.0     14.0
# Brooklyn Nets 15-16          -0.79 -1.10 -1.89  0.16  16.0     15.0
# Brooklyn Nets 16-17          -1.38 -0.32 -1.70  0.18  17.0     16.0
# Brooklyn Nets 17-18          -0.20 -0.42 -0.61  0.69  18.0     17.0
# Charlotte Bobcats 13-14      -0.97  0.75 -0.22  0.96  14.0     13.0
# Charlotte Hornets 14-15      -1.56  0.62 -0.95  0.57  15.0     14.0
# Charlotte Hornets 15-16      -0.37  0.57  0.20  1.24  16.0     15.0
# Charlotte Hornets 16-17      -0.33 -0.02 -0.35  1.04  17.0     16.0
# Charlotte Hornets 17-18       0.04 -0.20 -0.17  1.05  18.0     17.0
# Chicago Bulls 13-14          -1.22  1.25  0.05  1.28  14.0     13.0
# Chicago Bulls 14-15           0.50  0.10  0.61  1.42  15.0     14.0
# Chicago Bulls 15-16          -0.38 -0.44 -0.81  0.76  16.0     15.0
# Chicago Bulls 16-17          -0.22  0.21  0.02  1.10  17.0     16.0
# Chicago Bulls 17-18          -1.45 -0.25 -1.73  0.22  18.0     17.0
# Cleveland Cavaliers 13-14    -0.30 -0.39 -0.68  0.63  14.0     13.0
# Cleveland Cavaliers 14-15     1.00 -0.09  0.91  1.59  15.0     14.0
# Cleveland Cavaliers 15-16     0.73  0.18  0.89  1.72  16.0     15.0
# Cleveland Cavaliers 16-17     0.91 -0.35  0.56  1.47  17.0     16.0
# Cleveland Cavaliers 17-18     0.66 -0.95 -0.31  1.15  18.0     17.0
# ...                            ...   ...   ...   ...   ...      ...
# Portland Trail Blazers 13-14  0.39 -0.15  0.22  1.60  14.0     13.0
# Portland Trail Blazers 14-15  0.43  0.38  0.82  1.53  15.0     14.0
# Portland Trail Blazers 15-16  0.22 -0.13  0.07  1.21  16.0     15.0
# Portland Trail Blazers 16-17 -0.24 -0.25 -0.49  0.96  17.0     16.0
# Portland Trail Blazers 17-18 -0.39  0.79  0.42  1.33  18.0     17.0
# Sacramento Kings 13-14       -0.51 -0.32 -0.85  0.74  14.0     13.0
# Sacramento Kings 14-15        0.10 -0.90 -0.79  0.71  15.0     14.0
# Sacramento Kings 15-16       -0.20 -0.31 -0.52  0.77  16.0     15.0
# Sacramento Kings 16-17       -0.40 -0.43 -0.83  0.57  17.0     16.0
# Sacramento Kings 17-18       -0.94 -0.55 -1.51  0.22  18.0     17.0
# San Antonio Spurs 13-14       1.18  1.28  2.48  1.96  14.0     13.0
# San Antonio Spurs 14-15       0.81  1.08  1.89  1.82  15.0     14.0
# San Antonio Spurs 15-16       0.81  2.09  2.87  2.17  16.0     15.0
# San Antonio Spurs 16-17       0.48  1.34  1.82  1.79  17.0     16.0
# San Antonio Spurs 17-18      -0.10  1.05  0.98  1.38  18.0     17.0
# Toronto Raptors 13-14         0.18  0.18  0.38  1.34  14.0     13.0
# Toronto Raptors 14-15         1.33 -0.64  0.69  1.32  15.0     14.0
# Toronto Raptors 15-16         0.56  0.20  0.74  1.46  16.0     15.0
# Toronto Raptors 16-17         0.75  0.38  1.11  1.38  17.0     16.0
# Toronto Raptors 17-18         1.34  0.60  1.92  1.85  18.0     17.0
# Utah Jazz 13-14              -0.87 -1.08 -1.94  0.31  14.0     13.0
# Utah Jazz 14-15              -0.43  0.27 -0.15  1.08  15.0     14.0
# Utah Jazz 15-16              -0.16  0.47  0.32  1.21  16.0     15.0
# Utah Jazz 16-17               0.11  0.66  0.75  1.53  17.0     16.0
# Utah Jazz 17-18              -0.21  1.50  1.30  1.52  18.0     17.0
# Washington Wizards 13-14     -0.88  0.15 -0.73  1.11  14.0     13.0
# Washington Wizards 14-15     -0.74  0.61 -0.13  1.06  15.0     14.0
# Washington Wizards 15-16     -0.14  0.10 -0.03  1.10  16.0     15.0
# Washington Wizards 16-17      0.07 -0.63 -0.56  1.22  17.0     16.0
# Washington Wizards 17-18      0.14 -0.07  0.07  1.10  18.0     17.0
#
#                                     MPG  Year  TOUCHES  PTS PER\nTOUCH
# TM
# Atlanta Hawks 13-14           26.562538  14.0    48.30          0.2394
# Atlanta Hawks 14-15           24.635760  15.0    44.67          0.2377
# Atlanta Hawks 15-16           24.310153  16.0    43.79          0.2443
# Atlanta Hawks 16-17           25.435854  17.0    43.63          0.2535
# Atlanta Hawks 17-18           24.258777  18.0    47.21          0.2345
# Boston Celtics 13-14          25.577461  14.0    42.31          0.2332
# Boston Celtics 14-15          26.908659  15.0    47.29          0.2431
# Boston Celtics 15-16          24.614810  16.0    44.56          0.2453
# Boston Celtics 16-17          25.287533  17.0    47.05          0.2345
# Boston Celtics 17-18          25.650528  18.0    45.49          0.2464
# Brooklyn Nets 13-14           24.079364  14.0    41.53          0.2436
# Brooklyn Nets 14-15           26.398827  15.0    45.70          0.2616
# Brooklyn Nets 15-16           25.348534  16.0    46.01          0.2392
# Brooklyn Nets 16-17           23.272851  17.0    41.19          0.2453
# Brooklyn Nets 17-18           24.966528  18.0    46.65          0.2478
# Charlotte Bobcats 13-14       25.315766  14.0    45.79          0.2523
# Charlotte Hornets 14-15       25.802138  15.0    45.32          0.2455
# Charlotte Hornets 15-16       25.070673  16.0    42.89          0.2705
# Charlotte Hornets 16-17       25.638988  17.0    42.52          0.2853
# Charlotte Hornets 17-18       24.037374  18.0    41.28          0.2663
# Chicago Bulls 13-14           28.210786  14.0    48.36          0.2328
# Chicago Bulls 14-15           27.724394  15.0    49.14          0.2441
# Chicago Bulls 15-16           25.051986  16.0    44.59          0.2537
# Chicago Bulls 16-17           24.506922  17.0    43.26          0.2551
# Chicago Bulls 17-18           24.593300  18.0    42.19          0.2554
# Cleveland Cavaliers 13-14     25.368130  14.0    43.52          0.2504
# Cleveland Cavaliers 14-15     27.770544  15.0    48.11          0.2480
# Cleveland Cavaliers 15-16     25.947049  16.0    45.36          0.2496
# Cleveland Cavaliers 16-17     26.482265  17.0    42.66          0.2707
# Cleveland Cavaliers 17-18     23.384628  18.0    38.62          0.2774
# ...                                 ...   ...      ...             ...
# Portland Trail Blazers 13-14  25.194798  14.0    43.20          0.2626
# Portland Trail Blazers 14-15  26.501017  15.0    44.09          0.2749
# Portland Trail Blazers 15-16  24.662942  16.0    40.93          0.2612
# Portland Trail Blazers 16-17  26.167940  17.0    41.86          0.2539
# Portland Trail Blazers 17-18  24.987358  18.0    40.47          0.2574
# Sacramento Kings 13-14        25.258274  14.0    40.62          0.2655
# Sacramento Kings 14-15        25.592507  15.0    43.63          0.2662
# Sacramento Kings 15-16        26.205876  16.0    44.85          0.2810
# Sacramento Kings 16-17        24.855692  17.0    45.44          0.2307
# Sacramento Kings 17-18        24.833019  18.0    45.00          0.2374
# San Antonio Spurs 13-14       23.836236  14.0    44.58          0.2409
# San Antonio Spurs 14-15       24.161860  15.0    45.71          0.2399
# San Antonio Spurs 15-16       23.465983  16.0    44.21          0.2272
# San Antonio Spurs 16-17       23.772637  17.0    43.43          0.2416
# San Antonio Spurs 17-18       23.116239  18.0    41.23          0.2468
# Toronto Raptors 13-14         27.496203  14.0    47.30          0.2575
# Toronto Raptors 14-15         25.755107  15.0    42.13          0.2815
# Toronto Raptors 15-16         26.405230  16.0    45.70          0.2517
# Toronto Raptors 16-17         24.946455  17.0    40.88          0.2753
# Toronto Raptors 17-18         23.523042  18.0    41.71          0.2767
# Utah Jazz 13-14               25.317061  14.0    46.86          0.2141
# Utah Jazz 14-15               25.281453  15.0    50.42          0.1986
# Utah Jazz 15-16               25.648005  16.0    49.29          0.1962
# Utah Jazz 16-17               25.633998  17.0    46.63          0.2304
# Utah Jazz 17-18               24.368365  18.0    43.29          0.2453
# Washington Wizards 13-14      25.223940  14.0    44.19          0.2424
# Washington Wizards 14-15      24.376604  15.0    40.99          0.2602
# Washington Wizards 15-16      26.399341  16.0    46.01          0.2666
# Washington Wizards 16-17      24.899783  17.0    40.34          0.2799
# Washington Wizards 17-18      25.249598  18.0    43.19          0.2710
#
# [150 rows x 29 columns]

# %%
a.head()
# Out:
#               Player Pos  Age   G    MP   PER    TS%   3PAr    FTr  ORB%  \
# 1933   Allen Iverson  SG   32  82  3424  20.9  0.567  0.177  0.512   1.5
# 2344  Gilbert Arenas  PG   24  80  3384  23.8  0.581  0.324  0.479   2.0
# 1646    LeBron James  SF   21  79  3361  28.1  0.568  0.208  0.447   2.6
# 5016     Joe Johnson  SG   26  82  3343  17.3  0.535  0.297  0.253   2.9
# 4985     Joe Johnson  SG   24  82  3340  17.9  0.537  0.258  0.237   3.4
#
#         ...        WS  WS/48  OBPM  DBPM  BPM  VORP  \
# 1933    ...      11.6  0.163   3.5  -1.9  1.6   3.1
# 2344    ...      13.6  0.193   6.9  -1.4  5.5   6.4
# 1646    ...      16.3  0.232   7.9   1.4  9.3   9.5
# 5016    ...       7.0  0.100   3.1  -1.9  1.1   2.7
# 4985    ...       6.0  0.086   3.0  -2.4  0.7   2.2
#
#                              TM  YR  YRprior        MPG
# 1933       Denver Nuggets 07-08   8        7  41.756098
# 2344   Washington Wizards 05-06   6        5  42.300000
# 1646  Cleveland Cavaliers 05-06   6        5  42.544304
# 5016        Atlanta Hawks 07-08   8        7  40.768293
# 4985        Atlanta Hawks 05-06   6        5  40.731707
#
# [5 rows x 29 columns]

# %%
def sum_past_yrs(alladv):
    new = alladv
    for k, v in new.items():
        count = 1
        prior = k-count
        # 17 - prior (16)
        while prior > 4:
            # p, v in 15
            for player, votes in new[k].items():
                # p, in 14
                if player in new[prior].keys():
                    # p15 + p14
                    new[k][player] += new[prior][player]
            prior -= 1
    return new

# %%
fv_sum2 = sum_past_yrs(fv_dict)

# %%
fv_sum2
# Out:
# {17: {'Avery Bradley': 238.5,
#   'Klay Thompson': 39.5,
#   'John Wall': 70.75,
#   'DeAndre Jordan': 280.5,
#   'Paul Millsap': 64.25,
#   'Hassan Whiteside': 70.75,
#   'Marcus Smart': 10.25,
#   'Jimmy Butler': 237.5,
#   'LeBron James': 65.75,
#   'Robert Covington': 2.75,
#   'Russell Westbrook': 96.25,
#   'Paul George': 264.5,
#   'Kevin Durant': 14.5,
#   'Dwight Howard': 283.5,
#   'Mike Conley': 124.25,
#   'Jae Crowder': 24.75,
#   'Jrue Holiday': 5.25,
#   'Wesley Matthews': 11.75,
#   'Stephen Curry': 20.75,
#   'Andre Iguodala': 117.25,
#   'Michael Kidd-Gilchrist': 13.5,
#   'Ricky Rubio': 30.0,
#   'P.J. Tucker': 12.5,
#   'Trevor Ariza': 24.75,
#   'Nicolas Batum': 16.75,
#   'Marc Gasol': 67.5,
#   'Eric Gordon': 0.5,
#   'Karl-Anthony Towns': 0.5,
#   'Steven Adams': 0.25,
#   'LaMarcus Aldridge': 0.75,
#   'Al-Farouq Aminu': 0.25,
#   'Kentavious Caldwell-Pope': 13.75,
#   'George Hill': 15.5,
#   'Serge Ibaka': 449.25,
#   'Damian Lillard': 0.25,
#   'Luc Mbah a Moute': 11.75,
#   'Austin Rivers': 0.25,
#   'Isaiah Thomas': 0.25,
#   'Cody Zeller': 0.25,
#   'Kawhi Leonard': 458.5,
#   'Draymond Green': 347.75,
#   'Rudy Gobert': 121.5,
#   'Patrick Beverly': 83.5,
#   'Chris Paul': 677.5,
#   'Tony Allen': 616.75,
#   'Danny Green': 53.0,
#   'Andre Roberson': 13.75,
#   'Anthony Davis': 204.75,
#   'Giannis Antetokounmpo': 12.5},
#  16: {'Rudy Gobert': 43.0,
#   'Klay Thompson': 14.75,
#   'Jae Crowder': 11.75,
#   'LeBron James': 40.25,
#   'Kyle Lowry': 17.75,
#   'Danny Green': 21.0,
#   'Russell Westbrook': 71.0,
#   'Tim Duncan': 352.0,
#   'Ricky Rubio': 17.0,
#   'Kentavious Caldwell-Pope': 6.75,
#   'Anthony Davis': 130.0,
#   'Andre Drummond': 4.75,
#   'Serge Ibaka': 359.5,
#   'Stephen Curry': 12.5,
#   'Andre Iguodala': 95.25,
#   'Patrick Beverley': 7.75,
#   'Al Horford': 10.25,
#   'Marcus Smart': 2.75,
#   'John Wall': 41.0,
#   'Giannis Antetokounmpo': 2.25,
#   'Trevor Ariza': 18.0,
#   'Kent Bazemore': 0.75,
#   'Andrew Bogut': 63.75,
#   'DeMarcus Cousins': 1.25,
#   'Nicolas Batum': 13.0,
#   'Victor Oladipo': 3.25,
#   'LaMarcus Aldridge': 0.25,
#   'Harrison Barnes': 0.25,
#   'Bismack Biyombo': 0.25,
#   'Mike Conley': 97.0,
#   'Kevin Durant': 9.25,
#   'Derrick Favors': 0.25,
#   'George Hill': 12.25,
#   'Wesley Matthews': 8.75,
#   'Luc Mbah a Moute': 11.25,
#   'Kristaps Porzingis': 0.25,
#   'Andre Roberson': 0.25,
#   'Mike Scott': 0.25,
#   'Dwyane Wade': 100.25,
#   'Kawhi Leonard': 260.75,
#   'Draymond Green': 178.0,
#   'DeAndre Jordan': 175.0,
#   'Avery Bradley': 157.0,
#   'Chris Paul': 487.0,
#   'Paul Millsap': 29.0,
#   'Paul George': 183.5,
#   'Hassan Whiteside': 32.5,
#   'Tony Allen': 446.75,
#   'Jimmy Butler': 158.75},
#  15: {'Rudy Gobert': 13.5,
#   'LeBron James': 17.75,
#   'Russell Westbrook': 48.25,
#   'Avery Bradley': 87.0,
#   'Michael Kidd-Gilchrist': 6.75,
#   'Marc Gasol': 48.5,
#   'Danny Green': 6.0,
#   'Trevor Ariza': 11.75,
#   'Stephen Curry': 5.0,
#   'DeMarre Carroll': 3.75,
#   'Patrick Beverley': 2.5,
#   'Khris Middleton': 2.25,
#   'Serge Ibaka': 270.0,
#   'Andre Iguodala': 74.0,
#   'Paul Millsap': 2.5,
#   'Jeff Teague': 2.75,
#   'Mike Conley': 71.0,
#   'Joakim Noah': 218.0,
#   'Nerlens Noel': 1.25,
#   'P.J. Tucker': 7.5,
#   'Giannis Antetokounmpo': 0.75,
#   'Pau Gasol': 3.75,
#   'Wesley Matthews': 6.75,
#   'James Harden': 1.5,
#   'Marcus Smart': 0.5,
#   'Hassan Whiteside': 0.5,
#   'Eric Bledsoe': 7.75,
#   'DeMarcus Cousins': 0.25,
#   'Andre Drummond': 0.75,
#   'Manu Ginobili': 24.25,
#   'Blake Griffin': 0.25,
#   'George Hill': 9.25,
#   'Al Horford': 8.25,
#   'Victor Oladipo': 1.75,
#   'Zaza Pachulia': 0.25,
#   'Elfrid Payton': 0.25,
#   'Zach Randolph': 0.25,
#   'Rajon Rondo': 152.75,
#   'Iman Shumpert': 15.25,
#   'Dwyane Wade': 97.25,
#   'Kawhi Leonard': 111.0,
#   'Draymond Green': 57.75,
#   'Tony Allen': 296.75,
#   'DeAndre Jordan': 78.25,
#   'Chris Paul': 331.5,
#   'Anthony Davis': 69.75,
#   'Jimmy Butler': 84.5,
#   'Andrew Bogut': 36.5,
#   'John Wall': 20.75,
#   'Tim Duncan': 296.5},
#  14: {'DeAndre Jordan': 15.75,
#   'Anthony Davis': 15.5,
#   'Tony Allen': 177.0,
#   'Tim Duncan': 249.25,
#   'Dwight Howard': 266.5,
#   'Taj Gibson': 5.25,
#   'Mike Conley': 45.25,
#   'Ricky Rubio': 4.75,
#   'Lance Stephenson': 3.5,
#   'P.J. Tucker': 3.25,
#   'Kevin Durant': 5.5,
#   'Kyle Lowry': 4.5,
#   'Eric Bledsoe': 4.25,
#   'Marc Gasol': 30.0,
#   'John Wall': 2.0,
#   'Thabo Sefolosha': 56.0,
#   'Kirk Hinrich': 44.75,
#   'Trevor Ariza': 6.25,
#   'Avery Bradley': 54.25,
#   'Russell Westbrook': 34.25,
#   'Klay Thompson': 1.25,
#   'Andrew Bogut': 10.0,
#   'Chris Bosh': 3.0,
#   'Luol Deng': 59.0,
#   'Wesley Matthews': 5.0,
#   'Tony Parker': 14.0,
#   'Nicolas Batum': 9.75,
#   'Stephen Curry': 0.75,
#   'Danny Green': 0.75,
#   'Michael Kidd-Gilchrist': 0.75,
#   'Shaun Livingston': 0.75,
#   'Victor Oladipo': 0.75,
#   'DeMarre Carroll': 0.5,
#   'Matt Barnes': 0.5,
#   'James Harden': 0.5,
#   'George Hill': 6.5,
#   'Jeff Teague': 0.5,
#   'Dwyane Wade': 94.5,
#   'Kemba Walker': 0.5,
#   'David West': 2.5,
#   'Arron Afflalo': 7.25,
#   'Corey Brewer': 4.25,
#   'Michael Carter-Williams': 0.25,
#   'Darren Collison': 0.25,
#   'DeMar DeRozan': 0.25,
#   'Andre Drummond': 0.25,
#   'Monta Ellis': 0.25,
#   'Danny Granger': 0.25,
#   'Draymond Green': 0.25,
#   'Reggie Jackson': 0.25,
#   'David Lee': 2.25,
#   'Paul Millsap': 0.25,
#   'Rajon Rondo': 152.25,
#   'Joakim Noah': 136.75,
#   'Paul George': 104.25,
#   'Chris Paul': 213.0,
#   'Serge Ibaka': 184.0,
#   'Andre Igoudala': 52.0,
#   'Lebron James': 320.5,
#   'Patrick Beverly': 28.0,
#   'Jimmy Butler': 25.75,
#   'Kawhi Leonard': 26.25,
#   'Roy Hibbert': 31.0},
#  13: {'Andre Iguodala': 56,
#   'Larry Sanders': 16,
#   'Thabo Sefolosha': 39,
#   'Luol Deng': 47,
#   'Dwight Howard': 251,
#   'Kobe Bryant': 267,
#   'Roy Hibbert': 6,
#   'Kenneth Faried': 4,
#   'Russell Westbrook': 29,
#   'Shane Battier': 89,
#   'Nicolas Batum': 7,
#   'Corey Brewer': 2,
#   'George Hill': 4,
#   'Mike James': 3,
#   'Kawhi Leonard': 2,
#   'Tony Parker': 11,
#   'Dwyane Wade': 92,
#   'Metta World Peace': 57,
#   'Eric Bledsoe': 1,
#   'Kevin Durant': 2,
#   'Jrue Holiday': 3,
#   'Andrei Kirilenko': 17,
#   'Iman Shumpert': 14,
#   'David West': 1,
#   'Tony Allen': 109,
#   'Serge Ibaka': 100,
#   'Lebron James': 235,
#   'Chris Paul': 137,
#   'Joakim Noah': 57,
#   'Tyson Chandler': 96,
#   'Avery Bradley': 28,
#   'Mike Conley': 21,
#   'Tim Duncan': 218,
#   'Marc Gasol': 16,
#   'Paul George': 37},
#  12: {'Andre Iguodala': 40,
#   'Joakim Noah': 33,
#   'Iman Shumpert': 13,
#   'Paul George': 10,
#   'Russell Westbrook': 25,
#   'Josh Smith': 47,
#   'Dwyane Wade': 90,
#   'Thabo Sefolosha': 24,
#   'Grant Hill': 20,
#   'Tim Duncan': 198,
#   'Avery Bradley': 3,
#   'Marc Gasol': 4,
#   'Metta World Peace': 55,
#   'Shawn Marion': 39,
#   'Joe Johnson': 11,
#   'Mike Conley': 2,
#   'Derrick Rose': 15,
#   'Jrue Holiday': 2,
#   'Carlos Boozer': 1,
#   'Luc Mbah a Moute': 11,
#   'Tony Allen': 56,
#   'Dwight Howard': 242,
#   'Serge Ibaka': 54,
#   'Lebron James': 183,
#   'Chris Paul': 100,
#   'Kobe Bryant': 261,
#   'Tyson Chandler': 72,
#   'Luol Deng': 36,
#   'Kevin Garnett': 237,
#   'Rajon Rondo': 152},
#  11: {'Derrick Rose': 14,
#   'Dwyane Wade': 85,
#   'Russell Westbrook': 16,
#   'Gerald Wallace': 65,
#   'Grant Hill': 15,
#   'Luol Deng': 16,
#   'Tim Duncan': 193,
#   'Chuck Hayes': 11,
#   'Al Horford': 8,
#   'Josh Smith': 39,
#   'Ron Artest': 38,
#   'Serge Ibaka': 7,
#   'Shane Battier': 87,
#   'Thabo Sefolosha': 19,
#   'Wesley Matthews': 4,
#   'Kendrick Perkins': 11,
#   'Nicolas Batum': 5,
#   'Joe Johnson': 9,
#   'Keith Bogans': 2,
#   'Kyle Lowry': 2,
#   'Lamar Odom': 4,
#   'Luc Mbah a Moute': 10,
#   'Manu Ginobili': 24,
#   'Andrew Bogut': 9,
#   'Andrew Bynum': 1,
#   'Arron Afflalo': 7,
#   'Jrue Holiday': 1,
#   'Kirk Hinrich': 43,
#   'Nene Hilario': 2,
#   'Ronnie Brewer': 7,
#   'Shawn Marion': 36,
#   'Tayshaun Prince': 92,
#   'Kobe Bryant': 244,
#   'Kevin Garnett': 211,
#   'Dwight Howard': 201,
#   'Lebron James': 130,
#   'Rajon Rondo': 123,
#   'Tony Allen': 23,
#   'Tyson Chandler': 36,
#   'Andre Igoudala': 15,
#   'Joakim Noah': 19,
#   'Chis Paul': 18},
#  10: {'Jason Kidd': 95,
#   'Marcus Camby': 119,
#   'Ron Artest': 31,
#   'Deron Williams': 24,
#   'Kirk Hinrich': 42,
#   'Andrew Bogut': 8,
#   'Luc Mbah a Moute': 8,
#   'Arron Afflalo': 6,
#   'Kenyon Martin': 11,
#   'Kevin Garnett': 178,
#   'Grant Hill': 4,
#   'Joakim Noah': 4,
#   'Kendrick Perkins': 8,
#   'Shane Battier': 82,
#   'Andrei Kirilenko': 16,
#   'Russell Westbrook': 3,
#   'Trevor Ariza': 5,
#   'Andre Iguodala': 21,
#   'George Hill': 2,
#   'Jermaine O’Neal': 5,
#   'Joe Johnson': 7,
#   'Lamar Odom': 2,
#   'Luis Scola': 2,
#   'Manu Ginobili': 22,
#   'Nicolas Batum': 2,
#   'Caron Butler': 4,
#   'Chauncey Billups': 73,
#   'Jared Dudley': 1,
#   'Kevin Durant': 1,
#   'Raymond Felton': 1,
#   'Marc Gasol': 1,
#   'Pau Gasol': 3,
#   'Chuck Hayes': 1,
#   'Brendan Haywood': 2,
#   'Al Horford': 1,
#   'Serge Ibaka': 1,
#   'Ersan Ilyasova': 1,
#   'Stephen Jackson': 1,
#   'Nene Hilario': 1,
#   'Chris Paul': 65,
#   'Tayshaun Prince': 91,
#   'Earl Watson': 4,
#   'Kobe Bryant': 211,
#   'Dwight Howard': 145,
#   'Lebron James': 92,
#   'Rajon Rondo': 84,
#   'Gerald Wallace': 54,
#   'Tim Duncan': 182,
#   'Thabo Sefolosha': 14,
#   'Josh Smith': 32,
#   'Anderson Varejao': 18,
#   'Dwyane Wade': 72},
#  9: {'Tayshaun Prince': 90,
#   'Raja Bell': 60,
#   'Joel Przybilla': 10,
#   'Chauncey Billups': 72,
#   'Ronnie Brewer': 6,
#   'Andre Iguodala': 19,
#   'Yao Ming': 6,
#   'Emeka Okafor': 12,
#   'Kendrick Perkins': 4,
#   'Samuel Dalembert': 6,
#   'Derek Fisher': 7,
#   'Udonis Haslem': 6,
#   'Jason Kidd': 83,
#   'Anderson Varejao': 3,
#   'Deron Williams': 14,
#   'Trevor Ariza': 2,
#   'Kirk Hinrich': 33,
#   'Joe Johnson': 5,
#   'Andrei Kirilenko': 13,
#   'David Lee': 2,
#   'James Posey': 2,
#   'J.R. Smith': 2,
#   'Gerald Wallace': 24,
#   'NenFe': 1,
#   'Chris Andersen': 1,
#   'Pau Gasol': 2,
#   'Antonio McDyess': 1,
#   'Andre Miller': 7,
#   'Travis Outlaw': 1,
#   'Brandon Roy': 3,
#   'Rasheed Wallace': 39,
#   'Kobe Bryant': 177,
#   'Kevin Garnett': 173,
#   'Dwight Howard': 88,
#   'Lebron James': 47,
#   'Chris Paul': 64,
#   'Metta World Peace': 52,
#   'Shane Battier': 78,
#   'Tim Duncan': 161,
#   'Rajon Rondo': 34,
#   'Dwyane Wade': 52},
#  8: {'Chauncey Billups': 67,
#   'Jason Kidd': 80,
#   'Rasheed Wallace': 38,
#   'Rajon Rondo': 11,
#   'Deron Williams': 11,
#   'Josh Smith': 12,
#   'Ron Artest': 20,
#   'Tyson Chandler': 19,
#   'Andrei Kirilenko': 11,
#   'Derek Fisher': 4,
#   'LeBron James': 6,
#   'Manu Ginobili': 20,
#   'Kirk Hinrich': 31,
#   'Samuel Dalembert': 3,
#   'Andre Iguodala': 14,
#   'Brandon Roy': 2,
#   'Paul Pierce': 2,
#   'Andre Miller': 6,
#   'Andres Nocioni': 2,
#   'Baron Davis': 1,
#   'Caron Butler': 3,
#   'Chris Bosh': 2,
#   'Dikembe Mutombo': 1,
#   'Josh Howard': 13,
#   'Richard Hamilton': 4,
#   'Ronnie Brewer': 1,
#   'Bruce Bowen': 181,
#   'Kobe Bryant': 124,
#   'Marcus Camby': 107,
#   'Tim Duncan': 131,
#   'Kevin Garnett': 138,
#   'Shane Battier': 56,
#   'Raja Bell': 52,
#   'Dwight Howard': 33,
#   'Chris Paul': 28,
#   'Tayshaun Prince': 75},
#  7: {'Shane Battier': 27,
#   'Shawn Marion': 35,
#   'Chauncey Billups': 53,
#   'Ron Artest': 12,
#   'Gerald Wallace': 22,
#   'Alonzo Mourning': 16,
#   'Devin Harris': 8,
#   'Tyson Chandler': 11,
#   'Josh Howard': 12,
#   'Emeka Okafor': 7,
#   'Luol Deng': 5,
#   'Rasheed Wallace': 25,
#   'Dwight Howard': 8,
#   'Andrei Kirilenko': 5,
#   'Josh Smith': 4,
#   'Manu Ginobili': 16,
#   'Richard Hamilton': 3,
#   'Jermaine O’Neal': 3,
#   'Andre Iguodala': 12,
#   'Deron Williams': 3,
#   'Elton Brand': 4,
#   'Dwyane Wade': 26,
#   'Trenton Hassell': 5,
#   'Tony Parker': 9,
#   'Caron Butler': 2,
#   'Chris Duhon': 1,
#   'Allen Iverson': 17,
#   'Udonis Haslem': 3,
#   'Richard Jefferson': 2,
#   'Chris Paul': 2,
#   'Andre Miller': 5,
#   'Joel Przybilla': 3,
#   'Francisco Elson': 1,
#   'Chris Bosh': 1,
#   'Gilbert Arenas': 6,
#   'Raja Bell': 34,
#   'Bruce Bowen': 145,
#   'Kobe Bryant': 72,
#   'Marcus Camby': 70,
#   'Tim Duncan': 98,
#   'Kevin Garnett': 86,
#   'Kirk Hinrich': 28,
#   'Jason Kidd': 67,
#   'Tayshaun Prince': 55,
#   'Ben Wallace': 138},
#  6: {'Rasheed Wallace': 20,
#   'Gerald Wallace': 11,
#   'Shawn Marion': 20,
#   'Raja Bell': 9,
#   'Dwyane Wade': 24,
#   'Kirk Hinrich': 10,
#   'Alonzo Mourning': 7,
#   'Shane Battier': 10,
#   'Gilbert Arenas': 5,
#   'Andre Iguodala': 9,
#   'P.J. Brown': 4,
#   'Manu Ginobili': 12,
#   'Dwight Howard': 3,
#   'Josh Howard': 5,
#   'Brevin Knight': 5,
#   'Shaquille O’Neal': 19,
#   'Elton Brand': 2,
#   'LeBron James': 2,
#   'Tony Parker': 7,
#   'Quinton Ross': 2,
#   'Allen Iverson': 16,
#   'Eddie Jones': 3,
#   'Jason Collins': 1,
#   'Boris Diaw': 1,
#   'Pau Gasol': 1,
#   'Trenton Hassel': 1,
#   'Mike James': 1,
#   'Richard Jefferson': 1,
#   'Ruben Patterson': 1,
#   'Chris Paul': 1,
#   'Jason Terry': 1,
#   'Yao Ming': 1,
#   'Metta World Peace': 30,
#   'Bruce Bowen': 103,
#   'Andrei Kirlienko': 61,
#   'Kobe Bryant': 40,
#   'Ben Wallace': 105,
#   'Jason Kidd': 44,
#   'Chauncey Billups': 40,
#   'Marcus Camby': 36,
#   'Tim Duncan': 62,
#   'Kevin Garnett': 66,
#   'Tayshaun Prince': 34},
#  5: {'Shaquille O’Neal': 16,
#   'Allen Iverson': 14,
#   'Kobe Bryant': 12,
#   'Shawn Marion': 9,
#   'Manu Ginobili': 9,
#   'Rasheed Wallace': 8,
#   'Kenyon Martin': 6,
#   'Tony Parker': 5,
#   'Andre Iguodala': 5,
#   'Shane Battier': 4,
#   'Andre Miller': 4,
#   'Tyson Chandler': 3,
#   'Trenton Hassell': 3,
#   'Kirk Hinrich': 3,
#   'Joe Johnson': 3,
#   'Earl Watson': 3,
#   'Udonis Haslem': 2,
#   'Tracy McGrady': 2,
#   'Josh Howard': 2,
#   'Joel Przybilla': 2,
#   'Desmond Mason': 2,
#   'Brevin Knight': 2,
#   'Vince Carter': 1,
#   'P.J. Brown': 1,
#   'Mickael Pietrus': 1,
#   'Kurt Thomas': 1,
#   'Jeff Foster': 1,
#   'Greg Buckner': 1,
#   'Gilbert Arenas': 1,
#   'Gary Payton': 1,
#   'Emeka Okafor': 1,
#   'Eddie Jones': 1,
#   'Clifford Robinson': 1,
#   'Brendan Haywood': 1,
#   'Anthony Johnson': 1,
#   'Andres Nocioni': 1,
#   'Amaré Stoudemire': 1,
#   'Ben Wallace': 51,
#   'Kevin Garnett': 48,
#   'Bruce Bowen': 48,
#   'Tim Duncan': 39,
#   'Larry Hughes': 22,
#   'Tayshaun Prince': 21,
#   'Marcus Camby': 21,
#   'Chauncey Billups': 17,
#   'Andrei Kirlienko': 17,
#   'Jason Kidd': 16,
#   'Dwyane Wade': 16}}

# %%
fv_df2 = pd.DataFrame.from_dict(fv_sum2)

# %%
fv_df2
# Out:
#                        17      16      15      14     13     12     11     10  \
# Al Horford            NaN   10.25    8.25     NaN    NaN    NaN    8.0    1.0
# Al-Farouq Aminu      0.25     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Allen Iverson         NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Alonzo Mourning       NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Amaré Stoudemire      NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Anderson Varejao      NaN     NaN     NaN     NaN    NaN    NaN    NaN   18.0
# Andre Drummond        NaN    4.75    0.75    0.25    NaN    NaN    NaN    NaN
# Andre Igoudala        NaN     NaN     NaN   52.00    NaN    NaN   15.0    NaN
# Andre Iguodala     117.25   95.25   74.00     NaN   56.0   40.0    NaN   21.0
# Andre Miller          NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Andre Roberson      13.75    0.25     NaN     NaN    NaN    NaN    NaN    NaN
# Andrei Kirilenko      NaN     NaN     NaN     NaN   17.0    NaN    NaN   16.0
# Andrei Kirlienko      NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Andres Nocioni        NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Andrew Bogut          NaN   63.75   36.50   10.00    NaN    NaN    9.0    8.0
# Andrew Bynum          NaN     NaN     NaN     NaN    NaN    NaN    1.0    NaN
# Anthony Davis      204.75  130.00   69.75   15.50    NaN    NaN    NaN    NaN
# Anthony Johnson       NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Antonio McDyess       NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Arron Afflalo         NaN     NaN     NaN    7.25    NaN    NaN    7.0    6.0
# Austin Rivers        0.25     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Avery Bradley      238.50  157.00   87.00   54.25   28.0    3.0    NaN    NaN
# Baron Davis           NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Ben Wallace           NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Bismack Biyombo       NaN    0.25     NaN     NaN    NaN    NaN    NaN    NaN
# Blake Griffin         NaN     NaN    0.25     NaN    NaN    NaN    NaN    NaN
# Boris Diaw            NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Brandon Roy           NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Brendan Haywood       NaN     NaN     NaN     NaN    NaN    NaN    NaN    2.0
# Brevin Knight         NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# ...                   ...     ...     ...     ...    ...    ...    ...    ...
# Rudy Gobert        121.50   43.00   13.50     NaN    NaN    NaN    NaN    NaN
# Russell Westbrook   96.25   71.00   48.25   34.25   29.0   25.0   16.0    3.0
# Samuel Dalembert      NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Serge Ibaka        449.25  359.50  270.00  184.00  100.0   54.0    7.0    1.0
# Shane Battier         NaN     NaN     NaN     NaN   89.0    NaN   87.0   82.0
# Shaquille O’Neal      NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Shaun Livingston      NaN     NaN     NaN    0.75    NaN    NaN    NaN    NaN
# Shawn Marion          NaN     NaN     NaN     NaN    NaN   39.0   36.0    NaN
# Stephen Curry       20.75   12.50    5.00    0.75    NaN    NaN    NaN    NaN
# Stephen Jackson       NaN     NaN     NaN     NaN    NaN    NaN    NaN    1.0
# Steven Adams         0.25     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Taj Gibson            NaN     NaN     NaN    5.25    NaN    NaN    NaN    NaN
# Tayshaun Prince       NaN     NaN     NaN     NaN    NaN    NaN   92.0   91.0
# Thabo Sefolosha       NaN     NaN     NaN   56.00   39.0   24.0   19.0   14.0
# Tim Duncan            NaN  352.00  296.50  249.25  218.0  198.0  193.0  182.0
# Tony Allen         616.75  446.75  296.75  177.00  109.0   56.0   23.0    NaN
# Tony Parker           NaN     NaN     NaN   14.00   11.0    NaN    NaN    NaN
# Tracy McGrady         NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Travis Outlaw         NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Trenton Hassel        NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Trenton Hassell       NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Trevor Ariza        24.75   18.00   11.75    6.25    NaN    NaN    NaN    5.0
# Tyson Chandler        NaN     NaN     NaN     NaN   96.0   72.0   36.0    NaN
# Udonis Haslem         NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Victor Oladipo        NaN    3.25    1.75    0.75    NaN    NaN    NaN    NaN
# Vince Carter          NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Wesley Matthews     11.75    8.75    6.75    5.00    NaN    NaN    4.0    NaN
# Yao Ming              NaN     NaN     NaN     NaN    NaN    NaN    NaN    NaN
# Zach Randolph         NaN     NaN    0.25     NaN    NaN    NaN    NaN    NaN
# Zaza Pachulia         NaN     NaN    0.25     NaN    NaN    NaN    NaN    NaN
#
#                       9      8      7      6     5
# Al Horford           NaN    NaN    NaN    NaN   NaN
# Al-Farouq Aminu      NaN    NaN    NaN    NaN   NaN
# Allen Iverson        NaN    NaN   17.0   16.0  14.0
# Alonzo Mourning      NaN    NaN   16.0    7.0   NaN
# Amaré Stoudemire     NaN    NaN    NaN    NaN   1.0
# Anderson Varejao     3.0    NaN    NaN    NaN   NaN
# Andre Drummond       NaN    NaN    NaN    NaN   NaN
# Andre Igoudala       NaN    NaN    NaN    NaN   NaN
# Andre Iguodala      19.0   14.0   12.0    9.0   5.0
# Andre Miller         7.0    6.0    5.0    NaN   4.0
# Andre Roberson       NaN    NaN    NaN    NaN   NaN
# Andrei Kirilenko    13.0   11.0    5.0    NaN   NaN
# Andrei Kirlienko     NaN    NaN    NaN   61.0  17.0
# Andres Nocioni       NaN    2.0    NaN    NaN   1.0
# Andrew Bogut         NaN    NaN    NaN    NaN   NaN
# Andrew Bynum         NaN    NaN    NaN    NaN   NaN
# Anthony Davis        NaN    NaN    NaN    NaN   NaN
# Anthony Johnson      NaN    NaN    NaN    NaN   1.0
# Antonio McDyess      1.0    NaN    NaN    NaN   NaN
# Arron Afflalo        NaN    NaN    NaN    NaN   NaN
# Austin Rivers        NaN    NaN    NaN    NaN   NaN
# Avery Bradley        NaN    NaN    NaN    NaN   NaN
# Baron Davis          NaN    1.0    NaN    NaN   NaN
# Ben Wallace          NaN    NaN  138.0  105.0  51.0
# Bismack Biyombo      NaN    NaN    NaN    NaN   NaN
# Blake Griffin        NaN    NaN    NaN    NaN   NaN
# Boris Diaw           NaN    NaN    NaN    1.0   NaN
# Brandon Roy          3.0    2.0    NaN    NaN   NaN
# Brendan Haywood      NaN    NaN    NaN    NaN   1.0
# Brevin Knight        NaN    NaN    NaN    5.0   2.0
# ...                  ...    ...    ...    ...   ...
# Rudy Gobert          NaN    NaN    NaN    NaN   NaN
# Russell Westbrook    NaN    NaN    NaN    NaN   NaN
# Samuel Dalembert     6.0    3.0    NaN    NaN   NaN
# Serge Ibaka          NaN    NaN    NaN    NaN   NaN
# Shane Battier       78.0   56.0   27.0   10.0   4.0
# Shaquille O’Neal     NaN    NaN    NaN   19.0  16.0
# Shaun Livingston     NaN    NaN    NaN    NaN   NaN
# Shawn Marion         NaN    NaN   35.0   20.0   9.0
# Stephen Curry        NaN    NaN    NaN    NaN   NaN
# Stephen Jackson      NaN    NaN    NaN    NaN   NaN
# Steven Adams         NaN    NaN    NaN    NaN   NaN
# Taj Gibson           NaN    NaN    NaN    NaN   NaN
# Tayshaun Prince     90.0   75.0   55.0   34.0  21.0
# Thabo Sefolosha      NaN    NaN    NaN    NaN   NaN
# Tim Duncan         161.0  131.0   98.0   62.0  39.0
# Tony Allen           NaN    NaN    NaN    NaN   NaN
# Tony Parker          NaN    NaN    9.0    7.0   5.0
# Tracy McGrady        NaN    NaN    NaN    NaN   2.0
# Travis Outlaw        1.0    NaN    NaN    NaN   NaN
# Trenton Hassel       NaN    NaN    NaN    1.0   NaN
# Trenton Hassell      NaN    NaN    5.0    NaN   3.0
# Trevor Ariza         2.0    NaN    NaN    NaN   NaN
# Tyson Chandler       NaN   19.0   11.0    NaN   3.0
# Udonis Haslem        6.0    NaN    3.0    NaN   2.0
# Victor Oladipo       NaN    NaN    NaN    NaN   NaN
# Vince Carter         NaN    NaN    NaN    NaN   1.0
# Wesley Matthews      NaN    NaN    NaN    NaN   NaN
# Yao Ming             6.0    NaN    NaN    1.0   NaN
# Zach Randolph        NaN    NaN    NaN    NaN   NaN
# Zaza Pachulia        NaN    NaN    NaN    NaN   NaN
#
# [199 rows x 13 columns]

# %%
ad
